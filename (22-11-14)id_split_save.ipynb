# %% [markdown]
# # GOAL: ID LIST SPLIT 한 후에 FIX하여 학습진행 및 모델 고도화

# %%
import pandas as pd
import numpy as np
#import tensorflow as tf 
import os
import sys
from datetime import datetime, timedelta
from tqdm.autonotebook import tqdm
import csv
import re
from tensorflow.keras.optimizers import Adam
from xgboost import XGBClassifier
import scikitplot as skplt
import gzip
import shutil
from tensorflow.keras.models import Model, Sequential, load_model
from tensorflow.keras.layers import (
    Activation,
    AveragePooling2D,
    Dense,
    Dropout,
    Input,
    LSTM,
    GRU,
    Embedding,
    Bidirectional
)
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score, classification_report
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   import sys

# %%
path = '/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/icu/'

# %%
new_path = '/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/'

# %%
hos_path = '/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/hosp/'

# %%
import pickle
with gzip.open(new_path+'new_dict/death_dataset_20221112.pickle','rb') as f:  
    death_dataset = pickle.load(f)

# %%
hadm_ids = death_dataset['HADM_IDS']

# %%
peni_id = pd.read_csv(new_path+'new_csv/id_peni.csv')
macro_id = pd.read_csv(new_path+'new_csv/id_macro.csv')
glyco_id = pd.read_csv(new_path+'new_csv/id_glyco.csv')
fluoro_id = pd.read_csv(new_path+'new_csv/id_fluoro.csv')
cepha_id = pd.read_csv(new_path+'new_csv/id_cepha.csv')

# %%
## Define some util functions
NOT_CONVERTED = 'NOT_CONVERTED'
## 문자로 기록된 날짜 값들을 파이썬의 datetime 데이터로 바꿔주는 함수 작성
def str2datetime(s):
    def _convert(_s, _dformat):
        try:
            converted_dt = datetime.strptime(_s, _dformat)
        except Exception:
            return NOT_CONVERTED

        return converted_dt

    if isinstance(s, datetime):
        return s

    dformats = [
        '%Y-%m-%d %p %I:%M:%S',
        '%Y-%m-%d %H:%M:%S.%f',
        '%Y-%m-%d %H:%M:%S',
        '%Y-%m-%d %H:%M',
        '%y-%m-%d %H:%M',
        '%Y-%m-%d',
        '%Y%m%d',
        '%Y-%m-%d +%H:%M',
        '%Y%m%d %H%M',
        '%Y%m%d%H%M%S',
        ]

    s = s.split('.')[0]
    s = s.replace('오전', 'am').replace('오후', 'pm')
    for dformat in dformats:
        dt = _convert(s, dformat)
        if dt != NOT_CONVERTED:
            return dt

    return NOT_CONVERTED

# %%
# 사망 레이블 하기
death_labels = dict()
admissions = csv.DictReader(open("/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimiciv_der/sepsis3_admissions.csv", 'r', encoding='utf-8'))
for row in tqdm(admissions, desc='Get Death Label'):
    hadm_id = row['hadm_id']
    death_yn = int(row['hospital_expire_flag'])
    if death_yn:
        event_time = str2datetime(row['deathtime'])
    else:
        event_time = str2datetime(row['dischtime'])
        death_labels[hadm_id] = dict({'DEATH': death_yn, 'EVENT_TIME': event_time})
# Out:
# Get Death Label: 0it [00:00, ?it/s]

# %%
# 재실 기간 레이블 하기
los_labels = dict()
admissions = csv.DictReader(open('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimiciv_der/sepsis3_admissions.csv', 'r', encoding='utf-8'))
for row in tqdm(admissions, desc='Get loss Label'):
    hadm_id = row['hadm_id']
    admin_time = str2datetime(row['admittime'])
    disc_time = str2datetime(row['dischtime'])
    los = (disc_time - admin_time).total_seconds() / (60*60)
    los_labels[hadm_id] = int(los)
# Out:
# Get loss Label: 0it [00:00, ?it/s]

# %%
## 환자의 입실 퇴실 시간 정보 가져오기
Extracted_HADMIDS = hadm_ids
admin_disc_time = dict()

admissions = csv.DictReader(open('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimiciv_der/sepsis3_admissions.csv', 'r', encoding='utf-8'))
for row in admissions:
    hadm_id = row['hadm_id']
    admin_time = str2datetime(row['admittime'])
    disc_time = str2datetime(row['dischtime'])

    if (admin_time != NOT_CONVERTED) and (disc_time != NOT_CONVERTED):
        admin_disc_time[hadm_id] = dict({'ADMIN': admin_time, 'DISC': disc_time})

# %%
feature_keys = ['FiO2', 'HR', 'PaO2', 'SBP', 'Temperature','Creatinine','Glucose', 'Hb', 'Lactate', 'Plt','Sodium' ,'WBC','DBP', 'MAP', 'RESP', 'Chloride', 'Hct', 'PCO2', 'Potassium', 'PH', 'Anion Gap', 'Bilirubin']

EXTRACT_FEATURE_CODES_VS = dict({
    '226754': 'FiO2', '223835': 'FiO2', '227010': 'FiO2', '229280': 'FiO2', '229841': 'FiO2',
    '220045': 'HR', '220046': 'HR', '226764': 'HR', '227018': 'HR',
    '220224': 'PaO2', '227039': 'PaO2', '227516': 'PaO2',
    '220050': 'SBP' ,'220179': 'SBP', '224167': 'SBP', '227243': 'SBP', '228152': 'SBP',
    '223762': 'Temperature', '226329': 'Temperature', '227632': 'Temperature', '227634': 'Temperature',
    '50825': 'Temperature',
    ####### 새로운 features ##########
   '223761': 'TEMP_F',
   '225310': 'DBP', '220051': 'DBP', '220180': 'DBP',
   '225312': 'MAP', '220052': 'MAP', '220181': 'MAP',
   '220210': 'RESP', '224690': 'RESP'
    })
EXTRACT_FEATURE_CODES_LAB = dict({
    '220615': 'Creatinine', '229761': 'Creatinine',
    '52024': 'Creatinine', '50912': 'Creatinine', '52546': 'Creatinine', '51977': 'Creatinine',  '51081': 'Creatinine',
    '220621': 'Glucose', '225664': 'Glucose', '226537': 'Glucose',
    '50809': 'Glucose', '52027': 'Glucose', '50931': 'Glucose', '52569': 'Glucose', '51981': 'Glucose', '51478': 'Glucose',
    '220228': 'Hb',
    '50811': 'Hb', '50855': 'Hb', '51640': 'Hb', '51645': 'Hb', '51222': 'Hb', '52157': 'Hb',
    '225668': 'Lactate',
    '50813': 'Lactate', '52442': 'Lactate',
    '227457': 'Plt',
    '51704': 'Plt', '51265': 'Plt',
    '220645': 'Sodium', '226534': 'Sodium',
    '50824': 'Sodium', '52455': 'Sodium', '50983': 'Sodium', '52623': 'Sodium',
    '220546': 'WBC',
    '51755': 'WBC', '51756': 'WBC', '51301': 'WBC',
    ######### 새로운 features ############
    '50902': 'Chloride', '50806': 'Chloride',
    '50810': 'Hct', '51221': 'Hct',
    '50810': 'PCO2',
    '50822': 'Potassium', '50971': 'Potassium', '845825': 'Potassium',
    '50820': 'PH',
    '50868': 'Anion Gap', '769895': 'Anion Gap', '52456': 'Anion Gap', 
    '50885': 'Bilirubin'})

EXTRACT_FEATURE_CODES_NORMAL = dict({ #outlier 범위 - medical knowledge에 기반하여 계산
        'FiO2': [10, 100],
        'HR': [30, 200],
        'PaO2': [50, 200],
        'SBP': [40, 250],
        'Temperature': [30, 45],
        'Creatinine': [0.2, 100],
        'Glucose': [30, 1000],
        'Hb': [5, 20],
        'Lactate': [0.5, 2.5],
        'Plt': [10, 500],
        'Sodium': [90, 170],
        'WBC': [1, 30],
        'DBP':[30, 200],
        'MAP':[33, 216],
        'RESP':[0, 35],
        'Chloride':[70, 130],
        'Hct':[10, 50], 
        'PCO2':[5, 100],
        'Potassium':[1.0, 10.0],
        'PH':[5.5, 8.0],
        'Anion Gap':[5, 50],
        'Bilirubin':[0.1, 10]
})
NORMAL_VALUE = dict({ #missing value 대체값
        'FiO2': 40,
        'HR': 75, #(50+100)/2
        'PaO2': 87.5, #(75+100)/2
        'SBP': 115, #(90+140)/2 = 115
        'Temperature': 36.65, #(36.1+37.2)/2
        'Creatinine': 1.0, #(0.7+1.0)/2
        'Glucose': 100, #(60+140)/2
        'Hb': 15.0, #(13.8+17.2)/2
        'Lactate': 1.35, #(0.5+2.2)/2 = 1.35
        'Plt': 270, #(140+400)/2
        'Sodium': 140, #(135+145)/2
        'WBC': 7.5, #(5+10)/2
        'WBC': 7.5, #(5+10)/2
        'DBP': 90, #(80+100)/2 
        'MAP': 98, # (115 + 2*90) / 
        'RESP': 13, 
        'Chloride': 102, #(96+108) / 2
        'Hct': 34.5, #(34+45)/2
        'PCO2': 40, #(35+45)/2
        'Potassium': 4.5, #(3.5+5.4)/2
        'PH': 7.4, #(7.35 + 7.45) / 2
        'Anion Gap': 14, #8+20/2
        'Bilirubin': 0.8 #0+1.5/2
})

# %%
total_death_included_hadm_ids = list(death_labels.keys())
total_los_included_hadm_ids = list(los_labels.keys())

# %%
for i in range(len(death_dataset['DATA'])):
    if (death_dataset['DATA'][i].shape[0]) < 13:
        zeros = np.zeros((13, death_dataset['DATA'][i].shape[1]))
        zeros[:death_dataset['DATA'][i].shape[0], :] = death_dataset['DATA'][i]
        death_dataset['DATA'][i] = zeros
    else:
        death_dataset['DATA'][i] = death_dataset['DATA'][i][:13]

# %%
def making_num(id_list):
    X = np.zeros((len(id_list) , 13, 22))
    y = np.zeros((len(id_list), 1))
    j = 0
    for idx, i in (enumerate(tqdm(death_dataset['HADM_IDS']))):
        if int(i) in id_list['hadm_id'].tolist():
            X[j] = death_dataset['DATA'][idx]
    #         print(death_dataset['DATA'][idx].reshape)
            y[j] = death_dataset['LABEL'][idx]
            j += 1
    return X, y

# %%
# 25개 따로 빼서 
peni_id.drop(index = [10, 20, 9, 50, 100], inplace=True)
macro_id.drop(index = [10, 20, 9, 50, 100], inplace=True)
glyco_id.drop(index = [10, 20, 9, 50, 100], inplace=True)
fluoro_id.drop(index = [10, 20, 9, 50, 100], inplace=True)
cepha_id.drop(index = [10, 20, 9, 50, 100], inplace=True)

# %%
(peni_X, peni_y) = making_num(peni_id)
(macro_X, macro_y) = making_num(macro_id)
(glyco_X, glyco_y) = making_num(glyco_id)
(fluoro_X, fluoro_y) = making_num(fluoro_id)
(cepha_X, cepha_y) = making_num(cepha_id)
# Out:
#   0%|          | 0/32340 [00:00<?, ?it/s]
#   0%|          | 0/32340 [00:00<?, ?it/s]
#   0%|          | 0/32340 [00:00<?, ?it/s]
#   0%|          | 0/32340 [00:00<?, ?it/s]
#   0%|          | 0/32340 [00:00<?, ?it/s]

# %%
print(peni_X.shape, peni_y.shape, macro_X.shape,macro_y.shape, glyco_X.shape, glyco_y.shape, fluoro_X.shape, fluoro_y.shape, cepha_X.shape, cepha_y.shape)
# Out:
# (6067, 13, 22) (6067, 1) (1915, 13, 22) (1915, 1) (11761, 13, 22) (11761, 1) (3649, 13, 22) (3649, 1) (10958, 13, 22) (10958, 1)

# %%
peni_Y = to_categorical(peni_y)
macro_Y = to_categorical(macro_y)
glyco_Y = to_categorical(glyco_y)
fluoro_Y = to_categorical(fluoro_y)
cepha_Y = to_categorical(cepha_y)

# %%
from sklearn.model_selection import RandomizedSearchCV, train_test_split
def split_train_test(X, y, id_list):
    idx = list(range(len(X)))
    ids = id_list
    train_idx, valid_idx, y_train, y_valid = train_test_split(idx, y, test_size=0.1, shuffle=True, stratify=y)
    test_idx, valid_idx, y_test, y_valid = train_test_split(valid_idx, y_valid, test_size=0.5, shuffle=True, stratify=y_valid)
    train_id = [ids[i] for i in train_idx]
    test_id = [ids[i] for i in test_idx]
    valid_id = [ids[i] for i in valid_idx]
    id_dict = {'train_idx': train_idx, 'train_id':train_id, 'valid_idx':valid_idx, 'valid_id':valid_id, 'test_idx': test_idx, 'test_id':test_id}
    train_x  = [X[i] for i in id_dict['train_idx']]
    test_x  = [X[i] for i in id_dict['test_idx']]
    valid_x  = [X[i] for i in id_dict['valid_idx']]
    train_y  = [y[i] for i in id_dict['train_idx']]
    test_y  = [y[i] for i in id_dict['test_idx']]
    valid_y  = [y[i] for i in id_dict['valid_idx']]
    
#     xgb = XGBClassifier().fit(x_train, y_train)
#     predictions = xgb.predict_proba(x_valid)
    return train_x, valid_x, test_x, train_y, valid_y, test_y, id_dict

# %%
x_peni_train, x_peni_valid, x_peni_test, y_peni_train, y_peni_valid, y_peni_test, peni_id_dict  = split_train_test(peni_X, peni_Y, peni_id['hadm_id'].tolist())
x_macro_train, x_macro_valid, x_macro_test, y_macro_train, y_macro_valid, y_macro_test, macro_id_dict = split_train_test(macro_X, macro_Y, macro_id['hadm_id'].tolist())
x_glyco_train, y_glyco_train, x_glyco_valid, y_glyco_valid,  x_glyco_test, y_glyco_test, glyco_id_dict = split_train_test(glyco_X, glyco_Y, glyco_id['hadm_id'].tolist())
x_fluoro_train, x_fluoro_valid, x_fluoro_test, y_fluoro_train, y_fluoro_valid,y_fluoro_test, fluoro_id_dict = split_train_test(fluoro_X, fluoro_Y, fluoro_id['hadm_id'].tolist())
x_cepha_train, x_cepha_valid, x_cepha_test, y_cepha_train, y_cepha_valid, y_cepha_test, cepha_id_dict = split_train_test(cepha_X, cepha_Y, cepha_id['hadm_id'].tolist())

# %%
def save_dict_numpy(id_dict, train_x, valid_x, test_x, train_y, valid_y, test_y, type_):
    import pickle
    with open('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/new_dict/{}/id_list.pkl'.format(type_),'wb') as f:
         pickle.dump(id_dict, f)
    np.savez_compressed('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/numpy/{}/train_test_valid.npz'.format(type_), train_x = train_x, valid_x=valid_x, test_x=test_x, train_y=train_y, test_y=test_y, valid_y=valid_y)

# %%
save_dict_numpy(peni_id_dict, x_peni_train, x_peni_valid, x_peni_test, y_peni_train, y_peni_valid, y_peni_test, 'peni')
save_dict_numpy(macro_id_dict, x_macro_train, x_macro_valid, x_macro_test, y_macro_train, y_macro_valid, y_macro_test, 'macro')
save_dict_numpy(glyco_id_dict, x_glyco_train, y_glyco_train, x_glyco_valid, y_glyco_valid,  x_glyco_test, y_glyco_test, 'glyco')
save_dict_numpy(fluoro_id_dict, x_fluoro_train, x_fluoro_valid, x_fluoro_test, y_fluoro_train, y_fluoro_valid,y_fluoro_test, 'fluoro')
save_dict_numpy(cepha_id_dict,x_cepha_train, x_cepha_valid, x_cepha_test, y_cepha_train, y_cepha_valid, y_cepha_test, 'cepha')

# %%
# train_test_peni = np.load('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/numpy/peni/train_test_valid.npz')
# train_test_macro = np.load('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/numpy/macro/train_test_valid.npz')
# train_test_glyco = np.load('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/numpy/glyco/train_test_valid.npz')
# train_test_fluoro = np.load('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/numpy/fluoro/train_test_valid.npz')
# train_test_cepha = np.load('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/numpy/cepha/train_test_valid.npz')

# %%
def loaded_data(path):
    train_test_split = np.load(path)
    train_x = train_test_split['train_x']
    test_x = train_test_split['test_x']
    valid_x = train_test_split['valid_x']
    train_y = train_test_split['train_y']
    test_y = train_test_split['test_y']
    valid_y = train_test_split['valid_y']
    print('train_x shape: {}'.format(train_x.shape), 'valid_x shape: {}'.format(valid_x.shape),
          "test_x shape: {}".format(test_x.shape), "train_y shape: {}".format(train_y.shape),
          "valid_y shape: {}".format(valid_y.shape),
          "test_y shape: {}".format(test_y.shape))
    print("------------------------------------------------------------------------------")
    return train_x, valid_x, test_x, train_y, valid_y, test_y

# %%
x_peni_train, x_peni_valid, x_peni_test, y_peni_train, y_peni_valid, y_peni_test = loaded_data('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/numpy/peni/train_test_valid.npz')
x_macro_train, x_macro_valid, x_macro_test, y_macro_train, y_macro_valid, y_macro_test = loaded_data('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/numpy/macro/train_test_valid.npz')
x_glyco_train, x_glyco_valid, x_glyco_test, y_glyco_train, y_glyco_valid,  y_glyco_test = loaded_data('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/numpy/glyco/train_test_valid.npz')
x_fluoro_train, x_fluoro_valid, x_fluoro_test, y_fluoro_train, y_fluoro_valid, y_fluoro_test = loaded_data('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/numpy/fluoro/train_test_valid.npz')
x_cepha_train, x_cepha_valid, x_cepha_test, y_cepha_train, y_cepha_valid, y_cepha_test = loaded_data('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/numpy/cepha/train_test_valid.npz')
# Out:
# train_x shape: (5460, 13, 22) valid_x shape: (304, 13, 22) test_x shape: (303, 13, 22) train_y shape: (5460, 2) valid_y shape: (304, 2) test_y shape: (303, 2)
# ------------------------------------------------------------------------------
# train_x shape: (1723, 13, 22) valid_x shape: (96, 13, 22) test_x shape: (96, 13, 22) train_y shape: (1723, 2) valid_y shape: (96, 2) test_y shape: (96, 2)
# ------------------------------------------------------------------------------
# train_x shape: (10584, 13, 22) valid_x shape: (589, 13, 22) test_x shape: (588, 13, 22) train_y shape: (10584, 2) valid_y shape: (589, 2) test_y shape: (588, 2)
# ------------------------------------------------------------------------------
# train_x shape: (3284, 13, 22) valid_x shape: (183, 13, 22) test_x shape: (182, 13, 22) train_y shape: (3284, 2) valid_y shape: (183, 2) test_y shape: (182, 2)
# ------------------------------------------------------------------------------
# train_x shape: (9862, 13, 22) valid_x shape: (548, 13, 22) test_x shape: (548, 13, 22) train_y shape: (9862, 2) valid_y shape: (548, 2) test_y shape: (548, 2)
# ------------------------------------------------------------------------------

# %%
def model_gru(model_input):
    model_gru = GRU(50, activation='relu')(model_input)
    model_gru = Dense(10, activation='relu')(model_gru)
    output = Dense(2, activation='softmax')(model_gru)
    model = Model(model_input, output)
    print(model.summary())
    return model

# %%
model_input = Input(shape=(x_cepha_train.shape[1], x_cepha_train.shape[2]))
model = model_gru(model_input)
model.compile(Adam(lr=1e-3), loss='categorical_crossentropy', metrics='AUC')
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 13, 22)]          0
# _________________________________________________________________
# gru_1 (GRU)                  (None, 50)                11100
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                510
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 22
# =================================================================
# Total params: 11,632
# Trainable params: 11,632
# Non-trainable params: 0
# _________________________________________________________________
# None
# /home/je_hong/.local/lib/python3.6/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
callbacks = [ReduceLROnPlateau(monitor='val_loss', patience=4, verbose=1, factor=0.6),
             EarlyStopping(monitor='val_loss', patience=20),
             ModelCheckpoint(filepath=new_path+'model/{} model'.format("cepha"), monitor='val_loss', save_best_only=True)]

# %%
history = model.fit(x_cepha_train, y_cepha_train, 
          epochs = 40, 
          batch_size = 16, 
          validation_data=(x_cepha_valid,  y_cepha_valid), 
          verbose=1,callbacks=callbacks)
# Out:
# Epoch 1/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.4597 - auc: 0.9250 - val_loss: 0.3615 - val_auc: 0.9108
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/cepha model/assets
# Epoch 2/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.4504 - auc: 0.9274 - val_loss: 0.3592 - val_auc: 0.9124
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/cepha model/assets
# Epoch 3/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.4326 - auc: 0.9290 - val_loss: 0.3579 - val_auc: 0.9128
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/cepha model/assets
# Epoch 4/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3381 - auc: 0.9299 - val_loss: 0.3574 - val_auc: 0.9133
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/cepha model/assets
# Epoch 5/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3316 - auc: 0.9305 - val_loss: 0.3567 - val_auc: 0.9142
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/cepha model/assets
# Epoch 6/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3307 - auc: 0.9309 - val_loss: 0.3561 - val_auc: 0.9148
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/cepha model/assets
# Epoch 7/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3299 - auc: 0.9313 - val_loss: 0.3556 - val_auc: 0.9151
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/cepha model/assets
# Epoch 8/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3293 - auc: 0.9315 - val_loss: 0.3552 - val_auc: 0.9151
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/cepha model/assets
# Epoch 9/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3287 - auc: 0.9317 - val_loss: 0.3549 - val_auc: 0.9155
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/cepha model/assets
# Epoch 10/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3283 - auc: 0.9320 - val_loss: 0.3548 - val_auc: 0.9156
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/cepha model/assets
# Epoch 11/40
# 617/617 [==============================] - 6s 10ms/step - loss: 0.3280 - auc: 0.9320 - val_loss: 0.3547 - val_auc: 0.9166
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/cepha model/assets
# Epoch 12/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3277 - auc: 0.9321 - val_loss: 0.3547 - val_auc: 0.9167
# Epoch 13/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3274 - auc: 0.9323 - val_loss: 0.3549 - val_auc: 0.9168
# Epoch 14/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3273 - auc: 0.9324 - val_loss: 0.3550 - val_auc: 0.9168
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 2.1767824364360423e-06.
# Epoch 15/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3271 - auc: 0.9324 - val_loss: 0.3551 - val_auc: 0.9167
# Epoch 16/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3270 - auc: 0.9324 - val_loss: 0.3551 - val_auc: 0.9168
# Epoch 17/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3269 - auc: 0.9324 - val_loss: 0.3552 - val_auc: 0.9168
# Epoch 18/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3268 - auc: 0.9323 - val_loss: 0.3553 - val_auc: 0.9169
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.3060694072919432e-06.
# Epoch 19/40
# 617/617 [==============================] - 6s 10ms/step - loss: 0.3267 - auc: 0.9325 - val_loss: 0.3554 - val_auc: 0.9169
# Epoch 20/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3267 - auc: 0.9324 - val_loss: 0.3554 - val_auc: 0.9168
# Epoch 21/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3267 - auc: 0.9325 - val_loss: 0.3555 - val_auc: 0.9167
# Epoch 22/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3266 - auc: 0.9325 - val_loss: 0.3555 - val_auc: 0.9169
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 7.836416443751659e-07.
# Epoch 23/40
# 617/617 [==============================] - 6s 10ms/step - loss: 0.3266 - auc: 0.9325 - val_loss: 0.3556 - val_auc: 0.9168
# Epoch 24/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3266 - auc: 0.9325 - val_loss: 0.3556 - val_auc: 0.9168
# Epoch 25/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3265 - auc: 0.9325 - val_loss: 0.3557 - val_auc: 0.9169
# Epoch 26/40
# 617/617 [==============================] - 6s 11ms/step - loss: 0.3265 - auc: 0.9325 - val_loss: 0.3557 - val_auc: 0.9168
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 4.701850002675201e-07.
# Epoch 27/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3265 - auc: 0.9325 - val_loss: 0.3557 - val_auc: 0.9166
# Epoch 28/40
# 617/617 [==============================] - 6s 10ms/step - loss: 0.3265 - auc: 0.9325 - val_loss: 0.3558 - val_auc: 0.9166
# Epoch 29/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3265 - auc: 0.9325 - val_loss: 0.3558 - val_auc: 0.9166
# Epoch 30/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3265 - auc: 0.9325 - val_loss: 0.3558 - val_auc: 0.9166
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 2.8211100016051206e-07.
# Epoch 31/40
# 617/617 [==============================] - 7s 11ms/step - loss: 0.3264 - auc: 0.9325 - val_loss: 0.3558 - val_auc: 0.9166

# %%
model.save('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/cepha model/cepha_best_model.h5')
model = load_model('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/cepha model/cepha_best_model.h5')
predictions = model.predict(x_cepha_test)
y_true = np.argmax(y_cepha_test, axis=1)
y_pred = np.argmax(predictions, axis=1)
print(predictions.shape, y_cepha_test.shape)
fpr = dict()
tpr = dict()
roc_auc = dict()
target_names = ['normal', 'diabetes']

print(classification_report(y_true, y_pred, target_names=target_names, digits=4))
print(1 - roc_auc_score(y_true, predictions[:, 0]))
print(roc_auc_score(y_true, predictions[:, 1]))
skplt.metrics.plot_roc(
    y_true, predictions, title="Test Set", figsize=(10, 10), text_fontsize=15, title_fontsize=30,
)
print(y_true.shape)
# Out:
# (548, 2) (548, 2)
#               precision    recall  f1-score   support
#
#       normal     0.8726    0.9787    0.9226       469
#     diabetes     0.5455    0.1519    0.2376        79
#
#     accuracy                         0.8595       548
#    macro avg     0.7090    0.5653    0.5801       548
# weighted avg     0.8255    0.8595    0.8239       548
#
# 0.7469434023373189
# 0.7469434023373188
# (548,)

# %% [markdown]
# ## peni

# %%
callbacks = [ReduceLROnPlateau(monitor='val_loss', patience=4, verbose=1, factor=0.6),
             EarlyStopping(monitor='val_loss', patience=20),
             ModelCheckpoint(filepath=new_path+'model/{} model'.format("peni"), monitor='val_loss', save_best_only=True)]

# %%
history = model.fit(x_peni_train, y_peni_train, 
          epochs = 40, 
          batch_size = 16, 
          validation_data=(x_peni_valid,  y_peni_valid), 
          verbose=1,callbacks=callbacks)
# Out:
# Epoch 1/40
# 342/342 [==============================] - 7s 17ms/step - loss: 0.4475 - auc: 0.8716 - val_loss: 0.7469 - val_auc: 0.8512
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 2/40
# 342/342 [==============================] - 4s 13ms/step - loss: 0.4473 - auc: 0.8716 - val_loss: 0.7466 - val_auc: 0.8514
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 3/40
# 342/342 [==============================] - 5s 14ms/step - loss: 0.4471 - auc: 0.8719 - val_loss: 0.7464 - val_auc: 0.8514
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 4/40
# 342/342 [==============================] - 4s 12ms/step - loss: 0.4469 - auc: 0.8720 - val_loss: 0.7461 - val_auc: 0.8513
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 5/40
# 342/342 [==============================] - 5s 14ms/step - loss: 0.4468 - auc: 0.8721 - val_loss: 0.7459 - val_auc: 0.8512
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 6/40
# 342/342 [==============================] - 5s 15ms/step - loss: 0.4466 - auc: 0.8722 - val_loss: 0.7457 - val_auc: 0.8511
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 7/40
# 342/342 [==============================] - 5s 13ms/step - loss: 0.4465 - auc: 0.8723 - val_loss: 0.7455 - val_auc: 0.8512
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 8/40
# 342/342 [==============================] - 4s 13ms/step - loss: 0.4463 - auc: 0.8723 - val_loss: 0.7453 - val_auc: 0.8513
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 9/40
# 342/342 [==============================] - 5s 13ms/step - loss: 0.4462 - auc: 0.8723 - val_loss: 0.7451 - val_auc: 0.8511
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 10/40
# 342/342 [==============================] - 5s 14ms/step - loss: 0.4461 - auc: 0.8724 - val_loss: 0.7450 - val_auc: 0.8510
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 11/40
# 342/342 [==============================] - 5s 14ms/step - loss: 0.4460 - auc: 0.8724 - val_loss: 0.7448 - val_auc: 0.8509
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 12/40
# 342/342 [==============================] - 5s 14ms/step - loss: 0.4458 - auc: 0.8724 - val_loss: 0.7446 - val_auc: 0.8511
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 13/40
# 342/342 [==============================] - 5s 13ms/step - loss: 0.4457 - auc: 0.8725 - val_loss: 0.7445 - val_auc: 0.8513
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 14/40
# 342/342 [==============================] - 5s 16ms/step - loss: 0.4456 - auc: 0.8727 - val_loss: 0.7443 - val_auc: 0.8513
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 15/40
# 342/342 [==============================] - 4s 13ms/step - loss: 0.4455 - auc: 0.8728 - val_loss: 0.7441 - val_auc: 0.8513
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 16/40
# 342/342 [==============================] - 5s 15ms/step - loss: 0.4454 - auc: 0.8729 - val_loss: 0.7440 - val_auc: 0.8513
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 17/40
# 342/342 [==============================] - 4s 13ms/step - loss: 0.4453 - auc: 0.8729 - val_loss: 0.7438 - val_auc: 0.8514
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 18/40
# 342/342 [==============================] - 5s 14ms/step - loss: 0.4452 - auc: 0.8729 - val_loss: 0.7437 - val_auc: 0.8514
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 19/40
# 342/342 [==============================] - 4s 13ms/step - loss: 0.4451 - auc: 0.8730 - val_loss: 0.7435 - val_auc: 0.8515
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 20/40
# 342/342 [==============================] - 5s 15ms/step - loss: 0.4450 - auc: 0.8730 - val_loss: 0.7434 - val_auc: 0.8517
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 21/40
# 342/342 [==============================] - 4s 13ms/step - loss: 0.4449 - auc: 0.8730 - val_loss: 0.7432 - val_auc: 0.8520
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 22/40
# 342/342 [==============================] - 5s 14ms/step - loss: 0.4447 - auc: 0.8731 - val_loss: 0.7431 - val_auc: 0.8521
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 23/40
# 342/342 [==============================] - 5s 15ms/step - loss: 0.4446 - auc: 0.8732 - val_loss: 0.7429 - val_auc: 0.8521
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 24/40
# 342/342 [==============================] - 5s 14ms/step - loss: 0.4445 - auc: 0.8733 - val_loss: 0.7428 - val_auc: 0.8523
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 25/40
# 342/342 [==============================] - 4s 12ms/step - loss: 0.4444 - auc: 0.8733 - val_loss: 0.7426 - val_auc: 0.8522
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 26/40
# 342/342 [==============================] - 6s 17ms/step - loss: 0.4443 - auc: 0.8734 - val_loss: 0.7425 - val_auc: 0.8524
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 27/40
# 342/342 [==============================] - 4s 12ms/step - loss: 0.4443 - auc: 0.8734 - val_loss: 0.7424 - val_auc: 0.8524
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 28/40
# 342/342 [==============================] - 5s 14ms/step - loss: 0.4442 - auc: 0.8734 - val_loss: 0.7422 - val_auc: 0.8520
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 29/40
# 342/342 [==============================] - 5s 14ms/step - loss: 0.4441 - auc: 0.8735 - val_loss: 0.7421 - val_auc: 0.8520
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 30/40
# 342/342 [==============================] - 5s 14ms/step - loss: 0.4440 - auc: 0.8734 - val_loss: 0.7419 - val_auc: 0.8522
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 31/40
# 342/342 [==============================] - 4s 13ms/step - loss: 0.4439 - auc: 0.8737 - val_loss: 0.7418 - val_auc: 0.8522
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 32/40
# 342/342 [==============================] - 4s 13ms/step - loss: 0.4438 - auc: 0.8738 - val_loss: 0.7417 - val_auc: 0.8522
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 33/40
# 342/342 [==============================] - 5s 14ms/step - loss: 0.4437 - auc: 0.8738 - val_loss: 0.7416 - val_auc: 0.8522
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 34/40
# 342/342 [==============================] - 5s 15ms/step - loss: 0.4436 - auc: 0.8738 - val_loss: 0.7414 - val_auc: 0.8522
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 35/40
# 342/342 [==============================] - 4s 13ms/step - loss: 0.4435 - auc: 0.8738 - val_loss: 0.7413 - val_auc: 0.8526
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 36/40
# 342/342 [==============================] - 4s 12ms/step - loss: 0.4435 - auc: 0.8739 - val_loss: 0.7412 - val_auc: 0.8525
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 37/40
# 342/342 [==============================] - 5s 13ms/step - loss: 0.4434 - auc: 0.8739 - val_loss: 0.7411 - val_auc: 0.8525
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 38/40
# 342/342 [==============================] - 4s 13ms/step - loss: 0.4433 - auc: 0.8740 - val_loss: 0.7410 - val_auc: 0.8525
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 39/40
# 342/342 [==============================] - 5s 15ms/step - loss: 0.4432 - auc: 0.8740 - val_loss: 0.7409 - val_auc: 0.8524
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets
# Epoch 40/40
# 342/342 [==============================] - 4s 12ms/step - loss: 0.4432 - auc: 0.8740 - val_loss: 0.7408 - val_auc: 0.8524
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/assets

# %%
model.save('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/peni_best_model.h5')
model = load_model('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/peni model/peni_best_model.h5')
predictions = model.predict(x_peni_test)
y_true = np.argmax(y_peni_test, axis=1)
y_pred = np.argmax(predictions, axis=1)
print(predictions.shape, y_peni_test.shape)
fpr = dict()
tpr = dict()
roc_auc = dict()
target_names = ['normal', 'diabetes']

print(classification_report(y_true, y_pred, target_names=target_names, digits=4))
print(1 - roc_auc_score(y_true, predictions[:, 0]))
print(roc_auc_score(y_true, predictions[:, 1]))
skplt.metrics.plot_roc(
    y_true, predictions, title="Test Set", figsize=(10, 10), text_fontsize=15, title_fontsize=30,
)
print(y_true.shape)
# Out:
# (303, 2) (303, 2)
#               precision    recall  f1-score   support
#
#       normal     0.8448    0.9669    0.9017       242
#     diabetes     0.6923    0.2951    0.4138        61
#
#     accuracy                         0.8317       303
#    macro avg     0.7685    0.6310    0.6578       303
# weighted avg     0.8141    0.8317    0.8035       303
#
# 0.7039019103102561
# 0.7039019103102561
# (303,)

# %% [markdown]
# ## macro

# %%
callbacks = [ReduceLROnPlateau(monitor='val_loss', patience=4, verbose=1, factor=0.6),
             EarlyStopping(monitor='val_loss', patience=20),
             ModelCheckpoint(filepath=new_path+'model/{} model'.format("macro"), monitor='val_loss', save_best_only=True)]

# %%
history = model.fit(x_macro_train, y_macro_train, 
          epochs = 40, 
          batch_size = 16, 
          validation_data=(x_macro_valid,  y_macro_valid), 
          verbose=1,callbacks=callbacks)
# Out:
# Epoch 1/40
# 108/108 [==============================] - 4s 19ms/step - loss: 0.4083 - auc: 0.8893 - val_loss: 0.4151 - val_auc: 0.8750
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 2/40
# 108/108 [==============================] - 1s 10ms/step - loss: 0.4082 - auc: 0.8894 - val_loss: 0.4150 - val_auc: 0.8750
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 3/40
# 108/108 [==============================] - 1s 10ms/step - loss: 0.4082 - auc: 0.8894 - val_loss: 0.4150 - val_auc: 0.8750
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 4/40
# 108/108 [==============================] - 1s 14ms/step - loss: 0.4081 - auc: 0.8894 - val_loss: 0.4149 - val_auc: 0.8752
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 5/40
# 108/108 [==============================] - 2s 15ms/step - loss: 0.4081 - auc: 0.8895 - val_loss: 0.4149 - val_auc: 0.8757
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 6/40
# 108/108 [==============================] - 1s 12ms/step - loss: 0.4080 - auc: 0.8895 - val_loss: 0.4148 - val_auc: 0.8758
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 7/40
# 108/108 [==============================] - 1s 11ms/step - loss: 0.4080 - auc: 0.8895 - val_loss: 0.4147 - val_auc: 0.8759
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 8/40
# 108/108 [==============================] - 1s 11ms/step - loss: 0.4079 - auc: 0.8895 - val_loss: 0.4146 - val_auc: 0.8762
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 9/40
# 108/108 [==============================] - 1s 12ms/step - loss: 0.4079 - auc: 0.8896 - val_loss: 0.4146 - val_auc: 0.8761
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 10/40
# 108/108 [==============================] - 1s 12ms/step - loss: 0.4079 - auc: 0.8895 - val_loss: 0.4145 - val_auc: 0.8761
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 11/40
# 108/108 [==============================] - 1s 11ms/step - loss: 0.4078 - auc: 0.8895 - val_loss: 0.4145 - val_auc: 0.8761
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 12/40
# 108/108 [==============================] - 1s 11ms/step - loss: 0.4078 - auc: 0.8895 - val_loss: 0.4144 - val_auc: 0.8761
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 13/40
# 108/108 [==============================] - 1s 12ms/step - loss: 0.4077 - auc: 0.8894 - val_loss: 0.4143 - val_auc: 0.8761
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 14/40
# 108/108 [==============================] - 2s 14ms/step - loss: 0.4077 - auc: 0.8894 - val_loss: 0.4143 - val_auc: 0.8759
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 15/40
# 108/108 [==============================] - 1s 12ms/step - loss: 0.4077 - auc: 0.8894 - val_loss: 0.4142 - val_auc: 0.8760
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 16/40
# 108/108 [==============================] - 1s 10ms/step - loss: 0.4076 - auc: 0.8894 - val_loss: 0.4142 - val_auc: 0.8760
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 17/40
# 108/108 [==============================] - 1s 12ms/step - loss: 0.4076 - auc: 0.8894 - val_loss: 0.4141 - val_auc: 0.8762
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 18/40
# 108/108 [==============================] - 1s 12ms/step - loss: 0.4075 - auc: 0.8894 - val_loss: 0.4141 - val_auc: 0.8763
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 19/40
# 108/108 [==============================] - 2s 15ms/step - loss: 0.4075 - auc: 0.8894 - val_loss: 0.4140 - val_auc: 0.8766
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 20/40
# 108/108 [==============================] - 1s 10ms/step - loss: 0.4075 - auc: 0.8895 - val_loss: 0.4139 - val_auc: 0.8766
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 21/40
# 108/108 [==============================] - 1s 9ms/step - loss: 0.4074 - auc: 0.8895 - val_loss: 0.4139 - val_auc: 0.8762
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 22/40
# 108/108 [==============================] - 2s 16ms/step - loss: 0.4074 - auc: 0.8895 - val_loss: 0.4138 - val_auc: 0.8752
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 23/40
# 108/108 [==============================] - 1s 12ms/step - loss: 0.4073 - auc: 0.8895 - val_loss: 0.4138 - val_auc: 0.8753
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 24/40
# 108/108 [==============================] - 1s 11ms/step - loss: 0.4073 - auc: 0.8895 - val_loss: 0.4137 - val_auc: 0.8753
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 25/40
# 108/108 [==============================] - 1s 13ms/step - loss: 0.4073 - auc: 0.8896 - val_loss: 0.4137 - val_auc: 0.8758
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 26/40
# 108/108 [==============================] - 1s 11ms/step - loss: 0.4072 - auc: 0.8896 - val_loss: 0.4136 - val_auc: 0.8753
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 27/40
# 108/108 [==============================] - 1s 10ms/step - loss: 0.4072 - auc: 0.8896 - val_loss: 0.4135 - val_auc: 0.8753
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 28/40
# 108/108 [==============================] - 1s 11ms/step - loss: 0.4072 - auc: 0.8896 - val_loss: 0.4135 - val_auc: 0.8754
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 29/40
# 108/108 [==============================] - 1s 11ms/step - loss: 0.4071 - auc: 0.8896 - val_loss: 0.4134 - val_auc: 0.8757
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 30/40
# 108/108 [==============================] - 1s 10ms/step - loss: 0.4071 - auc: 0.8897 - val_loss: 0.4134 - val_auc: 0.8757
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 31/40
# 108/108 [==============================] - 1s 11ms/step - loss: 0.4070 - auc: 0.8897 - val_loss: 0.4133 - val_auc: 0.8757
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 32/40
# 108/108 [==============================] - 1s 10ms/step - loss: 0.4070 - auc: 0.8897 - val_loss: 0.4133 - val_auc: 0.8754
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 33/40
# 108/108 [==============================] - 1s 12ms/step - loss: 0.4070 - auc: 0.8896 - val_loss: 0.4132 - val_auc: 0.8754
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 34/40
# 108/108 [==============================] - 1s 10ms/step - loss: 0.4069 - auc: 0.8897 - val_loss: 0.4132 - val_auc: 0.8751
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 35/40
# 108/108 [==============================] - 1s 11ms/step - loss: 0.4069 - auc: 0.8897 - val_loss: 0.4131 - val_auc: 0.8752
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 36/40
# 108/108 [==============================] - 1s 14ms/step - loss: 0.4069 - auc: 0.8897 - val_loss: 0.4131 - val_auc: 0.8752
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 37/40
# 108/108 [==============================] - 1s 12ms/step - loss: 0.4068 - auc: 0.8898 - val_loss: 0.4130 - val_auc: 0.8754
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 38/40
# 108/108 [==============================] - 1s 11ms/step - loss: 0.4068 - auc: 0.8897 - val_loss: 0.4130 - val_auc: 0.8757
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 39/40
# 108/108 [==============================] - 1s 12ms/step - loss: 0.4068 - auc: 0.8898 - val_loss: 0.4129 - val_auc: 0.8757
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets
# Epoch 40/40
# 108/108 [==============================] - 1s 13ms/step - loss: 0.4067 - auc: 0.8898 - val_loss: 0.4129 - val_auc: 0.8761
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/assets

# %%
model.save('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/macro_best_model.h5')
model = load_model('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/macro model/macro_best_model.h5')
predictions = model.predict(x_macro_test)
y_true = np.argmax(y_macro_test, axis=1)
y_pred = np.argmax(predictions, axis=1)
print(predictions.shape, y_macro_test.shape)
fpr = dict()
tpr = dict()
roc_auc = dict()
target_names = ['normal', 'diabetes']

print(classification_report(y_true, y_pred, target_names=target_names, digits=4))
print(1 - roc_auc_score(y_true, predictions[:, 0]))
print(roc_auc_score(y_true, predictions[:, 1]))
skplt.metrics.plot_roc(
    y_true, predictions, title="Test Set", figsize=(10, 10), text_fontsize=15, title_fontsize=30,
)
print(y_true.shape)
# Out:
# (96, 2) (96, 2)
#               precision    recall  f1-score   support
#
#       normal     0.8876    0.9753    0.9294        81
#     diabetes     0.7143    0.3333    0.4545        15
#
#     accuracy                         0.8750        96
#    macro avg     0.8010    0.6543    0.6920        96
# weighted avg     0.8606    0.8750    0.8552        96
#
# 0.7547325102880659
# 0.7547325102880658
# (96,)

# %% [markdown]
# ## glyco

# %%
callbacks = [ReduceLROnPlateau(monitor='val_loss', patience=4, verbose=1, factor=0.6),
             EarlyStopping(monitor='val_loss', patience=20),
             ModelCheckpoint(filepath=new_path+'model/{} model'.format("glyco"), monitor='val_loss', save_best_only=True)]

# %%
history = model.fit(x_glyco_train, y_glyco_train, 
          epochs = 40, 
          batch_size = 16, 
          validation_data=(x_glyco_valid, y_glyco_valid), 
          verbose=1, callbacks=callbacks)
# Out:
# Epoch 1/40
# 662/662 [==============================] - 11s 12ms/step - loss: 0.4564 - auc: 0.8642 - val_loss: 0.4352 - val_auc: 0.8796
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 2/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4561 - auc: 0.8644 - val_loss: 0.4350 - val_auc: 0.8795
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 3/40
# 662/662 [==============================] - 7s 10ms/step - loss: 0.4558 - auc: 0.8646 - val_loss: 0.4349 - val_auc: 0.8796
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 4/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4556 - auc: 0.8645 - val_loss: 0.4347 - val_auc: 0.8796
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 5/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4553 - auc: 0.8645 - val_loss: 0.4346 - val_auc: 0.8799
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 6/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4551 - auc: 0.8646 - val_loss: 0.4345 - val_auc: 0.8800
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 7/40
# 662/662 [==============================] - 8s 11ms/step - loss: 0.4550 - auc: 0.8648 - val_loss: 0.4344 - val_auc: 0.8796
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 8/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4548 - auc: 0.8647 - val_loss: 0.4343 - val_auc: 0.8794
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 9/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4546 - auc: 0.8648 - val_loss: 0.4342 - val_auc: 0.8794
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 10/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4545 - auc: 0.8647 - val_loss: 0.4341 - val_auc: 0.8796
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 11/40
# 662/662 [==============================] - 8s 11ms/step - loss: 0.4543 - auc: 0.8648 - val_loss: 0.4341 - val_auc: 0.8798
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 12/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4542 - auc: 0.8650 - val_loss: 0.4340 - val_auc: 0.8797
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 13/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4541 - auc: 0.8650 - val_loss: 0.4339 - val_auc: 0.8798
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 14/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4540 - auc: 0.8651 - val_loss: 0.4339 - val_auc: 0.8797
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 15/40
# 662/662 [==============================] - 8s 12ms/step - loss: 0.4538 - auc: 0.8650 - val_loss: 0.4338 - val_auc: 0.8796
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 16/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4537 - auc: 0.8650 - val_loss: 0.4338 - val_auc: 0.8795
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 17/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4536 - auc: 0.8651 - val_loss: 0.4337 - val_auc: 0.8796
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 18/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4536 - auc: 0.8652 - val_loss: 0.4337 - val_auc: 0.8798
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 19/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4535 - auc: 0.8652 - val_loss: 0.4336 - val_auc: 0.8798
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 20/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4534 - auc: 0.8652 - val_loss: 0.4336 - val_auc: 0.8798
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 21/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4533 - auc: 0.8652 - val_loss: 0.4336 - val_auc: 0.8799
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 22/40
# 662/662 [==============================] - 8s 12ms/step - loss: 0.4532 - auc: 0.8652 - val_loss: 0.4336 - val_auc: 0.8798
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 23/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4532 - auc: 0.8653 - val_loss: 0.4335 - val_auc: 0.8801
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 24/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4531 - auc: 0.8654 - val_loss: 0.4335 - val_auc: 0.8801
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 25/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4530 - auc: 0.8654 - val_loss: 0.4335 - val_auc: 0.8799
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 26/40
# 662/662 [==============================] - 8s 11ms/step - loss: 0.4530 - auc: 0.8654 - val_loss: 0.4335 - val_auc: 0.8797
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 27/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4529 - auc: 0.8654 - val_loss: 0.4335 - val_auc: 0.8798
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 28/40
# 662/662 [==============================] - 8s 11ms/step - loss: 0.4529 - auc: 0.8654 - val_loss: 0.4334 - val_auc: 0.8797
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.6926659327509696e-07.
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 29/40
# 662/662 [==============================] - 8s 11ms/step - loss: 0.4528 - auc: 0.8655 - val_loss: 0.4334 - val_auc: 0.8797
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 30/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4528 - auc: 0.8655 - val_loss: 0.4334 - val_auc: 0.8798
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 31/40
# 662/662 [==============================] - 8s 11ms/step - loss: 0.4528 - auc: 0.8655 - val_loss: 0.4334 - val_auc: 0.8797
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 32/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4528 - auc: 0.8657 - val_loss: 0.4334 - val_auc: 0.8797
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1.0155995937566331e-07.
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 33/40
# 662/662 [==============================] - 8s 11ms/step - loss: 0.4527 - auc: 0.8657 - val_loss: 0.4334 - val_auc: 0.8797
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 34/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4527 - auc: 0.8657 - val_loss: 0.4334 - val_auc: 0.8798
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 35/40
# 662/662 [==============================] - 8s 11ms/step - loss: 0.4527 - auc: 0.8657 - val_loss: 0.4334 - val_auc: 0.8798
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 36/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4527 - auc: 0.8656 - val_loss: 0.4334 - val_auc: 0.8798
#
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 6.093597733070056e-08.
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 37/40
# 662/662 [==============================] - 7s 10ms/step - loss: 0.4527 - auc: 0.8657 - val_loss: 0.4334 - val_auc: 0.8798
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 38/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4527 - auc: 0.8656 - val_loss: 0.4334 - val_auc: 0.8798
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 39/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4527 - auc: 0.8657 - val_loss: 0.4334 - val_auc: 0.8798
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets
# Epoch 40/40
# 662/662 [==============================] - 7s 11ms/step - loss: 0.4527 - auc: 0.8656 - val_loss: 0.4334 - val_auc: 0.8800
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 3.656158469311776e-08.
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/assets

# %%
model.save('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/glyco_best_model.h5')
model = load_model('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/glyco model/glyco_best_model.h5')
predictions = model.predict(x_glyco_test)
y_true = np.argmax(y_glyco_test, axis=1)
y_pred = np.argmax(predictions, axis=1)
print(predictions.shape, y_glyco_test.shape)
fpr = dict()
tpr = dict()
roc_auc = dict()
target_names = ['normal', 'diabetes']

print(classification_report(y_true, y_pred, target_names=target_names, digits=4))
print(1 - roc_auc_score(y_true, predictions[:, 0]))
print(roc_auc_score(y_true, predictions[:, 1]))
skplt.metrics.plot_roc(
    y_true, predictions, title="Test Set", figsize=(10, 10), text_fontsize=15, title_fontsize=30,
)
print(y_true.shape)
# Out:
# (588, 2) (588, 2)
#               precision    recall  f1-score   support
#
#       normal     0.8232    0.9914    0.8995       465
#     diabetes     0.8571    0.1951    0.3179       123
#
#     accuracy                         0.8248       588
#    macro avg     0.8402    0.5933    0.6087       588
# weighted avg     0.8303    0.8248    0.7778       588
#
# 0.7171431069149401
# 0.7171431069149401
# (588,)

# %% [markdown]
# ## fluoro

# %%
callbacks = [ReduceLROnPlateau(monitor='val_loss', patience=4, verbose=1, factor=0.6),
             EarlyStopping(monitor='val_loss', patience=20),
             ModelCheckpoint(filepath=new_path+'model/{} model'.format("fluoro"), monitor='val_loss', save_best_only=True)]

# %%
history = model.fit(x_fluoro_train, y_fluoro_train, 
          epochs = 40, 
          batch_size = 16, 
          validation_data=(x_fluoro_valid, y_fluoro_valid), 
          verbose=1,callbacks=callbacks)
# Out:
# Epoch 1/40
# 206/206 [==============================] - 5s 18ms/step - loss: 0.3804 - auc: 0.9066 - val_loss: 0.3687 - val_auc: 0.9051
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 2/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3804 - auc: 0.9066 - val_loss: 0.3687 - val_auc: 0.9051
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 3/40
# 206/206 [==============================] - 2s 10ms/step - loss: 0.3804 - auc: 0.9066 - val_loss: 0.3687 - val_auc: 0.9052
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 4/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3804 - auc: 0.9066 - val_loss: 0.3687 - val_auc: 0.9052
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 5/40
# 206/206 [==============================] - 2s 10ms/step - loss: 0.3804 - auc: 0.9065 - val_loss: 0.3686 - val_auc: 0.9052
#
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 2.1936950389545017e-08.
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 6/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3804 - auc: 0.9066 - val_loss: 0.3686 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 7/40
# 206/206 [==============================] - 2s 12ms/step - loss: 0.3803 - auc: 0.9066 - val_loss: 0.3686 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 8/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3803 - auc: 0.9066 - val_loss: 0.3686 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 9/40
# 206/206 [==============================] - 2s 10ms/step - loss: 0.3803 - auc: 0.9066 - val_loss: 0.3686 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 10/40
# 206/206 [==============================] - 2s 10ms/step - loss: 0.3803 - auc: 0.9066 - val_loss: 0.3686 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 11/40
# 206/206 [==============================] - 2s 12ms/step - loss: 0.3803 - auc: 0.9066 - val_loss: 0.3686 - val_auc: 0.9052
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 12/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3803 - auc: 0.9066 - val_loss: 0.3686 - val_auc: 0.9052
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 13/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3803 - auc: 0.9066 - val_loss: 0.3686 - val_auc: 0.9052
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.316217002056419e-08.
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 14/40
# 206/206 [==============================] - 2s 10ms/step - loss: 0.3803 - auc: 0.9066 - val_loss: 0.3686 - val_auc: 0.9052
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 15/40
# 206/206 [==============================] - 2s 12ms/step - loss: 0.3803 - auc: 0.9066 - val_loss: 0.3686 - val_auc: 0.9052
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 16/40
# 206/206 [==============================] - 2s 12ms/step - loss: 0.3803 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9052
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 17/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3803 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 7.897302012338514e-09.
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 18/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 19/40
# 206/206 [==============================] - 2s 12ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 20/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 21/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 4.738381420565929e-09.
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 22/40
# 206/206 [==============================] - 2s 12ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 23/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 24/40
# 206/206 [==============================] - 2s 10ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 25/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 2.843028745758147e-09.
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 26/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 27/40
# 206/206 [==============================] - 2s 12ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 28/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 29/40
# 206/206 [==============================] - 2s 12ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.7058172208095356e-09.
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 30/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 31/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 32/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 33/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.023490359131074e-09.
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 34/40
# 206/206 [==============================] - 2s 10ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
# Epoch 35/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
# Epoch 36/40
# 206/206 [==============================] - 2s 10ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 37/40
# 206/206 [==============================] - 2s 11ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 6.14094242123997e-10.
# INFO:tensorflow:Assets written to: /data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/assets
# Epoch 38/40
# 206/206 [==============================] - 2s 12ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
# Epoch 39/40
# 206/206 [==============================] - 3s 12ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053
# Epoch 40/40
# 206/206 [==============================] - 2s 10ms/step - loss: 0.3802 - auc: 0.9066 - val_loss: 0.3685 - val_auc: 0.9053

# %%
model.save('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/fluoro_best_model.h5')
model = load_model('/data2/je_hong/kaist/kaist/physionet.org/files/mimiciv/2.0/mimic_rev/model/fluoro model/fluoro_best_model.h5')
predictions = model.predict(x_fluoro_test)
y_true = np.argmax(y_fluoro_test, axis=1)
y_pred = np.argmax(predictions, axis=1)
print(predictions.shape, y_fluoro_test.shape)
fpr = dict()
tpr = dict()
roc_auc = dict()
target_names = ['normal', 'diabetes']

print(classification_report(y_true, y_pred, target_names=target_names, digits=4))
print(1 - roc_auc_score(y_true, predictions[:, 0]))
print(roc_auc_score(y_true, predictions[:, 1]))
skplt.metrics.plot_roc(
    y_true, predictions, title="Test Set", figsize=(10, 10), text_fontsize=15, title_fontsize=30,
)
print(y_true.shape)
# Out:
# (182, 2) (182, 2)
#               precision    recall  f1-score   support
#
#       normal     0.8596    0.9871    0.9189       155
#     diabetes     0.5000    0.0741    0.1290        27
#
#     accuracy                         0.8516       182
#    macro avg     0.6798    0.5306    0.5240       182
# weighted avg     0.8062    0.8516    0.8017       182
#
# 0.6117084826762247
# 0.6117084826762246
# (182,)

# %% [markdown]
# ## 빼낸 id별로 나눠서 실험 진행 필요
