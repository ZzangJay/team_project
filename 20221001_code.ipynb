# %% [markdown]
# <a href="https://colab.research.google.com/github/ZzangJay/team_project/blob/jangjaewon/20221001_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
#import tensorflow as tf 
import os
import sys
from datetime import datetime, timedelta

# %%
from google.colab import drive  # for colab
drive.mount('/content/gdrive/')  # for colab
cloud_directory = '/content/gdrive/MyDrive/mimiciv_unzip/'
os.listdir(cloud_directory) # for colab, check cloud directory mount
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).
# ['CHANGELOG.txt',
#  'LICENSE.txt',
#  'SHA256SUMS.txt',
#  'index.html',
#  'icu',
#  'hosp',
#  'drop_2_chartevents.csv']

# %%
admission = pd.read_csv('/content/gdrive/MyDrive/mimiciv_unzip/hosp/admissions.csv', low_memory=False, dtype='str', keep_default_na=False)
patients = pd.read_csv('/content/gdrive/MyDrive/mimiciv_unzip/hosp/patients.csv', low_memory=False, dtype='str', keep_default_na=False)
diagnoses_icd = pd.read_csv('/content/gdrive/MyDrive/mimiciv_unzip/hosp/diagnoses_icd.csv', low_memory=False, dtype='str', keep_default_na=False)

# %%
microbiologyevents = pd.read_csv('/content/gdrive/MyDrive/mimiciv_unzip/hosp/microbiologyevents.csv', low_memory=False, dtype='str', keep_default_na=False,chunksize = 10 ** 5)
chartevents = pd.read_csv('/content/gdrive/MyDrive/mimiciv_unzip/icu/chartevents.csv', low_memory=False, dtype='str', keep_default_na=False,chunksize = 10 ** 5)
labevents = pd.read_csv('/content/gdrive/MyDrive/mimiciv_unzip/hosp/labevents.csv', low_memory=False, dtype='str', keep_default_na=False,chunksize = 10 ** 5)

# %%
print(admission.size)
print(patients.size)
print(diagnoses_icd.size)
# Out:
# 6814860
# 1892760
# 25034420

# %%
microbiologyevents[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-ddc7f3df3e52> in <module>
# ----> 1 microbiologyevents[0]
#
# TypeError: 'TextFileReader' object is not subscriptable

# %%
for df in microbiologyevents :
  if 
    display(df.head(3))
# Out:
#   microevent_id subject_id hadm_id micro_specimen_id            chartdate  \
# 0             1   10000032                    636109  2180-03-23 00:00:00
# 1             2   10000032                   1836584  2180-03-23 00:00:00
# 2             3   10000032                   4131591  2180-03-23 00:00:00
#
#              charttime spec_itemid  spec_type_desc test_seq  \
# 0  2180-03-23 11:51:00       70093    Blood (Toxo)        1
# 1  2180-03-23 11:51:00       70017  SEROLOGY/BLOOD        1
# 2  2180-03-23 11:51:00       70087  Blood (CMV AB)        1
#
#              storedate  ... org_name isolate_num quantity ab_itemid ab_name  \
# 0  2180-03-26 00:00:00  ...
# 1  2180-03-24 00:00:00  ...
# 2  2180-03-26 00:00:00  ...
#
#   dilution_text dilution_comparison dilution_value interpretation  \
# 0
# 1
# 2
#
#                                             comments
# 0  NEGATIVE FOR TOXOPLASMA IgG ANTIBODY BY EIA.  ...
# 1  POSITIVE BY EIA.  A positive IgG result genera...
# 2                                                ___
#
# [3 rows x 24 columns]
#        microevent_id subject_id   hadm_id micro_specimen_id  \
# 100000        100001   10297708  22677931            555709
# 100001        100002   10297708  22677931            555709
# 100002        100003   10297708  22677931            555709
#
#                   chartdate            charttime spec_itemid  \
# 100000  2136-08-15 00:00:00  2136-08-15 19:57:00       70021
# 100001  2136-08-15 00:00:00  2136-08-15 19:57:00       70021
# 100002  2136-08-15 00:00:00  2136-08-15 19:57:00       70021
#
#                 spec_type_desc test_seq            storedate  ... org_name  \
# 100000  BRONCHOALVEOLAR LAVAGE        6  2136-08-29 00:00:00  ...    YEAST
# 100001  BRONCHOALVEOLAR LAVAGE        1  2136-08-16 00:00:00  ...
# 100002  BRONCHOALVEOLAR LAVAGE        3  2136-08-23 00:00:00  ...
#
#        isolate_num quantity ab_itemid ab_name dilution_text  \
# 100000           2
# 100001
# 100002
#
#        dilution_comparison dilution_value interpretation  \
# 100000
# 100001
# 100002
#
#                          comments
# 100000
# 100001                        ___
# 100002  NO LEGIONELLA ISOLATED.
#
# [3 rows x 24 columns]
#        microevent_id subject_id   hadm_id micro_specimen_id  \
# 200000        200001   10600115  27876015           4179812
# 200001        200002   10600115  27876015           1649150
# 200002        200003   10600115  27876015           2677961
#
#                   chartdate            charttime spec_itemid   spec_type_desc  \
# 200000  2150-01-05 00:00:00  2150-01-05 10:27:00       70012    BLOOD CULTURE
# 200001  2150-01-05 00:00:00  2150-01-05 16:56:00       70023  CATHETER TIP-IV
# 200002  2150-01-05 00:00:00  2150-01-05 19:00:00       70012    BLOOD CULTURE
#
#        test_seq            storedate  ... org_name isolate_num quantity  \
# 200000        1  2150-01-11 00:00:00  ...
# 200001        1  2150-01-07 00:00:00  ...
# 200002        1  2150-01-11 00:00:00  ...
#
#        ab_itemid ab_name dilution_text dilution_comparison dilution_value  \
# 200000
# 200001
# 200002
#
#        interpretation                  comments
# 200000                             NO GROWTH.
# 200001                 No significant growth.
# 200002                             NO GROWTH.
#
# [3 rows x 24 columns]
#        microevent_id subject_id hadm_id micro_specimen_id  \
# 300000        300001   10901772                   5745308
# 300001        300002   10901772                   3111843
# 300002        300003   10901772                   4339393
#
#                   chartdate            charttime spec_itemid spec_type_desc  \
# 300000  2154-07-16 00:00:00  2154-07-16 11:51:00       70012  BLOOD CULTURE
# 300001  2154-07-16 00:00:00  2154-07-16 12:57:00       70079          URINE
# 300002  2154-08-26 00:00:00  2154-08-26 21:15:00       70079          URINE
#
#        test_seq            storedate  ... org_name isolate_num quantity  \
# 300000        1  2154-07-21 00:00:00  ...
# 300001        1  2154-07-17 00:00:00  ...
# 300002        1  2154-08-27 00:00:00  ...
#
#        ab_itemid ab_name dilution_text dilution_comparison dilution_value  \
# 300000
# 300001
# 300002
#
#        interpretation                                           comments
# 300000                                                      NO GROWTH.
# 300001                 MIXED BACTERIAL FLORA ( >= 3 COLONY TYPES), CO...
# 300002                 MIXED BACTERIAL FLORA ( >= 3 COLONY TYPES), CO...
#
# [3 rows x 24 columns]
#        microevent_id subject_id hadm_id micro_specimen_id  \
# 400000        400001   11184659                   2160920
# 400001        400002   11184659                   2160920
# 400002        400003   11184659                   8172954
#
#                   chartdate            charttime spec_itemid  spec_type_desc  \
# 400000  2143-11-23 00:00:00  2143-11-23 11:56:00       70077           URINE
# 400001  2143-11-23 00:00:00  2143-11-23 11:56:00       70077           URINE
# 400002  2143-11-23 00:00:00  2143-11-23 11:56:00       70017  SEROLOGY/BLOOD
#
#        test_seq            storedate  ... org_name isolate_num quantity  \
# 400000        1  2143-11-26 00:00:00  ...
# 400001        2  2143-11-26 00:00:00  ...
# 400002        1  2143-11-26 00:00:00  ...
#
#        ab_itemid ab_name dilution_text dilution_comparison dilution_value  \
# 400000
# 400001
# 400002
#
#        interpretation                                           comments
# 400000                 Negative for Chlamydia trachomatis by ___, APT...
# 400001                 Negative for Neisseria gonorrhoeae by ___, APT...
# 400002                    NONREACTIVE.  Reference Range: Non-Reactive.
#
# [3 rows x 24 columns]
#        microevent_id subject_id   hadm_id micro_specimen_id  \
# 500000        500001   11475003  23069992           5169362
# 500001        500002   11475003  23069992           5169362
# 500002        500003   11475003  23069992           5169362
#
#                   chartdate            charttime spec_itemid  \
# 500000  2131-02-25 00:00:00  2131-02-25 17:12:00       70021
# 500001  2131-02-25 00:00:00  2131-02-25 17:12:00       70021
# 500002  2131-02-25 00:00:00  2131-02-25 17:12:00       70021
#
#                 spec_type_desc test_seq            storedate  ...  \
# 500000  BRONCHOALVEOLAR LAVAGE        2  2131-03-02 00:00:00  ...
# 500001  BRONCHOALVEOLAR LAVAGE        2  2131-03-02 00:00:00  ...
# 500002  BRONCHOALVEOLAR LAVAGE        2  2131-03-02 00:00:00  ...
#
#                    org_name isolate_num quantity ab_itemid  \
# 500000  STAPH AUREUS COAG +           1              90008
# 500001  STAPH AUREUS COAG +           1              90011
# 500002  STAPH AUREUS COAG +           1              90012
#
#                    ab_name dilution_text dilution_comparison dilution_value  \
# 500000  TRIMETHOPRIM/SULFA         <=0.5          <=                    0.5
# 500001        TETRACYCLINE             4          =                       4
# 500002          GENTAMICIN         <=0.5          <=                    0.5
#
#        interpretation                               comments
# 500000              S  Commensal Respiratory Flora Absent.
# 500001              S  Commensal Respiratory Flora Absent.
# 500002              S  Commensal Respiratory Flora Absent.
#
# [3 rows x 24 columns]
#        microevent_id subject_id hadm_id micro_specimen_id  \
# 600000        600001   11763371                   2970412
# 600001        600002   11763371                   3971198
# 600002        600003   11763371                   1291706
#
#                   chartdate            charttime spec_itemid spec_type_desc  \
# 600000  2128-07-04 00:00:00  2128-07-04 12:55:00       70046     IMMUNOLOGY
# 600001  2128-07-20 00:00:00  2128-07-20 09:35:00       70046     IMMUNOLOGY
# 600002  2129-12-12 00:00:00  2129-12-12 14:25:00       70046     IMMUNOLOGY
#
#        test_seq            storedate  ... org_name isolate_num quantity  \
# 600000        1  2128-07-05 00:00:00  ...
# 600001        1  2128-07-21 00:00:00  ...
# 600002        1  2129-12-14 00:00:00  ...
#
#        ab_itemid ab_name dilution_text dilution_comparison dilution_value  \
# 600000
# 600001
# 600002
#
#        interpretation comments
# 600000                     ___
# 600001                     ___
# 600002                     ___
#
# [3 rows x 24 columns]
#        microevent_id subject_id hadm_id micro_specimen_id  \
# 700000        700001   12059869                   3024505
# 700001        700002   12059869                   3944665
# 700002        700003   12059869                   7687251
#
#                   chartdate            charttime spec_itemid  spec_type_desc  \
# 700000  2120-02-05 00:00:00  2120-02-05 10:55:00       70017  SEROLOGY/BLOOD
# 700001  2120-02-05 00:00:00  2120-02-05 10:55:00       70017  SEROLOGY/BLOOD
# 700002  2120-02-05 00:00:00  2120-02-05 10:55:00       70017  SEROLOGY/BLOOD
#
#        test_seq            storedate  ... org_name isolate_num quantity  \
# 700000        1  2120-02-06 00:00:00  ...
# 700001        1  2120-02-07 00:00:00  ...
# 700002        1  2120-02-06 00:00:00  ...
#
#        ab_itemid ab_name dilution_text dilution_comparison dilution_value  \
# 700000
# 700001
# 700002
#
#        interpretation                                           comments
# 700000                 POSITIVE BY EIA.  A positive IgG result genera...
# 700001                 POSITIVE BY EIA.  A positive IgG result genera...
# 700002                    NONREACTIVE.  Reference Range: Non-Reactive.
#
# [3 rows x 24 columns]
#        microevent_id subject_id   hadm_id micro_specimen_id  \
# 800000        800001   12356657  22793142            445912
# 800001        800002   12356657  22793142            445912
# 800002        800003   12356657  22793142            445912
#
#                   chartdate            charttime spec_itemid spec_type_desc  \
# 800000  2155-12-14 00:00:00  2155-12-14 08:43:00       70079          URINE
# 800001  2155-12-14 00:00:00  2155-12-14 08:43:00       70079          URINE
# 800002  2155-12-14 00:00:00  2155-12-14 08:43:00       70079          URINE
#
#        test_seq            storedate  ...               org_name isolate_num  \
# 800000        1  2155-12-17 00:00:00  ...  KLEBSIELLA PNEUMONIAE           1
# 800001        1  2155-12-17 00:00:00  ...  KLEBSIELLA PNEUMONIAE           1
# 800002        1  2155-12-17 00:00:00  ...  KLEBSIELLA PNEUMONIAE           1
#
#        quantity ab_itemid             ab_name dilution_text  \
# 800000              90008  TRIMETHOPRIM/SULFA          =>16
# 800001              90010      NITROFURANTOIN           256
# 800002              90012          GENTAMICIN          =>16
#
#        dilution_comparison dilution_value interpretation comments
# 800000          =>                     16              R
# 800001          =                     256              R
# 800002          =>                     16              R
#
# [3 rows x 24 columns]
#        microevent_id subject_id hadm_id micro_specimen_id  \
# 900000        900001   12649654                   5241894
# 900001        900002   12649661                   6310063
# 900002        900003   12649661                   3277770
#
#                   chartdate            charttime spec_itemid  spec_type_desc  \
# 900000  2190-05-09 00:00:00  2190-05-09 16:52:00       70017  SEROLOGY/BLOOD
# 900001  2181-03-27 00:00:00  2181-03-27 09:05:00       70079           URINE
# 900002  2182-05-31 00:00:00  2182-05-31 14:30:00       70040            SWAB
#
#        test_seq            storedate  ... org_name isolate_num quantity  \
# 900000        1  2190-05-11 00:00:00  ...
# 900001        1  2181-03-28 00:00:00  ...
# 900002        1  2182-06-01 00:00:00  ...
#
#        ab_itemid ab_name dilution_text dilution_comparison dilution_value  \
# 900000
# 900001
# 900002
#
#        interpretation                                           comments
# 900000                 NEGATIVE BY EIA.            (Reference Range-N...
# 900001                 MIXED BACTERIAL FLORA ( >= 3 COLONY TYPES), CO...
# 900002                      Negative for Chlamydia trachomatis by PCR.
#
# [3 rows x 24 columns]
#         microevent_id subject_id   hadm_id micro_specimen_id  \
# 1000000       1000001   12945967  20913173           1851317
# 1000001       1000002   12945967  20913173           3411778
# 1000002       1000003   12945967  20913173           5030056
#
#                    chartdate            charttime spec_itemid spec_type_desc  \
# 1000000  2180-10-12 00:00:00  2180-10-12 19:10:00       70012  BLOOD CULTURE
# 1000001  2180-10-12 00:00:00  2180-10-12 19:10:00       70012  BLOOD CULTURE
# 1000002  2180-10-13 00:00:00  2180-10-13 22:07:00       70079          URINE
#
#         test_seq            storedate  ... org_name isolate_num quantity  \
# 1000000        1  2180-10-18 00:00:00  ...
# 1000001        1  2180-10-18 00:00:00  ...
# 1000002        1  2180-10-14 00:00:00  ...
#
#         ab_itemid ab_name dilution_text dilution_comparison dilution_value  \
# 1000000
# 1000001
# 1000002
#
#         interpretation                                           comments
# 1000000                                                      NO GROWTH.
# 1000001                                                      NO GROWTH.
# 1000002                 MIXED BACTERIAL FLORA ( >= 3 COLONY TYPES), CO...
#
# [3 rows x 24 columns]
#         microevent_id subject_id hadm_id micro_specimen_id  \
# 1100000       1100001   13232362                   9474395
# 1100001       1100002   13232362                   9474395
# 1100002       1100003   13232362                   9474395
#
#                    chartdate            charttime spec_itemid spec_type_desc  \
# 1100000  2126-03-26 00:00:00  2126-03-26 10:20:00       70079          URINE
# 1100001  2126-03-26 00:00:00  2126-03-26 10:20:00       70079          URINE
# 1100002  2126-03-26 00:00:00  2126-03-26 10:20:00       70079          URINE
#
#         test_seq            storedate  ...          org_name isolate_num  \
# 1100000        1  2126-03-28 00:00:00  ...  ESCHERICHIA COLI           1
# 1100001        1  2126-03-28 00:00:00  ...  ESCHERICHIA COLI           1
# 1100002        1  2126-03-28 00:00:00  ...  ESCHERICHIA COLI           1
#
#         quantity ab_itemid      ab_name dilution_text dilution_comparison  \
# 1100000              90012   GENTAMICIN           <=1          <=
# 1100001              90013   TOBRAMYCIN           <=1          <=
# 1100002              90017  CEFTAZIDIME           <=1          <=
#
#         dilution_value interpretation  \
# 1100000              1              S
# 1100001              1              S
# 1100002              1              S
#
#                                                   comments
# 1100000  Culture workup discontinued. Further incubatio...
# 1100001  Culture workup discontinued. Further incubatio...
# 1100002  Culture workup discontinued. Further incubatio...
#
# [3 rows x 24 columns]
#         microevent_id subject_id hadm_id micro_specimen_id  \
# 1200000       1200001   13524753                   1286468
# 1200001       1200002   13524753                   1286468
# 1200002       1200003   13524753                   1286468
#
#                    chartdate            charttime spec_itemid spec_type_desc  \
# 1200000  2111-04-24 00:00:00  2111-04-24 14:45:00       70012  BLOOD CULTURE
# 1200001  2111-04-24 00:00:00  2111-04-24 14:45:00       70012  BLOOD CULTURE
# 1200002  2111-04-24 00:00:00  2111-04-24 14:45:00       70012  BLOOD CULTURE
#
#         test_seq            storedate  ...             org_name isolate_num  \
# 1200000        1  2111-04-30 00:00:00  ...  STAPH AUREUS COAG +           1
# 1200001        1  2111-04-30 00:00:00  ...  STAPH AUREUS COAG +           1
# 1200002        1  2111-04-30 00:00:00  ...  STAPH AUREUS COAG +           1
#
#         quantity ab_itemid       ab_name dilution_text dilution_comparison  \
# 1200000              90012    GENTAMICIN         <=0.5          <=
# 1200001              90016     OXACILLIN        <=0.25          <=
# 1200002              90025  LEVOFLOXACIN          0.25          =
#
#         dilution_value interpretation comments
# 1200000            0.5              S
# 1200001           0.25              S
# 1200002           0.25              S
#
# [3 rows x 24 columns]
#         microevent_id subject_id   hadm_id micro_specimen_id  \
# 1300000       1300001   13820366  29457859           2845343
# 1300001       1300002   13820366  29457859           1030438
# 1300002       1300003   13820366  29457859           1030438
#
#                    chartdate            charttime spec_itemid  \
# 1300000  2174-11-12 00:00:00  2174-11-12 11:46:00       70006
# 1300001  2174-11-12 00:00:00  2174-11-12 11:46:00       70068
# 1300002  2174-11-12 00:00:00  2174-11-12 11:46:00       70068
#
#             spec_type_desc test_seq            storedate  ...  \
# 1300000  ANORECTAL/VAGINAL        1  2174-11-14 00:00:00  ...
# 1300001               SWAB        1  2174-11-13 00:00:00  ...
# 1300002               SWAB        2  2174-11-14 00:00:00  ...
#
#                                        org_name isolate_num quantity  \
# 1300000  POSITIVE FOR GROUP B BETA STREPTOCOCCI           1
# 1300001
# 1300002
#
#         ab_itemid ab_name dilution_text dilution_comparison dilution_value  \
# 1300000
# 1300001
# 1300002
#
#         interpretation                                        comments
# 1300000
# 1300001                 GRAM STAIN NEGATIVE FOR BACTERIAL VAGINOSIS.
# 1300002                                          NEGATIVE FOR YEAST.
#
# [3 rows x 24 columns]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-24751c6b163f> in <module>
# ----> 1 for df in microbiologyevents :
#       2     display(df.head(3))
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in __next__(self)
#    1022     def __next__(self):
#    1023         try:
# -> 1024             return self.get_chunk()
#    1025         except StopIteration:
#    1026             self.close()
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in get_chunk(self, size)
#    1072                 raise StopIteration
#    1073             size = min(size, self.nrows - self._currow)
# -> 1074         return self.read(nrows=size)
#    1075
#    1076     def __enter__(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     227
#     228             else:
# --> 229                 data = self._reader.read(nrows)
#     230         except StopIteration:
#     231             if self._first_chunk:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/dtypes/common.py in is_extension_array_dtype(arr_or_dtype)
#    1418
#    1419
# -> 1420 def is_extension_array_dtype(arr_or_dtype) -> bool:
#    1421     """
#    1422     Check if an object is a pandas extension array type.
#
# KeyboardInterrupt:

# %%
admission.columns
# Out:
# Index(['subject_id', 'hadm_id', 'admittime', 'dischtime', 'deathtime',
#        'admission_type', 'admission_location', 'discharge_location',
#        'insurance', 'language', 'marital_status', 'race', 'edregtime',
#        'edouttime', 'hospital_expire_flag'],
#       dtype='object')

# %%
sepsis = pd.read_csv('/content/gdrive/MyDrive/mimiciv_der/sepsis3.csv', low_memory=False, dtype='str', keep_default_na=False)

# %%
admission = pd.merge(left = admission, right = sepsis[['subject_id','sepsis3']], how='inner', left_on='subject_id', right_on='subject_id')
patients = pd.merge(left = patients, right = sepsis[['subject_id','sepsis3']], how='inner', left_on='subject_id', right_on='subject_id')
diagnoses_icd = pd.merge(left = diagnoses_icd, right = sepsis[['subject_id','sepsis3']], how='inner', left_on='subject_id', right_on='subject_id')
#microbiologyevents = pd.merge(left = microbiologyevents, right = sepsis[['subject_id','sepsis3']], how='inner', left_on='subject_id', right_on='subject_id')
#chartevents = pd.merge(left = chartevents, right = sepsis[['subject_id','sepsis3']], how='inner', left_on='subject_id', right_on='subject_id')
#labevents = pd.merge(left = labevents, right = sepsis[['subject_id','sepsis3']], how='inner', left_on='subject_id', right_on='subject_id')

# %%
microbiologyevents = pd.merge(left = pd.concat(microbiologyevents), right = sepsis[['subject_id','sepsis3']], how='inner', left_on='subject_id', right_on='subject_id')

# %%
chartevents = pd.merge(left = pd.concat(chartevents), right = sepsis[['subject_id','sepsis3']], how='inner', left_on='subject_id', right_on='subject_id')
labevents = pd.merge(left = pd.concat(labevents), right = sepsis[['subject_id','sepsis3']], how='inner', left_on='subject_id', right_on='subject_id')

# %%
microbiologyevents
# Out:
#         microevent_id subject_id   hadm_id micro_specimen_id  \
# 0             1400360   14110658  29672831           1089815
# 1             1400361   14110658  29672831           3375902
# 2             1400362   14110658  29672831           3838345
# 3             1400363   14110658                     8502568
# 4             1400364   14110658  22444253           8986425
# ...               ...        ...       ...               ...
# 1444695       3395205   19999840  21033226           5323018
# 1444696       3395206   19999840  21033226           9959252
# 1444697       3395207   19999840  21033226            186839
# 1444698       3395208   19999840                       43002
# 1444699       3395209   19999840                       43002
#
#                    chartdate            charttime spec_itemid  \
# 0        2145-06-28 00:00:00  2145-06-28 15:40:00       70012
# 1        2145-06-28 00:00:00  2145-06-28 16:30:00       70079
# 2        2145-06-28 00:00:00  2145-06-28 17:30:00       70012
# 3        2146-05-15 00:00:00  2146-05-15 19:20:00       70079
# 4        2146-06-14 00:00:00  2146-06-14 23:19:00       70079
# ...                      ...                  ...         ...
# 1444695  2164-09-14 00:00:00  2164-09-14 12:13:00       70091
# 1444696  2164-09-17 00:00:00  2164-09-17 06:10:00       70064
# 1444697  2164-09-17 00:00:00  2164-09-17 11:58:00       70012
# 1444698  2164-09-18 00:00:00                            70055
# 1444699  2164-09-18 00:00:00                            70055
#
#              spec_type_desc test_seq            storedate  ... isolate_num  \
# 0             BLOOD CULTURE        1  2145-07-04 00:00:00  ...
# 1                     URINE        1  2145-06-29 00:00:00  ...
# 2             BLOOD CULTURE        1  2145-07-04 00:00:00  ...
# 3                     URINE        1  2146-05-16 00:00:00  ...
# 4                     URINE        1  2146-06-16 00:00:00  ...
# ...                     ...      ...                  ...  ...         ...
# 1444695         MRSA SCREEN        1  2164-09-16 00:00:00  ...
# 1444696               STOOL        1  2164-09-17 00:00:00  ...
# 1444697       BLOOD CULTURE        1  2164-09-23 00:00:00  ...
# 1444698  POSTMORTEM CULTURE        1  2164-09-22 00:00:00  ...           1
# 1444699  POSTMORTEM CULTURE        2  2164-10-19 00:00:00  ...
#
#         quantity ab_itemid ab_name dilution_text dilution_comparison  \
# 0
# 1
# 2
# 3
# 4
# ...          ...       ...     ...           ...                 ...
# 1444695
# 1444696
# 1444697
# 1444698
# 1444699
#
#         dilution_value interpretation  \
# 0
# 1
# 2
# 3
# 4
# ...                ...            ...
# 1444695
# 1444696
# 1444697
# 1444698
# 1444699
#
#                                                   comments sepsis3
# 0                                             NO GROWTH.      true
# 1                                       < 10,000 CFU/mL.      true
# 2                                             NO GROWTH.      true
# 3        MIXED BACTERIAL FLORA ( >= 3 COLONY TYPES), CO...    true
# 4        MIXED BACTERIAL FLORA ( >= 3 COLONY TYPES), CO...    true
# ...                                                    ...     ...
# 1444695                                No MRSA isolated.      true
# 1444696  Feces negative for C. difficile toxin A & B by...    true
# 1444697                                       NO GROWTH.      true
# 1444698                                                       true
# 1444699                               NO VIRUS ISOLATED.      true
#
# [1444700 rows x 25 columns]

# %%
# item id, valuenum 전처리해야함.

# %%
sepsis.columns
# Out:
# Index(['subject_id', 'stay_id', 'antibiotic_time', 'culture_time',
#        'suspected_infection_time', 'sofa_time', 'sofa_score', 'respiration',
#        'coagulation', 'liver', 'cardiovascular', 'cns', 'renal', 'sepsis3'],
#       dtype='object')

# %%
sepsis
# Out:
#        subject_id   stay_id      antibiotic_time         culture_time  \
# 0        16266622  32828424  2134-09-20 16:00:00  2134-09-20 15:32:00
# 1        13830137  31445489  2174-05-06 22:00:00  2174-05-06 00:00:00
# 2        14367208  39300189  2135-09-14 18:00:00  2135-09-14 00:45:00
# 3        12035173  34909617  2168-01-25 02:00:00  2168-01-22 04:04:00
# 4        13729279  39470047  2181-01-14 04:00:00  2181-01-13 17:50:00
# ...           ...       ...                  ...                  ...
# 34673    10827578  34763877  2130-05-09 08:00:00  2130-05-09 11:55:00
# 34674    11713814  37767813  2159-05-31 08:00:00  2159-05-31 06:25:00
# 34675    17715294  37357219  2131-07-25 13:00:00  2131-07-25 12:50:00
# 34676    11180969  35240504  2139-10-30 08:00:00  2139-10-29 21:52:00
# 34677    16794039  30606871  2112-01-11 00:00:00  2112-01-10 12:29:00
#
#       suspected_infection_time            sofa_time  sofa_score  respiration  \
# 0          2134-09-20 15:32:00  2134-09-20 16:00:00           2            2
# 1          2174-05-06 00:00:00  2174-05-06 21:00:00           2            0
# 2          2135-09-14 00:45:00  2135-09-14 04:00:00           2            0
# 3          2168-01-22 04:04:00  2168-01-22 01:00:00           2            0
# 4          2181-01-13 17:50:00  2181-01-14 05:00:00           2            0
# ...                        ...                  ...         ...          ...
# 34673      2130-05-09 08:00:00  2130-05-07 08:00:00          17            3
# 34674      2159-05-31 06:25:00  2159-05-29 07:00:00          17            2
# 34675      2131-07-25 12:50:00  2131-07-23 13:00:00          17            2
# 34676      2139-10-29 21:52:00  2139-10-27 22:00:00          20            4
# 34677      2112-01-10 12:29:00  2112-01-08 13:00:00          20            4
#
#        coagulation  liver  cardiovascular  cns  renal  sepsis3
# 0                0      0               0    0      0     True
# 1                0      0               0    0      2     True
# 2                0      1               0    0      1     True
# 3                0      0               0    2      0     True
# 4                0      0               0    2      0     True
# ...            ...    ...             ...  ...    ...      ...
# 34673            3      3               4    0      4     True
# 34674            2      2               4    4      3     True
# 34675            4      4               4    0      3     True
# 34676            2      2               4    4      4     True
# 34677            0      4               4    4      4     True
#
# [34678 rows x 14 columns]

# %%
sum(sepsis['sepsis3'])/len(sepsis['sepsis3'])
# Out:
# 1.0

# %%
# 한 환자가 있고 입원 여러번 한 경우 입원 아이디 여러번
# stayid 가 다르다.
# syayid 첫번째꺼
# intime, outtime, death time
# intime과 outtime 안에 death time 이 있으면 상태악화로 정의

# %%
# 제외조건

# %%
# input data 붙여오기

# %%
VITAL_SIGNS = {'PULSE': ['220045', '211'],
               'RESP': ['220210', '618'],
               'SBP': ['220050', '220179', '225309', '51', '455'],
               'DBP': ['220051', '220180', '225310', '8368', '8441'],
               'FiO2': ['223835', '189', '190'],
               'MAP': ['220052', '1321', '438']
               }
LABS = {'BILIRUBIN': ['50885'],
        'LACTATE': ['50813'],
        'pH': ['50820', '50831'],
        'SODIUM': ['50983'],
        'POTASSIUM': ['50971'],
        'CREATININE': ['50912'],
        'WBC': ['51301'],
        'HEMATOCRIT': ['51221']
        }
