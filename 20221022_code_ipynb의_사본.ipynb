# %% [markdown]
# <a href="https://colab.research.google.com/github/ZzangJay/team_project/blob/jangjaewon/20221022_code_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
#import tensorflow as tf 
import os
import sys
from datetime import datetime, timedelta


from tqdm.autonotebook import tqdm
import csv

import re

import gzip
import shutil

# %%
from google.colab import drive  # for colab
drive.mount('/content/gdrive/')  # for colab
cloud_directory = '/content/gdrive/MyDrive/mimiciv_unzip/'
os.listdir(cloud_directory) # for colab, check cloud directory mount
# Out:
# Mounted at /content/gdrive/
# ['CHANGELOG.txt',
#  'LICENSE.txt',
#  'SHA256SUMS.txt',
#  'index.html',
#  'icu',
#  'hosp',
#  'drop_2_chartevents.csv']

# %%
admission = pd.read_csv('/content/gdrive/MyDrive/mimiciv_unzip/hosp/admissions.csv', low_memory=False, dtype='str', keep_default_na=False)
patients = pd.read_csv('/content/gdrive/MyDrive/mimiciv_unzip/hosp/patients.csv', low_memory=False, dtype='str', keep_default_na=False)
diagnoses_icd = pd.read_csv('/content/gdrive/MyDrive/mimiciv_unzip/hosp/diagnoses_icd.csv', low_memory=False, dtype='str', keep_default_na=False)
icustays = pd.read_csv('/content/gdrive/MyDrive/mimiciv_unzip/icu/icustays.csv', low_memory=False, dtype='str', keep_default_na=False)

# %%
sepsis = pd.read_csv('/content/gdrive/MyDrive/mimiciv_der/sepsis3.csv', low_memory=False, dtype='str', keep_default_na=False)

# %%
admission = pd.merge(left = admission, right = sepsis[['subject_id','sepsis3']], how='inner', left_on='subject_id', right_on='subject_id')
patients = pd.merge(left = patients, right = sepsis[['subject_id','sepsis3']], how='inner', left_on='subject_id', right_on='subject_id')
diagnoses_icd = pd.merge(left = diagnoses_icd, right = sepsis[['subject_id','sepsis3']], how='inner', left_on='subject_id', right_on='subject_id')
sepsis = pd.merge(left = sepsis, right = icustays[['hadm_id','stay_id']], how='left', left_on='stay_id', right_on='stay_id')

# %%
Total_HADMIDS = set(sepsis['hadm_id'])

# %%
EXTRACT_FEATURE_CODES_VS = dict({
    '220045': 'PULSE',
    '211': 'PULSE',
    '618': 'RESP',
    '220210': 'RESP',
    '220050': 'SBP',
    '220179': 'SBP',
    '225309': 'SBP',
    '51': 'SBP',
    '455': 'SBP',
    '220051': 'DBP',
    '220180': 'DBP',
    '225310': 'DBP',
    '8368': 'DBP',
    '8441': 'DBP',
    '223762': 'TEMP',
    '676': 'TEMP',
    '677': 'TEMP',
    '223761': 'TEMP_F',
    '678': 'TEMP_F',
    '679': 'TEMP_F',
    '223835' : 'FiO2',
    '189' : 'FiO2',
    '190' : 'FiO2',
    '220052' : 'MAP',
    '1321' : 'MAP',
    '438' : 'MAP'
})

EXTRACT_FEATURE_CODES_LAB = dict({
    '50885': 'BILIRUBIN',
    '220546': 'WBC',
    '51301': 'WBC',
    '51221': 'HEMATOCRIT',
    '225668': 'LACTATE',
    '50813': 'LACTATE',
    '51265': 'PLATELET',
    '50912': 'CREATININE',
    '220615': 'CREATININE',
    '229761': 'CREATININE',
    '50983': 'SODIUM',
    '50820': 'PH',
    '50831': 'PH',
    '50971': 'POTASSIUM'
})

FEATURE_NORMAL_RANGE = dict({
    'PULSE': (0, 300),
    'SBP': (0, 300),
    'DBP': (0, 300),
    'RESP': (0, 120),
    'TEMP': (25, 50),
    'BILIRUBIN': (0, 75),
    'WBC': (0, 100),
    'HEMATOCRIT': (0, 100),
    'LACTATE': (0, 20),
    'PLATELET': (0, 1000),
    'CREATININE': (0, 20),
    'SODIUM': (0, 500) 
})

# VITAL_SIGNS = {'PULSE': ['220045', '211'],
#                'RESP': ['220210', '618'],
#                'SBP': ['220050', '220179', '225309', '51', '455'],
#                'DBP': ['220051', '220180', '225310', '8368', '8441'],
#                'FiO2': ['223835', '189', '190'],
#                'MAP': ['220052', '1321', '438']
#                }
# LABS = {'BILIRUBIN': ['50885'],
#         'LACTATE': ['50813'],
#         'pH': ['50820', '50831'],
#         'SODIUM': ['50983'],
#         'POTASSIUM': ['50971'],
#         'CREATININE': ['50912'],
#         'WBC': ['51301'],
#         'HEMATOCRIT': ['51221']
#         }

# VITAL_SIGNS = {'PULSE': ['220045', '211'],
#                'RESP': ['220210', '618'],
#                'SBP': ['228152','229899','220050', '220179', '225309', '51', '455','224167','227243'],
#                'DBP': ['220051', '220180', '225310', '8368', '8441'],
#                'FiO2': ['229280','229841','226754','227009','227010', '223835', '189', '190'],
#                'MAP': ['220052', '1321', '438']
#                }

# LABS = {'lactate': ['225668'],
#         'glucose'	: ['220621','225664','226537','228388'],
#         'creatinine' : ['220615','229761'],
#         'WBC'	: ['220546','51301'],
#         'heart rate' : ['220046','220047','226764','220045','227018'],
#         'sodium' : ['220645','226534','228389','228390'],
#         'temperature' : ['223762','226329','227632','227634'],
#         'platelet' : ['227457'],
#         'hemoglobin' : ['220228'],
#         'pao2' : ['220224','227516','227039'],
# }

# %%
## Define some util functions
NOT_CONVERTED = 'NOT_CONVERTED'
## 문자로 기록된 날짜 값들을 파이썬의 datetime 데이터로 바꿔주는 함수 작성
def str2datetime(s):
    def _convert(_s, _dformat):
        try:
            converted_dt = datetime.strptime(_s, _dformat)
        except Exception:
            return NOT_CONVERTED

        return converted_dt

    if isinstance(s, datetime):
        return s

    dformats = [
        '%Y-%m-%d %p %I:%M:%S',
        '%Y-%m-%d %H:%M:%S.%f',
        '%Y-%m-%d %H:%M:%S',
        '%Y-%m-%d %H:%M',
        '%y-%m-%d %H:%M',
        '%Y-%m-%d',
        '%Y%m%d',
        '%Y-%m-%d +%H:%M',
        '%Y%m%d %H%M',
        '%Y%m%d%H%M%S',
        ]

    s = s.split('.')[0]
    s = s.replace('오전', 'am').replace('오후', 'pm')
    for dformat in dformats:
        dt = _convert(s, dformat)
        if dt != NOT_CONVERTED:
            return dt

    return NOT_CONVERTED

# %%
def extract_features():
  features_hadm_id = dict()
  chartevents = csv.DictReader(open('/content/gdrive/MyDrive/mimiciv_unzip/icu/chartevents.csv', 'r', encoding='utf-8'))
  labevents = csv.DictReader(open('/content/gdrive/MyDrive/mimiciv_unzip/hosp/labevents.csv', 'r', encoding='utf-8'))
  for row in tqdm(chartevents, desc='Extract_VS', total=7241351, ncols=700):
    if row['hadm_id'] in Total_HADMIDS:
      hadm_id = row['hadm_id']
      features_hadm_id[hadm_id] = features_hadm_id.get(hadm_id, dict()) #get 없으면 2번째로 return

      item_id = row['itemid']
      if item_id not in EXTRACT_FEATURE_CODES_VS:
        continue
      item_name = EXTRACT_FEATURE_CODES_VS[item_id]
      try:
        #정규식을 이용해서 기록된 값에서 숫자 형태의 값만 가져오기
        #소수점 둘째자리 까지만 값을 사용하기
        item_value = round(float(re.findall("\d+\.\d+|\d+", row['valuenum'])[0]), 2)
      except Exception:
        continue
      
      item_time = str2datetime(row['charttime'])
      if item_time == NOT_CONVERTED:
        continue
      #GCP total score도 시간대에 총합으로 사용함
      if item_name == 'TEMP_F':
        item_value = round((item_value - 32.0) / 1.8, 2)
        item_name = 'TEMP'

    #   if item_value > FEATURE_NORMAL_RANGE[item_name][1]:
    #     item_value = FEATURE_NORMAL_RANGE[item_name][1]
    #   elif item_value < FEATURE_NORMAL_RANGE[item_name][0]:
    #     item_value = FEATURE_NORMAL_RANGE[item_name][0]

      features_hadm_id[hadm_id][item_name] = features_hadm_id[hadm_id].get(item_name, list()) #같은 환자의 여러개 feature가 있으면 list로 반환하도록
      features_hadm_id[hadm_id][item_name].append((item_time, item_value))
      
    else:
      continue

  for row in tqdm(labevents, desc='Extract_LAB', total=615328, ncols=700):
    if row['hadm_id'] in Total_HADMIDS:
      hadm_id = row['hadm_id']
      features_hadm_id[hadm_id] = features_hadm_id.get(hadm_id, dict())

      item_id = row['itemid']
      if item_id not in EXTRACT_FEATURE_CODES_LAB:
        continue
      item_name = EXTRACT_FEATURE_CODES_LAB[item_id]
      try:
        #정규식을 이용해서 기록된 값에서 숫자 형태의 값만 가져오기
        #소수점 둘째자리 까지만 값을 사용하기
        item_value = round(float(re.findall("\d+\.\d+|\d+", row['valuenum'])[0]), 2)
      except Exception:
        continue
      
      item_time = str2datetime(row['charttime'])
      if item_time == NOT_CONVERTED:
        continue

      #if item_value > FEATURE_NORMAL_RANGE[item_name][1]:
      #  item_value = FEATURE_NORMAL_RANGE[item_name][1]
      #elif item_value < FEATURE_NORMAL_RANGE[item_name][0]:
      #  item_value = FEATURE_NORMAL_RANGE[item_name][0]
        
      features_hadm_id[hadm_id][item_name] = features_hadm_id[hadm_id].get(item_name, list())
      features_hadm_id[hadm_id][item_name].append((item_time, item_value))
      
    else:
      continue
      
  return features_hadm_id

# %%
extracted_features = extract_features()
# Out:
# Extract_VS:   0%|                                                                                             …
# Extract_LAB:   0%|                                                                                            …

# %%
import pickle
import gzip
with gzip.open('/content/gdrive/MyDrive/mimiciv_der/sepsis3_extracted_features_raw.pickle', 'wb') as f:
    pickle.dump(extracted_features, f)

# %%
from itertools import islice

# %%
dict(list(extracted_features.items())[0:2])
# Out:
# {'26184834': {'FiO2': [(datetime.datetime(2131, 1, 11, 4, 0), 100.0),
#    (datetime.datetime(2131, 1, 11, 7, 0), 50.0),
#    (datetime.datetime(2131, 1, 11, 11, 0), 50.0),
#    (datetime.datetime(2131, 1, 11, 12, 0), 50.0),
#    (datetime.datetime(2131, 1, 11, 16, 0), 50.0),
#    (datetime.datetime(2131, 1, 11, 19, 0), 50.0),
#    (datetime.datetime(2131, 1, 12, 0, 0), 50.0),
#    (datetime.datetime(2131, 1, 12, 4, 0), 50.0),
#    (datetime.datetime(2131, 1, 12, 7, 0), 50.0),
#    (datetime.datetime(2131, 1, 12, 8, 0), 40.0),
#    (datetime.datetime(2131, 1, 12, 11, 0), 40.0),
#    (datetime.datetime(2131, 1, 12, 15, 0), 40.0),
#    (datetime.datetime(2131, 1, 12, 21, 0), 40.0),
#    (datetime.datetime(2131, 1, 13, 0, 0), 40.0),
#    (datetime.datetime(2131, 1, 13, 4, 0), 40.0),
#    (datetime.datetime(2131, 1, 13, 7, 0), 40.0),
#    (datetime.datetime(2131, 1, 13, 11, 0), 40.0),
#    (datetime.datetime(2131, 1, 13, 19, 0), 40.0),
#    (datetime.datetime(2131, 1, 13, 23, 0), 40.0),
#    (datetime.datetime(2131, 1, 14, 3, 0), 40.0),
#    (datetime.datetime(2131, 1, 14, 7, 0), 40.0),
#    (datetime.datetime(2131, 1, 14, 15, 0), 40.0),
#    (datetime.datetime(2131, 1, 14, 19, 0), 40.0),
#    (datetime.datetime(2131, 1, 14, 23, 0), 40.0),
#    (datetime.datetime(2131, 1, 15, 3, 0), 40.0),
#    (datetime.datetime(2131, 1, 15, 8, 0), 40.0),
#    (datetime.datetime(2131, 1, 15, 11, 0), 40.0),
#    (datetime.datetime(2131, 1, 15, 15, 0), 40.0),
#    (datetime.datetime(2131, 1, 15, 19, 0), 40.0),
#    (datetime.datetime(2131, 1, 15, 23, 0), 40.0),
#    (datetime.datetime(2131, 1, 16, 3, 0), 40.0),
#    (datetime.datetime(2131, 1, 16, 7, 0), 40.0),
#    (datetime.datetime(2131, 1, 16, 10, 0), 40.0),
#    (datetime.datetime(2131, 1, 16, 11, 0), 40.0),
#    (datetime.datetime(2131, 1, 16, 15, 0), 40.0),
#    (datetime.datetime(2131, 1, 16, 20, 0), 40.0),
#    (datetime.datetime(2131, 1, 17, 0, 0), 40.0),
#    (datetime.datetime(2131, 1, 17, 4, 0), 40.0),
#    (datetime.datetime(2131, 1, 17, 8, 0), 40.0),
#    (datetime.datetime(2131, 1, 17, 12, 0), 40.0),
#    (datetime.datetime(2131, 1, 17, 16, 0), 40.0),
#    (datetime.datetime(2131, 1, 17, 20, 0), 40.0),
#    (datetime.datetime(2131, 1, 18, 0, 0), 40.0),
#    (datetime.datetime(2131, 1, 18, 3, 30), 40.0),
#    (datetime.datetime(2131, 1, 18, 7, 0), 40.0),
#    (datetime.datetime(2131, 1, 18, 12, 0), 40.0),
#    (datetime.datetime(2131, 1, 18, 16, 0), 40.0),
#    (datetime.datetime(2131, 1, 18, 21, 0), 40.0),
#    (datetime.datetime(2131, 1, 19, 0, 0), 40.0),
#    (datetime.datetime(2131, 1, 19, 4, 0), 40.0),
#    (datetime.datetime(2131, 1, 19, 7, 0), 40.0),
#    (datetime.datetime(2131, 1, 19, 11, 0), 40.0),
#    (datetime.datetime(2131, 1, 19, 16, 0), 40.0),
#    (datetime.datetime(2131, 1, 19, 18, 40), 100.0),
#    (datetime.datetime(2131, 1, 19, 18, 45), 100.0),
#    (datetime.datetime(2131, 1, 19, 20, 0), 70.0),
#    (datetime.datetime(2131, 1, 19, 22, 0), 35.0)],
#   'RESP': [(datetime.datetime(2131, 1, 11, 4, 20), 16.0),
#    (datetime.datetime(2131, 1, 11, 5, 0), 10.0),
#    (datetime.datetime(2131, 1, 11, 6, 0), 20.0),
#    (datetime.datetime(2131, 1, 11, 6, 44), 20.0),
#    (datetime.datetime(2131, 1, 11, 6, 47), 15.0),
#    (datetime.datetime(2131, 1, 11, 7, 0), 18.0),
#    (datetime.datetime(2131, 1, 11, 8, 0), 20.0),
#    (datetime.datetime(2131, 1, 11, 9, 0), 20.0),
#    (datetime.datetime(2131, 1, 11, 10, 0), 19.0),
#    (datetime.datetime(2131, 1, 11, 11, 0), 14.0),
#    (datetime.datetime(2131, 1, 11, 12, 0), 12.0),
#    (datetime.datetime(2131, 1, 11, 13, 0), 19.0),
#    (datetime.datetime(2131, 1, 11, 14, 0), 18.0),
#    (datetime.datetime(2131, 1, 11, 15, 0), 17.0),
#    (datetime.datetime(2131, 1, 11, 16, 0), 20.0),
#    (datetime.datetime(2131, 1, 11, 17, 0), 17.0),
#    (datetime.datetime(2131, 1, 11, 18, 0), 17.0),
#    (datetime.datetime(2131, 1, 11, 19, 0), 16.0),
#    (datetime.datetime(2131, 1, 11, 20, 0), 26.0),
#    (datetime.datetime(2131, 1, 11, 21, 0), 17.0),
#    (datetime.datetime(2131, 1, 11, 21, 37), 19.0),
#    (datetime.datetime(2131, 1, 11, 22, 0), 17.0),
#    (datetime.datetime(2131, 1, 11, 23, 0), 15.0),
#    (datetime.datetime(2131, 1, 12, 0, 0), 19.0),
#    (datetime.datetime(2131, 1, 12, 1, 0), 17.0),
#    (datetime.datetime(2131, 1, 12, 2, 0), 17.0),
#    (datetime.datetime(2131, 1, 12, 3, 0), 14.0),
#    (datetime.datetime(2131, 1, 12, 4, 0), 17.0),
#    (datetime.datetime(2131, 1, 12, 5, 0), 23.0),
#    (datetime.datetime(2131, 1, 12, 6, 0), 21.0),
#    (datetime.datetime(2131, 1, 12, 7, 0), 17.0),
#    (datetime.datetime(2131, 1, 12, 8, 0), 21.0),
#    (datetime.datetime(2131, 1, 12, 9, 0), 16.0),
#    (datetime.datetime(2131, 1, 12, 10, 0), 21.0),
#    (datetime.datetime(2131, 1, 12, 11, 0), 22.0),
#    (datetime.datetime(2131, 1, 12, 11, 4), 24.0),
#    (datetime.datetime(2131, 1, 12, 12, 0), 23.0),
#    (datetime.datetime(2131, 1, 12, 12, 4), 20.0),
#    (datetime.datetime(2131, 1, 12, 13, 0), 22.0),
#    (datetime.datetime(2131, 1, 12, 13, 4), 23.0),
#    (datetime.datetime(2131, 1, 12, 14, 0), 18.0),
#    (datetime.datetime(2131, 1, 12, 14, 4), 19.0),
#    (datetime.datetime(2131, 1, 12, 15, 0), 16.0),
#    (datetime.datetime(2131, 1, 12, 15, 4), 17.0),
#    (datetime.datetime(2131, 1, 12, 16, 0), 18.0),
#    (datetime.datetime(2131, 1, 12, 16, 4), 20.0),
#    (datetime.datetime(2131, 1, 12, 17, 0), 21.0),
#    (datetime.datetime(2131, 1, 12, 17, 4), 23.0),
#    (datetime.datetime(2131, 1, 12, 18, 0), 20.0),
#    (datetime.datetime(2131, 1, 12, 18, 4), 24.0),
#    (datetime.datetime(2131, 1, 12, 19, 0), 26.0),
#    (datetime.datetime(2131, 1, 12, 20, 0), 19.0),
#    (datetime.datetime(2131, 1, 12, 21, 0), 18.0),
#    (datetime.datetime(2131, 1, 12, 22, 0), 28.0),
#    (datetime.datetime(2131, 1, 12, 23, 0), 22.0),
#    (datetime.datetime(2131, 1, 13, 0, 0), 25.0),
#    (datetime.datetime(2131, 1, 13, 1, 0), 23.0),
#    (datetime.datetime(2131, 1, 13, 2, 0), 22.0),
#    (datetime.datetime(2131, 1, 13, 3, 0), 24.0),
#    (datetime.datetime(2131, 1, 13, 4, 0), 21.0),
#    (datetime.datetime(2131, 1, 13, 5, 0), 17.0),
#    (datetime.datetime(2131, 1, 13, 6, 0), 18.0),
#    (datetime.datetime(2131, 1, 13, 7, 0), 18.0),
#    (datetime.datetime(2131, 1, 13, 8, 0), 17.0),
#    (datetime.datetime(2131, 1, 13, 9, 0), 17.0),
#    (datetime.datetime(2131, 1, 13, 10, 0), 16.0),
#    (datetime.datetime(2131, 1, 13, 11, 0), 18.0),
#    (datetime.datetime(2131, 1, 13, 12, 0), 17.0),
#    (datetime.datetime(2131, 1, 13, 13, 0), 17.0),
#    (datetime.datetime(2131, 1, 13, 14, 0), 18.0),
#    (datetime.datetime(2131, 1, 13, 15, 0), 24.0),
#    (datetime.datetime(2131, 1, 13, 16, 0), 25.0),
#    (datetime.datetime(2131, 1, 13, 17, 0), 27.0),
#    (datetime.datetime(2131, 1, 13, 18, 0), 23.0),
#    (datetime.datetime(2131, 1, 13, 19, 0), 20.0),
#    (datetime.datetime(2131, 1, 13, 20, 0), 22.0),
#    (datetime.datetime(2131, 1, 13, 21, 0), 24.0),
#    (datetime.datetime(2131, 1, 13, 22, 0), 22.0),
#    (datetime.datetime(2131, 1, 13, 23, 0), 21.0),
#    (datetime.datetime(2131, 1, 14, 0, 0), 20.0),
#    (datetime.datetime(2131, 1, 14, 1, 0), 17.0),
#    (datetime.datetime(2131, 1, 14, 2, 0), 17.0),
#    (datetime.datetime(2131, 1, 14, 3, 0), 16.0),
#    (datetime.datetime(2131, 1, 14, 4, 0), 17.0),
#    (datetime.datetime(2131, 1, 14, 5, 0), 17.0),
#    (datetime.datetime(2131, 1, 14, 6, 0), 16.0),
#    (datetime.datetime(2131, 1, 14, 7, 0), 32.0),
#    (datetime.datetime(2131, 1, 14, 8, 0), 29.0),
#    (datetime.datetime(2131, 1, 14, 9, 0), 19.0),
#    (datetime.datetime(2131, 1, 14, 10, 0), 18.0),
#    (datetime.datetime(2131, 1, 14, 13, 33), 16.0),
#    (datetime.datetime(2131, 1, 14, 14, 0), 21.0),
#    (datetime.datetime(2131, 1, 14, 15, 0), 29.0),
#    (datetime.datetime(2131, 1, 14, 16, 0), 25.0),
#    (datetime.datetime(2131, 1, 14, 17, 0), 22.0),
#    (datetime.datetime(2131, 1, 14, 18, 0), 10.0),
#    (datetime.datetime(2131, 1, 14, 19, 0), 15.0),
#    (datetime.datetime(2131, 1, 14, 20, 0), 21.0),
#    (datetime.datetime(2131, 1, 14, 21, 0), 26.0),
#    (datetime.datetime(2131, 1, 14, 22, 0), 24.0),
#    (datetime.datetime(2131, 1, 14, 23, 0), 25.0),
#    (datetime.datetime(2131, 1, 15, 0, 0), 25.0),
#    (datetime.datetime(2131, 1, 15, 1, 0), 16.0),
#    (datetime.datetime(2131, 1, 15, 2, 0), 15.0),
#    (datetime.datetime(2131, 1, 15, 3, 0), 27.0),
#    (datetime.datetime(2131, 1, 15, 4, 0), 22.0),
#    (datetime.datetime(2131, 1, 15, 5, 0), 24.0),
#    (datetime.datetime(2131, 1, 15, 6, 0), 29.0),
#    (datetime.datetime(2131, 1, 15, 7, 0), 26.0),
#    (datetime.datetime(2131, 1, 15, 8, 0), 25.0),
#    (datetime.datetime(2131, 1, 15, 9, 0), 25.0),
#    (datetime.datetime(2131, 1, 15, 10, 0), 27.0),
#    (datetime.datetime(2131, 1, 15, 11, 0), 23.0),
#    (datetime.datetime(2131, 1, 15, 12, 0), 15.0),
#    (datetime.datetime(2131, 1, 15, 13, 0), 15.0),
#    (datetime.datetime(2131, 1, 15, 14, 0), 14.0),
#    (datetime.datetime(2131, 1, 15, 15, 0), 13.0),
#    (datetime.datetime(2131, 1, 15, 16, 0), 18.0),
#    (datetime.datetime(2131, 1, 15, 17, 0), 18.0),
#    (datetime.datetime(2131, 1, 15, 18, 0), 18.0),
#    (datetime.datetime(2131, 1, 15, 19, 0), 16.0),
#    (datetime.datetime(2131, 1, 15, 20, 0), 15.0),
#    (datetime.datetime(2131, 1, 15, 21, 0), 19.0),
#    (datetime.datetime(2131, 1, 15, 22, 0), 21.0),
#    (datetime.datetime(2131, 1, 15, 23, 0), 18.0),
#    (datetime.datetime(2131, 1, 16, 0, 0), 19.0),
#    (datetime.datetime(2131, 1, 16, 1, 0), 22.0),
#    (datetime.datetime(2131, 1, 16, 2, 0), 12.0),
#    (datetime.datetime(2131, 1, 16, 3, 0), 15.0),
#    (datetime.datetime(2131, 1, 16, 4, 0), 20.0),
#    (datetime.datetime(2131, 1, 16, 5, 0), 19.0),
#    (datetime.datetime(2131, 1, 16, 6, 0), 19.0),
#    (datetime.datetime(2131, 1, 16, 7, 0), 26.0),
#    (datetime.datetime(2131, 1, 16, 8, 0), 22.0),
#    (datetime.datetime(2131, 1, 16, 9, 0), 21.0),
#    (datetime.datetime(2131, 1, 16, 10, 0), 20.0),
#    (datetime.datetime(2131, 1, 16, 11, 0), 21.0),
#    (datetime.datetime(2131, 1, 16, 12, 0), 20.0),
#    (datetime.datetime(2131, 1, 16, 13, 0), 20.0),
#    (datetime.datetime(2131, 1, 16, 14, 0), 19.0),
#    (datetime.datetime(2131, 1, 16, 15, 0), 16.0),
#    (datetime.datetime(2131, 1, 16, 16, 0), 18.0),
#    (datetime.datetime(2131, 1, 16, 17, 0), 20.0),
#    (datetime.datetime(2131, 1, 16, 18, 0), 20.0),
#    (datetime.datetime(2131, 1, 16, 19, 0), 21.0),
#    (datetime.datetime(2131, 1, 16, 20, 0), 23.0),
#    (datetime.datetime(2131, 1, 16, 21, 0), 17.0),
#    (datetime.datetime(2131, 1, 16, 22, 0), 17.0),
#    (datetime.datetime(2131, 1, 16, 23, 0), 20.0),
#    (datetime.datetime(2131, 1, 17, 0, 0), 20.0),
#    (datetime.datetime(2131, 1, 17, 1, 0), 17.0),
#    (datetime.datetime(2131, 1, 17, 2, 0), 17.0),
#    (datetime.datetime(2131, 1, 17, 3, 0), 16.0),
#    (datetime.datetime(2131, 1, 17, 4, 0), 14.0),
#    (datetime.datetime(2131, 1, 17, 5, 0), 27.0),
#    (datetime.datetime(2131, 1, 17, 6, 0), 18.0),
#    (datetime.datetime(2131, 1, 17, 7, 0), 18.0),
#    (datetime.datetime(2131, 1, 17, 8, 0), 31.0),
#    (datetime.datetime(2131, 1, 17, 9, 0), 20.0),
#    (datetime.datetime(2131, 1, 17, 10, 0), 19.0),
#    (datetime.datetime(2131, 1, 17, 11, 0), 18.0),
#    (datetime.datetime(2131, 1, 17, 12, 0), 22.0),
#    (datetime.datetime(2131, 1, 17, 13, 0), 20.0),
#    (datetime.datetime(2131, 1, 17, 14, 0), 21.0),
#    (datetime.datetime(2131, 1, 17, 15, 0), 18.0),
#    (datetime.datetime(2131, 1, 17, 16, 0), 19.0),
#    (datetime.datetime(2131, 1, 17, 17, 0), 20.0),
#    (datetime.datetime(2131, 1, 17, 18, 0), 19.0),
#    (datetime.datetime(2131, 1, 17, 19, 0), 26.0),
#    (datetime.datetime(2131, 1, 17, 20, 0), 30.0),
#    (datetime.datetime(2131, 1, 17, 21, 0), 26.0),
#    (datetime.datetime(2131, 1, 17, 22, 0), 20.0),
#    (datetime.datetime(2131, 1, 17, 23, 0), 14.0),
#    (datetime.datetime(2131, 1, 18, 0, 0), 19.0),
#    (datetime.datetime(2131, 1, 18, 1, 0), 20.0),
#    (datetime.datetime(2131, 1, 18, 2, 0), 20.0),
#    (datetime.datetime(2131, 1, 18, 3, 0), 17.0),
#    (datetime.datetime(2131, 1, 18, 4, 0), 21.0),
#    (datetime.datetime(2131, 1, 18, 5, 0), 24.0),
#    (datetime.datetime(2131, 1, 18, 6, 0), 19.0),
#    (datetime.datetime(2131, 1, 18, 7, 0), 14.0),
#    (datetime.datetime(2131, 1, 18, 8, 0), 17.0),
#    (datetime.datetime(2131, 1, 18, 9, 0), 17.0),
#    (datetime.datetime(2131, 1, 18, 10, 0), 15.0),
#    (datetime.datetime(2131, 1, 18, 11, 0), 15.0),
#    (datetime.datetime(2131, 1, 18, 12, 0), 17.0),
#    (datetime.datetime(2131, 1, 18, 13, 0), 15.0),
#    (datetime.datetime(2131, 1, 18, 14, 0), 21.0),
#    (datetime.datetime(2131, 1, 18, 15, 0), 18.0),
#    (datetime.datetime(2131, 1, 18, 16, 0), 18.0),
#    (datetime.datetime(2131, 1, 18, 17, 0), 15.0),
#    (datetime.datetime(2131, 1, 18, 18, 0), 16.0),
#    (datetime.datetime(2131, 1, 18, 19, 0), 17.0),
#    (datetime.datetime(2131, 1, 18, 20, 0), 16.0),
#    (datetime.datetime(2131, 1, 18, 21, 0), 15.0),
#    (datetime.datetime(2131, 1, 18, 22, 0), 13.0),
#    (datetime.datetime(2131, 1, 18, 23, 0), 12.0),
#    (datetime.datetime(2131, 1, 19, 0, 0), 16.0),
#    (datetime.datetime(2131, 1, 19, 1, 0), 16.0),
#    (datetime.datetime(2131, 1, 19, 2, 0), 17.0),
#    (datetime.datetime(2131, 1, 19, 3, 0), 16.0),
#    (datetime.datetime(2131, 1, 19, 4, 0), 17.0),
#    (datetime.datetime(2131, 1, 19, 5, 0), 19.0),
#    (datetime.datetime(2131, 1, 19, 6, 0), 19.0),
#    (datetime.datetime(2131, 1, 19, 7, 0), 23.0),
#    (datetime.datetime(2131, 1, 19, 8, 0), 20.0),
#    (datetime.datetime(2131, 1, 19, 9, 0), 19.0),
#    (datetime.datetime(2131, 1, 19, 10, 0), 18.0),
#    (datetime.datetime(2131, 1, 19, 11, 0), 16.0),
#    (datetime.datetime(2131, 1, 19, 12, 0), 21.0),
#    (datetime.datetime(2131, 1, 19, 13, 0), 13.0),
#    (datetime.datetime(2131, 1, 19, 14, 0), 14.0),
#    (datetime.datetime(2131, 1, 19, 15, 0), 17.0),
#    (datetime.datetime(2131, 1, 19, 16, 0), 17.0),
#    (datetime.datetime(2131, 1, 19, 17, 0), 18.0),
#    (datetime.datetime(2131, 1, 19, 18, 0), 14.0),
#    (datetime.datetime(2131, 1, 19, 19, 0), 15.0),
#    (datetime.datetime(2131, 1, 19, 20, 0), 16.0),
#    (datetime.datetime(2131, 1, 19, 21, 0), 16.0),
#    (datetime.datetime(2131, 1, 19, 22, 0), 11.0),
#    (datetime.datetime(2131, 1, 19, 23, 0), 10.0),
#    (datetime.datetime(2131, 1, 20, 0, 0), 8.0),
#    (datetime.datetime(2131, 1, 20, 1, 0), 9.0),
#    (datetime.datetime(2131, 1, 20, 2, 0), 8.0),
#    (datetime.datetime(2131, 1, 20, 4, 0), 14.0)],
#   'PULSE': [(datetime.datetime(2131, 1, 11, 4, 22), 38.0),
#    (datetime.datetime(2131, 1, 11, 5, 0), 60.0),
#    (datetime.datetime(2131, 1, 11, 6, 0), 72.0),
#    (datetime.datetime(2131, 1, 11, 6, 44), 71.0),
#    (datetime.datetime(2131, 1, 11, 6, 47), 71.0),
#    (datetime.datetime(2131, 1, 11, 7, 0), 70.0),
#    (datetime.datetime(2131, 1, 11, 8, 0), 71.0),
#    (datetime.datetime(2131, 1, 11, 9, 0), 71.0),
#    (datetime.datetime(2131, 1, 11, 10, 0), 70.0),
#    (datetime.datetime(2131, 1, 11, 11, 0), 70.0),
#    (datetime.datetime(2131, 1, 11, 12, 0), 70.0),
#    (datetime.datetime(2131, 1, 11, 13, 0), 70.0),
#    (datetime.datetime(2131, 1, 11, 14, 0), 70.0),
#    (datetime.datetime(2131, 1, 11, 15, 0), 71.0),
#    (datetime.datetime(2131, 1, 11, 16, 0), 70.0),
#    (datetime.datetime(2131, 1, 11, 17, 0), 73.0),
#    (datetime.datetime(2131, 1, 11, 18, 0), 73.0),
#    (datetime.datetime(2131, 1, 11, 19, 0), 75.0),
#    (datetime.datetime(2131, 1, 11, 20, 0), 76.0),
#    (datetime.datetime(2131, 1, 11, 21, 0), 74.0),
#    (datetime.datetime(2131, 1, 11, 21, 37), 78.0),
#    (datetime.datetime(2131, 1, 11, 22, 0), 74.0),
#    (datetime.datetime(2131, 1, 11, 23, 0), 73.0),
#    (datetime.datetime(2131, 1, 12, 0, 0), 74.0),
#    (datetime.datetime(2131, 1, 12, 1, 0), 79.0),
#    (datetime.datetime(2131, 1, 12, 2, 0), 80.0),
#    (datetime.datetime(2131, 1, 12, 3, 0), 77.0),
#    (datetime.datetime(2131, 1, 12, 4, 0), 78.0),
#    (datetime.datetime(2131, 1, 12, 5, 0), 71.0),
#    (datetime.datetime(2131, 1, 12, 6, 0), 71.0),
#    (datetime.datetime(2131, 1, 12, 7, 0), 85.0),
#    (datetime.datetime(2131, 1, 12, 8, 0), 85.0),
#    (datetime.datetime(2131, 1, 12, 9, 0), 85.0),
#    (datetime.datetime(2131, 1, 12, 10, 0), 80.0),
#    (datetime.datetime(2131, 1, 12, 11, 0), 75.0),
#    (datetime.datetime(2131, 1, 12, 11, 4), 79.0),
#    (datetime.datetime(2131, 1, 12, 12, 0), 51.0),
#    (datetime.datetime(2131, 1, 12, 12, 4), 60.0),
#    (datetime.datetime(2131, 1, 12, 13, 0), 79.0),
#    (datetime.datetime(2131, 1, 12, 13, 4), 80.0),
#    (datetime.datetime(2131, 1, 12, 14, 0), 81.0),
#    (datetime.datetime(2131, 1, 12, 14, 4), 79.0),
#    (datetime.datetime(2131, 1, 12, 15, 0), 78.0),
#    (datetime.datetime(2131, 1, 12, 15, 4), 79.0),
#    (datetime.datetime(2131, 1, 12, 16, 0), 77.0),
#    (datetime.datetime(2131, 1, 12, 16, 4), 77.0),
#    (datetime.datetime(2131, 1, 12, 17, 0), 76.0),
#    (datetime.datetime(2131, 1, 12, 17, 4), 80.0),
#    (datetime.datetime(2131, 1, 12, 18, 0), 57.0),
#    (datetime.datetime(2131, 1, 12, 18, 4), 63.0),
#    (datetime.datetime(2131, 1, 12, 19, 0), 83.0),
#    (datetime.datetime(2131, 1, 12, 20, 0), 78.0),
#    (datetime.datetime(2131, 1, 12, 21, 0), 78.0),
#    (datetime.datetime(2131, 1, 12, 22, 0), 82.0),
#    (datetime.datetime(2131, 1, 12, 23, 0), 56.0),
#    (datetime.datetime(2131, 1, 13, 0, 0), 80.0),
#    (datetime.datetime(2131, 1, 13, 1, 0), 76.0),
#    (datetime.datetime(2131, 1, 13, 2, 0), 79.0),
#    (datetime.datetime(2131, 1, 13, 3, 0), 50.0),
#    (datetime.datetime(2131, 1, 13, 4, 0), 50.0),
#    (datetime.datetime(2131, 1, 13, 5, 0), 50.0),
#    (datetime.datetime(2131, 1, 13, 6, 0), 47.0),
#    (datetime.datetime(2131, 1, 13, 7, 0), 52.0),
#    (datetime.datetime(2131, 1, 13, 8, 0), 53.0),
#    (datetime.datetime(2131, 1, 13, 9, 0), 50.0),
#    (datetime.datetime(2131, 1, 13, 10, 0), 50.0),
#    (datetime.datetime(2131, 1, 13, 11, 0), 57.0),
#    (datetime.datetime(2131, 1, 13, 12, 0), 50.0),
#    (datetime.datetime(2131, 1, 13, 13, 0), 54.0),
#    (datetime.datetime(2131, 1, 13, 14, 0), 57.0),
#    (datetime.datetime(2131, 1, 13, 15, 0), 76.0),
#    (datetime.datetime(2131, 1, 13, 16, 0), 75.0),
#    (datetime.datetime(2131, 1, 13, 17, 0), 76.0),
#    (datetime.datetime(2131, 1, 13, 18, 0), 75.0),
#    (datetime.datetime(2131, 1, 13, 19, 0), 79.0),
#    (datetime.datetime(2131, 1, 13, 20, 0), 78.0),
#    (datetime.datetime(2131, 1, 13, 21, 0), 80.0),
#    (datetime.datetime(2131, 1, 13, 22, 0), 77.0),
#    (datetime.datetime(2131, 1, 13, 23, 0), 73.0),
#    (datetime.datetime(2131, 1, 14, 0, 0), 74.0),
#    (datetime.datetime(2131, 1, 14, 1, 0), 71.0),
#    (datetime.datetime(2131, 1, 14, 2, 0), 71.0),
#    (datetime.datetime(2131, 1, 14, 3, 0), 71.0),
#    (datetime.datetime(2131, 1, 14, 4, 0), 72.0),
#    (datetime.datetime(2131, 1, 14, 5, 0), 71.0),
#    (datetime.datetime(2131, 1, 14, 6, 0), 72.0),
#    (datetime.datetime(2131, 1, 14, 7, 0), 77.0),
#    (datetime.datetime(2131, 1, 14, 8, 0), 79.0),
#    (datetime.datetime(2131, 1, 14, 9, 0), 75.0),
#    (datetime.datetime(2131, 1, 14, 10, 0), 76.0),
#    (datetime.datetime(2131, 1, 14, 13, 33), 70.0),
#    (datetime.datetime(2131, 1, 14, 14, 0), 77.0),
#    (datetime.datetime(2131, 1, 14, 15, 0), 79.0),
#    (datetime.datetime(2131, 1, 14, 16, 0), 79.0),
#    (datetime.datetime(2131, 1, 14, 17, 0), 77.0),
#    (datetime.datetime(2131, 1, 14, 18, 0), 76.0),
#    (datetime.datetime(2131, 1, 14, 19, 0), 75.0),
#    (datetime.datetime(2131, 1, 14, 20, 0), 74.0),
#    (datetime.datetime(2131, 1, 14, 21, 0), 72.0),
#    (datetime.datetime(2131, 1, 14, 22, 0), 73.0),
#    (datetime.datetime(2131, 1, 14, 23, 0), 73.0),
#    (datetime.datetime(2131, 1, 15, 0, 0), 72.0),
#    (datetime.datetime(2131, 1, 15, 1, 0), 75.0),
#    (datetime.datetime(2131, 1, 15, 2, 0), 74.0),
#    (datetime.datetime(2131, 1, 15, 3, 0), 72.0),
#    (datetime.datetime(2131, 1, 15, 4, 0), 72.0),
#    (datetime.datetime(2131, 1, 15, 5, 0), 74.0),
#    (datetime.datetime(2131, 1, 15, 6, 0), 74.0),
#    (datetime.datetime(2131, 1, 15, 7, 0), 74.0),
#    (datetime.datetime(2131, 1, 15, 8, 0), 74.0),
#    (datetime.datetime(2131, 1, 15, 9, 0), 70.0),
#    (datetime.datetime(2131, 1, 15, 10, 0), 71.0),
#    (datetime.datetime(2131, 1, 15, 11, 0), 71.0),
#    (datetime.datetime(2131, 1, 15, 12, 0), 73.0),
#    (datetime.datetime(2131, 1, 15, 13, 0), 71.0),
#    (datetime.datetime(2131, 1, 15, 14, 0), 70.0),
#    (datetime.datetime(2131, 1, 15, 15, 0), 70.0),
#    (datetime.datetime(2131, 1, 15, 16, 0), 69.0),
#    (datetime.datetime(2131, 1, 15, 17, 0), 71.0),
#    (datetime.datetime(2131, 1, 15, 18, 0), 70.0),
#    (datetime.datetime(2131, 1, 15, 19, 0), 72.0),
#    (datetime.datetime(2131, 1, 15, 20, 0), 73.0),
#    (datetime.datetime(2131, 1, 15, 21, 0), 75.0),
#    (datetime.datetime(2131, 1, 15, 22, 0), 68.0),
#    (datetime.datetime(2131, 1, 15, 23, 0), 76.0),
#    (datetime.datetime(2131, 1, 16, 0, 0), 73.0),
#    (datetime.datetime(2131, 1, 16, 1, 0), 73.0),
#    (datetime.datetime(2131, 1, 16, 2, 0), 72.0),
#    (datetime.datetime(2131, 1, 16, 3, 0), 68.0),
#    (datetime.datetime(2131, 1, 16, 4, 0), 71.0),
#    (datetime.datetime(2131, 1, 16, 5, 0), 72.0),
#    (datetime.datetime(2131, 1, 16, 6, 0), 72.0),
#    (datetime.datetime(2131, 1, 16, 7, 0), 74.0),
#    (datetime.datetime(2131, 1, 16, 8, 0), 71.0),
#    (datetime.datetime(2131, 1, 16, 9, 0), 73.0),
#    (datetime.datetime(2131, 1, 16, 10, 0), 67.0),
#    (datetime.datetime(2131, 1, 16, 11, 0), 68.0),
#    (datetime.datetime(2131, 1, 16, 12, 0), 79.0),
#    (datetime.datetime(2131, 1, 16, 13, 0), 72.0),
#    (datetime.datetime(2131, 1, 16, 14, 0), 71.0),
#    (datetime.datetime(2131, 1, 16, 15, 0), 70.0),
#    (datetime.datetime(2131, 1, 16, 16, 0), 72.0),
#    (datetime.datetime(2131, 1, 16, 17, 0), 70.0),
#    (datetime.datetime(2131, 1, 16, 18, 0), 73.0),
#    (datetime.datetime(2131, 1, 16, 19, 0), 72.0),
#    (datetime.datetime(2131, 1, 16, 20, 0), 70.0),
#    (datetime.datetime(2131, 1, 16, 21, 0), 75.0),
#    (datetime.datetime(2131, 1, 16, 22, 0), 70.0),
#    (datetime.datetime(2131, 1, 16, 23, 0), 77.0),
#    (datetime.datetime(2131, 1, 17, 0, 0), 74.0),
#    (datetime.datetime(2131, 1, 17, 1, 0), 73.0),
#    (datetime.datetime(2131, 1, 17, 2, 0), 71.0),
#    (datetime.datetime(2131, 1, 17, 3, 0), 72.0),
#    (datetime.datetime(2131, 1, 17, 4, 0), 71.0),
#    (datetime.datetime(2131, 1, 17, 5, 0), 72.0),
#    (datetime.datetime(2131, 1, 17, 6, 0), 70.0),
#    (datetime.datetime(2131, 1, 17, 7, 0), 70.0),
#    (datetime.datetime(2131, 1, 17, 8, 0), 70.0),
#    (datetime.datetime(2131, 1, 17, 9, 0), 72.0),
#    (datetime.datetime(2131, 1, 17, 10, 0), 73.0),
#    (datetime.datetime(2131, 1, 17, 11, 0), 70.0),
#    (datetime.datetime(2131, 1, 17, 12, 0), 68.0),
#    (datetime.datetime(2131, 1, 17, 13, 0), 70.0),
#    (datetime.datetime(2131, 1, 17, 14, 0), 71.0),
#    (datetime.datetime(2131, 1, 17, 15, 0), 72.0),
#    (datetime.datetime(2131, 1, 17, 16, 0), 69.0),
#    (datetime.datetime(2131, 1, 17, 17, 0), 69.0),
#    (datetime.datetime(2131, 1, 17, 18, 0), 65.0),
#    (datetime.datetime(2131, 1, 17, 19, 0), 71.0),
#    (datetime.datetime(2131, 1, 17, 20, 0), 70.0),
#    (datetime.datetime(2131, 1, 17, 21, 0), 70.0),
#    (datetime.datetime(2131, 1, 17, 22, 0), 71.0),
#    (datetime.datetime(2131, 1, 17, 23, 0), 73.0),
#    (datetime.datetime(2131, 1, 18, 0, 0), 77.0),
#    (datetime.datetime(2131, 1, 18, 1, 0), 68.0),
#    (datetime.datetime(2131, 1, 18, 2, 0), 70.0),
#    (datetime.datetime(2131, 1, 18, 3, 0), 67.0),
#    (datetime.datetime(2131, 1, 18, 4, 0), 68.0),
#    (datetime.datetime(2131, 1, 18, 5, 0), 70.0),
#    (datetime.datetime(2131, 1, 18, 6, 0), 64.0),
#    (datetime.datetime(2131, 1, 18, 7, 0), 68.0),
#    (datetime.datetime(2131, 1, 18, 8, 0), 67.0),
#    (datetime.datetime(2131, 1, 18, 9, 0), 67.0),
#    (datetime.datetime(2131, 1, 18, 10, 0), 68.0),
#    (datetime.datetime(2131, 1, 18, 11, 0), 67.0),
#    (datetime.datetime(2131, 1, 18, 12, 0), 69.0),
#    (datetime.datetime(2131, 1, 18, 13, 0), 70.0),
#    (datetime.datetime(2131, 1, 18, 14, 0), 67.0),
#    (datetime.datetime(2131, 1, 18, 15, 0), 73.0),
#    (datetime.datetime(2131, 1, 18, 16, 0), 68.0),
#    (datetime.datetime(2131, 1, 18, 17, 0), 68.0),
#    (datetime.datetime(2131, 1, 18, 18, 0), 71.0),
#    (datetime.datetime(2131, 1, 18, 19, 0), 69.0),
#    (datetime.datetime(2131, 1, 18, 20, 0), 70.0),
#    (datetime.datetime(2131, 1, 18, 21, 0), 72.0),
#    (datetime.datetime(2131, 1, 18, 22, 0), 65.0),
#    (datetime.datetime(2131, 1, 18, 23, 0), 63.0),
#    (datetime.datetime(2131, 1, 19, 0, 0), 67.0),
#    (datetime.datetime(2131, 1, 19, 1, 0), 66.0),
#    (datetime.datetime(2131, 1, 19, 2, 0), 68.0),
#    (datetime.datetime(2131, 1, 19, 3, 0), 65.0),
#    (datetime.datetime(2131, 1, 19, 4, 0), 67.0),
#    (datetime.datetime(2131, 1, 19, 5, 0), 68.0),
#    (datetime.datetime(2131, 1, 19, 6, 0), 65.0),
#    (datetime.datetime(2131, 1, 19, 7, 0), 63.0),
#    (datetime.datetime(2131, 1, 19, 8, 0), 63.0),
#    (datetime.datetime(2131, 1, 19, 9, 0), 66.0),
#    (datetime.datetime(2131, 1, 19, 10, 0), 66.0),
#    (datetime.datetime(2131, 1, 19, 11, 0), 65.0),
#    (datetime.datetime(2131, 1, 19, 12, 0), 66.0),
#    (datetime.datetime(2131, 1, 19, 13, 0), 66.0),
#    (datetime.datetime(2131, 1, 19, 14, 0), 67.0),
#    (datetime.datetime(2131, 1, 19, 15, 0), 66.0),
#    (datetime.datetime(2131, 1, 19, 16, 0), 63.0),
#    (datetime.datetime(2131, 1, 19, 17, 0), 64.0),
#    (datetime.datetime(2131, 1, 19, 18, 0), 70.0),
#    (datetime.datetime(2131, 1, 19, 19, 0), 71.0),
#    (datetime.datetime(2131, 1, 19, 20, 0), 74.0),
#    (datetime.datetime(2131, 1, 19, 21, 0), 74.0),
#    (datetime.datetime(2131, 1, 19, 22, 0), 72.0),
#    (datetime.datetime(2131, 1, 19, 23, 0), 74.0),
#    (datetime.datetime(2131, 1, 20, 0, 0), 77.0),
#    (datetime.datetime(2131, 1, 20, 1, 0), 87.0),
#    (datetime.datetime(2131, 1, 20, 2, 0), 75.0),
#    (datetime.datetime(2131, 1, 20, 4, 0), 74.0)],
#   'SBP': [(datetime.datetime(2131, 1, 11, 4, 25), 180.0),
#    (datetime.datetime(2131, 1, 11, 5, 1), 167.0),
#    (datetime.datetime(2131, 1, 11, 6, 1), 102.0),
#    (datetime.datetime(2131, 1, 11, 6, 47), 110.0),
#    (datetime.datetime(2131, 1, 11, 7, 1), 93.0),
#    (datetime.datetime(2131, 1, 11, 8, 1), 102.0),
#    (datetime.datetime(2131, 1, 11, 9, 1), 138.0),
#    (datetime.datetime(2131, 1, 11, 10, 1), 116.0),
#    (datetime.datetime(2131, 1, 11, 11, 1), 96.0),
#    (datetime.datetime(2131, 1, 11, 12, 1), 98.0),
#    (datetime.datetime(2131, 1, 11, 13, 1), 110.0),
#    (datetime.datetime(2131, 1, 11, 14, 1), 106.0),
#    (datetime.datetime(2131, 1, 11, 15, 1), 114.0),
#    (datetime.datetime(2131, 1, 11, 16, 1), 138.0),
#    (datetime.datetime(2131, 1, 11, 17, 1), 158.0),
#    (datetime.datetime(2131, 1, 11, 18, 1), 135.0),
#    (datetime.datetime(2131, 1, 11, 19, 1), 127.0),
#    (datetime.datetime(2131, 1, 11, 20, 1), 151.0),
#    (datetime.datetime(2131, 1, 11, 21, 1), 116.0),
#    (datetime.datetime(2131, 1, 11, 22, 1), 116.0),
#    (datetime.datetime(2131, 1, 11, 23, 1), 129.0),
#    (datetime.datetime(2131, 1, 12, 0, 1), 154.0),
#    (datetime.datetime(2131, 1, 12, 1, 1), 111.0),
#    (datetime.datetime(2131, 1, 12, 2, 1), 114.0),
#    (datetime.datetime(2131, 1, 12, 3, 1), 117.0),
#    (datetime.datetime(2131, 1, 12, 4, 1), 119.0),
#    (datetime.datetime(2131, 1, 12, 5, 1), 143.0),
#    (datetime.datetime(2131, 1, 12, 6, 1), 145.0),
#    (datetime.datetime(2131, 1, 12, 7, 1), 134.0),
#    (datetime.datetime(2131, 1, 12, 8, 1), 136.0),
#    (datetime.datetime(2131, 1, 12, 9, 1), 113.0),
#    (datetime.datetime(2131, 1, 12, 10, 1), 135.0),
#    (datetime.datetime(2131, 1, 12, 11, 1), 129.0),
#    (datetime.datetime(2131, 1, 12, 11, 31), 134.0),
#    (datetime.datetime(2131, 1, 12, 12, 1), 139.0),
#    (datetime.datetime(2131, 1, 12, 12, 31), 137.0),
#    (datetime.datetime(2131, 1, 12, 13, 1), 132.0),
#    (datetime.datetime(2131, 1, 12, 13, 31), 135.0),
#    (datetime.datetime(2131, 1, 12, 14, 1), 112.0),
#    (datetime.datetime(2131, 1, 12, 14, 31), 116.0),
#    (datetime.datetime(2131, 1, 12, 15, 1), 127.0),
#    (datetime.datetime(2131, 1, 12, 15, 31), 128.0),
#    (datetime.datetime(2131, 1, 12, 16, 1), 137.0),
#    (datetime.datetime(2131, 1, 12, 16, 31), 133.0),
#    (datetime.datetime(2131, 1, 12, 17, 1), 131.0),
#    (datetime.datetime(2131, 1, 12, 17, 31), 116.0),
#    (datetime.datetime(2131, 1, 12, 18, 1), 161.0),
#    (datetime.datetime(2131, 1, 12, 18, 31), 173.0),
#    (datetime.datetime(2131, 1, 12, 19, 1), 148.0),
#    (datetime.datetime(2131, 1, 12, 20, 1), 149.0),
#    (datetime.datetime(2131, 1, 12, 21, 1), 145.0),
#    (datetime.datetime(2131, 1, 12, 22, 1), 144.0),
#    (datetime.datetime(2131, 1, 12, 23, 1), 161.0),
#    (datetime.datetime(2131, 1, 13, 0, 1), 151.0),
#    (datetime.datetime(2131, 1, 13, 1, 1), 151.0),
#    (datetime.datetime(2131, 1, 13, 2, 1), 157.0),
#    (datetime.datetime(2131, 1, 13, 3, 1), 157.0),
#    (datetime.datetime(2131, 1, 13, 4, 2), 182.0),
#    (datetime.datetime(2131, 1, 13, 5, 1), 193.0),
#    (datetime.datetime(2131, 1, 13, 6, 1), 132.0),
#    (datetime.datetime(2131, 1, 13, 7, 1), 126.0),
#    (datetime.datetime(2131, 1, 13, 8, 1), 121.0),
#    (datetime.datetime(2131, 1, 13, 9, 1), 140.0),
#    (datetime.datetime(2131, 1, 13, 10, 1), 136.0),
#    (datetime.datetime(2131, 1, 13, 11, 1), 145.0),
#    (datetime.datetime(2131, 1, 13, 12, 1), 136.0),
#    (datetime.datetime(2131, 1, 13, 13, 1), 145.0),
#    (datetime.datetime(2131, 1, 13, 14, 1), 127.0),
#    (datetime.datetime(2131, 1, 13, 15, 1), 135.0),
#    (datetime.datetime(2131, 1, 13, 16, 1), 149.0),
#    (datetime.datetime(2131, 1, 13, 17, 1), 147.0),
#    (datetime.datetime(2131, 1, 13, 18, 1), 153.0),
#    (datetime.datetime(2131, 1, 13, 19, 1), 140.0),
#    (datetime.datetime(2131, 1, 13, 20, 1), 146.0),
#    (datetime.datetime(2131, 1, 13, 21, 1), 145.0),
#    (datetime.datetime(2131, 1, 13, 22, 1), 147.0),
#    (datetime.datetime(2131, 1, 13, 23, 1), 125.0),
#    (datetime.datetime(2131, 1, 14, 0, 1), 131.0),
#    (datetime.datetime(2131, 1, 14, 1, 1), 131.0),
#    (datetime.datetime(2131, 1, 14, 2, 1), 129.0),
#    (datetime.datetime(2131, 1, 14, 3, 1), 139.0),
#    (datetime.datetime(2131, 1, 14, 4, 1), 136.0),
#    (datetime.datetime(2131, 1, 14, 5, 1), 142.0),
#    (datetime.datetime(2131, 1, 14, 6, 1), 140.0),
#    (datetime.datetime(2131, 1, 14, 7, 1), 120.0),
#    (datetime.datetime(2131, 1, 14, 8, 1), 127.0),
#    (datetime.datetime(2131, 1, 14, 9, 1), 136.0),
#    (datetime.datetime(2131, 1, 14, 10, 31), 146.0),
#    (datetime.datetime(2131, 1, 14, 13, 38), 134.0),
#    (datetime.datetime(2131, 1, 14, 14, 0), 133.0),
#    (datetime.datetime(2131, 1, 14, 15, 16), 151.0),
#    (datetime.datetime(2131, 1, 14, 16, 1), 153.0),
#    (datetime.datetime(2131, 1, 14, 17, 31), 149.0),
#    (datetime.datetime(2131, 1, 14, 18, 16), 145.0),
#    (datetime.datetime(2131, 1, 14, 19, 1), 136.0),
#    (datetime.datetime(2131, 1, 14, 20, 1), 135.0),
#    (datetime.datetime(2131, 1, 14, 21, 1), 138.0),
#    (datetime.datetime(2131, 1, 14, 22, 1), 129.0),
#    (datetime.datetime(2131, 1, 14, 23, 1), 130.0),
#    (datetime.datetime(2131, 1, 15, 0, 1), 129.0),
#    (datetime.datetime(2131, 1, 15, 1, 1), 118.0),
#    (datetime.datetime(2131, 1, 15, 2, 1), 124.0),
#    (datetime.datetime(2131, 1, 15, 3, 1), 132.0),
#    (datetime.datetime(2131, 1, 15, 4, 1), 119.0),
#    (datetime.datetime(2131, 1, 15, 5, 1), 124.0),
#    (datetime.datetime(2131, 1, 15, 6, 1), 125.0),
#    (datetime.datetime(2131, 1, 15, 7, 1), 122.0),
#    (datetime.datetime(2131, 1, 15, 8, 1), 121.0),
#    (datetime.datetime(2131, 1, 15, 9, 1), 134.0),
#    (datetime.datetime(2131, 1, 15, 10, 1), 135.0),
#    (datetime.datetime(2131, 1, 15, 11, 1), 136.0),
#    (datetime.datetime(2131, 1, 15, 12, 1), 122.0),
#    (datetime.datetime(2131, 1, 15, 13, 1), 129.0),
#    (datetime.datetime(2131, 1, 15, 14, 1), 131.0),
#    (datetime.datetime(2131, 1, 15, 15, 1), 110.0),
#    (datetime.datetime(2131, 1, 15, 16, 1), 131.0),
#    (datetime.datetime(2131, 1, 15, 17, 1), 120.0),
#    (datetime.datetime(2131, 1, 15, 18, 1), 124.0),
#    (datetime.datetime(2131, 1, 15, 19, 1), 129.0),
#    (datetime.datetime(2131, 1, 15, 20, 1), 129.0),
#    (datetime.datetime(2131, 1, 15, 21, 1), 143.0),
#    (datetime.datetime(2131, 1, 15, 22, 1), 125.0),
#    (datetime.datetime(2131, 1, 15, 23, 1), 137.0),
#    (datetime.datetime(2131, 1, 16, 0, 1), 131.0),
#    (datetime.datetime(2131, 1, 16, 1, 1), 127.0),
#    (datetime.datetime(2131, 1, 16, 2, 1), 126.0),
#    (datetime.datetime(2131, 1, 16, 3, 1), 130.0),
#    (datetime.datetime(2131, 1, 16, 4, 1), 130.0),
#    (datetime.datetime(2131, 1, 16, 5, 1), 122.0),
#    (datetime.datetime(2131, 1, 16, 6, 1), 127.0),
#    (datetime.datetime(2131, 1, 16, 7, 1), 129.0),
#    (datetime.datetime(2131, 1, 16, 8, 1), 127.0),
#    (datetime.datetime(2131, 1, 16, 9, 1), 128.0),
#    (datetime.datetime(2131, 1, 16, 10, 1), 136.0),
#    (datetime.datetime(2131, 1, 16, 11, 1), 150.0),
#    (datetime.datetime(2131, 1, 16, 12, 1), 124.0),
#    (datetime.datetime(2131, 1, 16, 13, 1), 119.0),
#    (datetime.datetime(2131, 1, 16, 14, 1), 121.0),
#    (datetime.datetime(2131, 1, 16, 15, 1), 114.0),
#    (datetime.datetime(2131, 1, 16, 16, 1), 131.0),
#    (datetime.datetime(2131, 1, 16, 17, 1), 122.0),
#    (datetime.datetime(2131, 1, 16, 18, 1), 133.0),
#    (datetime.datetime(2131, 1, 16, 19, 1), 128.0),
#    (datetime.datetime(2131, 1, 16, 20, 1), 142.0),
#    (datetime.datetime(2131, 1, 16, 21, 1), 111.0),
#    (datetime.datetime(2131, 1, 16, 22, 1), 136.0),
#    (datetime.datetime(2131, 1, 16, 23, 1), 126.0),
#    (datetime.datetime(2131, 1, 17, 0, 1), 125.0),
#    (datetime.datetime(2131, 1, 17, 1, 1), 122.0),
#    (datetime.datetime(2131, 1, 17, 2, 1), 115.0),
#    (datetime.datetime(2131, 1, 17, 3, 1), 128.0),
#    (datetime.datetime(2131, 1, 17, 4, 1), 120.0),
#    (datetime.datetime(2131, 1, 17, 5, 1), 131.0),
#    (datetime.datetime(2131, 1, 17, 6, 1), 125.0),
#    (datetime.datetime(2131, 1, 17, 7, 1), 121.0),
#    (datetime.datetime(2131, 1, 17, 8, 1), 139.0),
#    (datetime.datetime(2131, 1, 17, 9, 2), 115.0),
#    (datetime.datetime(2131, 1, 17, 10, 1), 109.0),
#    (datetime.datetime(2131, 1, 17, 11, 1), 107.0),
#    (datetime.datetime(2131, 1, 17, 12, 1), 119.0),
#    (datetime.datetime(2131, 1, 17, 13, 1), 114.0),
#    (datetime.datetime(2131, 1, 17, 14, 1), 131.0),
#    (datetime.datetime(2131, 1, 17, 15, 1), 138.0),
#    (datetime.datetime(2131, 1, 17, 16, 1), 120.0),
#    (datetime.datetime(2131, 1, 17, 17, 1), 119.0),
#    (datetime.datetime(2131, 1, 17, 18, 1), 126.0),
#    (datetime.datetime(2131, 1, 17, 19, 1), 115.0),
#    (datetime.datetime(2131, 1, 17, 20, 1), 118.0),
#    (datetime.datetime(2131, 1, 17, 21, 1), 126.0),
#    (datetime.datetime(2131, 1, 17, 22, 1), 118.0),
#    (datetime.datetime(2131, 1, 17, 23, 1), 130.0),
#    (datetime.datetime(2131, 1, 18, 0, 1), 114.0),
#    (datetime.datetime(2131, 1, 18, 1, 1), 133.0),
#    (datetime.datetime(2131, 1, 18, 2, 1), 137.0),
#    (datetime.datetime(2131, 1, 18, 3, 1), 120.0),
#    (datetime.datetime(2131, 1, 18, 4, 1), 121.0),
#    (datetime.datetime(2131, 1, 18, 5, 1), 119.0),
#    (datetime.datetime(2131, 1, 18, 6, 1), 113.0),
#    (datetime.datetime(2131, 1, 18, 7, 1), 110.0),
#    (datetime.datetime(2131, 1, 18, 8, 1), 140.0),
#    (datetime.datetime(2131, 1, 18, 9, 4), 128.0),
#    (datetime.datetime(2131, 1, 18, 10, 1), 112.0),
#    (datetime.datetime(2131, 1, 18, 11, 1), 120.0),
#    (datetime.datetime(2131, 1, 18, 12, 1), 124.0),
#    (datetime.datetime(2131, 1, 18, 13, 1), 132.0),
#    (datetime.datetime(2131, 1, 18, 14, 1), 125.0),
#    (datetime.datetime(2131, 1, 18, 15, 1), 115.0),
#    (datetime.datetime(2131, 1, 18, 16, 1), 120.0),
#    (datetime.datetime(2131, 1, 18, 17, 1), 103.0),
#    (datetime.datetime(2131, 1, 18, 18, 0), 93.0),
#    (datetime.datetime(2131, 1, 18, 19, 1), 122.0),
#    (datetime.datetime(2131, 1, 18, 20, 1), 120.0),
#    (datetime.datetime(2131, 1, 18, 21, 1), 137.0),
#    (datetime.datetime(2131, 1, 18, 22, 1), 94.0),
#    (datetime.datetime(2131, 1, 18, 23, 1), 117.0),
#    (datetime.datetime(2131, 1, 19, 0, 1), 117.0),
#    (datetime.datetime(2131, 1, 19, 1, 1), 123.0),
#    (datetime.datetime(2131, 1, 19, 2, 1), 132.0),
#    (datetime.datetime(2131, 1, 19, 3, 1), 109.0),
#    (datetime.datetime(2131, 1, 19, 4, 1), 116.0),
#    (datetime.datetime(2131, 1, 19, 5, 1), 138.0),
#    (datetime.datetime(2131, 1, 19, 6, 1), 121.0),
#    (datetime.datetime(2131, 1, 19, 7, 1), 123.0),
#    (datetime.datetime(2131, 1, 19, 8, 1), 125.0),
#    (datetime.datetime(2131, 1, 19, 9, 1), 107.0),
#    (datetime.datetime(2131, 1, 19, 10, 1), 118.0),
#    (datetime.datetime(2131, 1, 19, 11, 1), 118.0),
#    (datetime.datetime(2131, 1, 19, 12, 1), 131.0),
#    (datetime.datetime(2131, 1, 19, 13, 1), 116.0),
#    (datetime.datetime(2131, 1, 19, 14, 1), 124.0),
#    (datetime.datetime(2131, 1, 19, 15, 1), 113.0),
#    (datetime.datetime(2131, 1, 19, 16, 1), 118.0),
#    (datetime.datetime(2131, 1, 19, 17, 1), 126.0),
#    (datetime.datetime(2131, 1, 19, 18, 1), 118.0),
#    (datetime.datetime(2131, 1, 19, 19, 1), 135.0),
#    (datetime.datetime(2131, 1, 19, 20, 1), 132.0),
#    (datetime.datetime(2131, 1, 19, 21, 1), 136.0),
#    (datetime.datetime(2131, 1, 19, 22, 1), 146.0),
#    (datetime.datetime(2131, 1, 19, 23, 1), 148.0),
#    (datetime.datetime(2131, 1, 20, 0, 1), 147.0),
#    (datetime.datetime(2131, 1, 20, 4, 19), 86.0)],
#   'DBP': [(datetime.datetime(2131, 1, 11, 4, 25), 12.0),
#    (datetime.datetime(2131, 1, 11, 5, 1), 49.0),
#    (datetime.datetime(2131, 1, 11, 6, 1), 63.0),
#    (datetime.datetime(2131, 1, 11, 6, 47), 76.0),
#    (datetime.datetime(2131, 1, 11, 7, 1), 62.0),
#    (datetime.datetime(2131, 1, 11, 8, 1), 71.0),
#    (datetime.datetime(2131, 1, 11, 9, 1), 76.0),
#    (datetime.datetime(2131, 1, 11, 10, 1), 66.0),
#    (datetime.datetime(2131, 1, 11, 11, 1), 60.0),
#    (datetime.datetime(2131, 1, 11, 12, 1), 72.0),
#    (datetime.datetime(2131, 1, 11, 13, 1), 77.0),
#    (datetime.datetime(2131, 1, 11, 14, 1), 75.0),
#    (datetime.datetime(2131, 1, 11, 15, 1), 69.0),
#    (datetime.datetime(2131, 1, 11, 16, 1), 123.0),
#    (datetime.datetime(2131, 1, 11, 17, 1), 91.0),
#    (datetime.datetime(2131, 1, 11, 18, 1), 86.0),
#    (datetime.datetime(2131, 1, 11, 19, 1), 73.0),
#    (datetime.datetime(2131, 1, 11, 20, 1), 96.0),
#    (datetime.datetime(2131, 1, 11, 21, 1), 75.0),
#    (datetime.datetime(2131, 1, 11, 22, 1), 75.0),
#    (datetime.datetime(2131, 1, 11, 23, 1), 81.0),
#    (datetime.datetime(2131, 1, 12, 0, 1), 79.0),
#    (datetime.datetime(2131, 1, 12, 1, 1), 70.0),
#    (datetime.datetime(2131, 1, 12, 2, 1), 68.0),
#    (datetime.datetime(2131, 1, 12, 3, 1), 73.0),
#    (datetime.datetime(2131, 1, 12, 4, 1), 77.0),
#    (datetime.datetime(2131, 1, 12, 5, 1), 82.0),
#    (datetime.datetime(2131, 1, 12, 6, 1), 93.0),
#    (datetime.datetime(2131, 1, 12, 7, 1), 83.0),
#    (datetime.datetime(2131, 1, 12, 8, 1), 88.0),
#    (datetime.datetime(2131, 1, 12, 9, 1), 74.0),
#    (datetime.datetime(2131, 1, 12, 10, 1), 78.0),
#    (datetime.datetime(2131, 1, 12, 11, 1), 77.0),
#    (datetime.datetime(2131, 1, 12, 11, 31), 69.0),
#    (datetime.datetime(2131, 1, 12, 12, 1), 65.0),
#    (datetime.datetime(2131, 1, 12, 12, 31), 84.0),
#    (datetime.datetime(2131, 1, 12, 13, 1), 78.0),
#    (datetime.datetime(2131, 1, 12, 13, 31), 73.0),
#    (datetime.datetime(2131, 1, 12, 14, 1), 76.0),
#    (datetime.datetime(2131, 1, 12, 14, 31), 70.0),
#    (datetime.datetime(2131, 1, 12, 15, 1), 78.0),
#    (datetime.datetime(2131, 1, 12, 15, 31), 73.0),
#    (datetime.datetime(2131, 1, 12, 16, 1), 75.0),
#    (datetime.datetime(2131, 1, 12, 16, 31), 80.0),
#    (datetime.datetime(2131, 1, 12, 17, 1), 77.0),
#    (datetime.datetime(2131, 1, 12, 17, 31), 68.0),
#    (datetime.datetime(2131, 1, 12, 18, 1), 109.0),
#    (datetime.datetime(2131, 1, 12, 18, 31), 88.0),
#    (datetime.datetime(2131, 1, 12, 19, 1), 79.0),
#    (datetime.datetime(2131, 1, 12, 20, 1), 97.0),
#    (datetime.datetime(2131, 1, 12, 21, 1), 80.0),
#    (datetime.datetime(2131, 1, 12, 22, 1), 83.0),
#    (datetime.datetime(2131, 1, 12, 23, 1), 82.0),
#    (datetime.datetime(2131, 1, 13, 0, 1), 93.0),
#    (datetime.datetime(2131, 1, 13, 1, 1), 88.0),
#    (datetime.datetime(2131, 1, 13, 2, 1), 74.0),
#    (datetime.datetime(2131, 1, 13, 3, 1), 77.0),
#    (datetime.datetime(2131, 1, 13, 4, 2), 72.0),
#    (datetime.datetime(2131, 1, 13, 5, 1), 75.0),
#    (datetime.datetime(2131, 1, 13, 6, 1), 68.0),
#    (datetime.datetime(2131, 1, 13, 7, 1), 70.0),
#    (datetime.datetime(2131, 1, 13, 8, 1), 60.0),
#    (datetime.datetime(2131, 1, 13, 9, 1), 72.0),
#    (datetime.datetime(2131, 1, 13, 10, 1), 75.0),
#    (datetime.datetime(2131, 1, 13, 11, 1), 73.0),
#    (datetime.datetime(2131, 1, 13, 12, 1), 71.0),
#    (datetime.datetime(2131, 1, 13, 13, 1), 71.0),
#    (datetime.datetime(2131, 1, 13, 14, 1), 65.0),
#    (datetime.datetime(2131, 1, 13, 15, 1), 79.0),
#    (datetime.datetime(2131, 1, 13, 16, 1), 82.0),
#    (datetime.datetime(2131, 1, 13, 17, 1), 80.0),
#    (datetime.datetime(2131, 1, 13, 18, 1), 85.0),
#    (datetime.datetime(2131, 1, 13, 19, 1), 83.0),
#    (datetime.datetime(2131, 1, 13, 20, 1), 83.0),
#    (datetime.datetime(2131, 1, 13, 21, 1), 84.0),
#    (datetime.datetime(2131, 1, 13, 22, 1), 88.0),
#    (datetime.datetime(2131, 1, 13, 23, 1), 79.0),
#    (datetime.datetime(2131, 1, 14, 0, 1), 76.0),
#    (datetime.datetime(2131, 1, 14, 1, 1), 81.0),
#    (datetime.datetime(2131, 1, 14, 2, 1), 76.0),
#    (datetime.datetime(2131, 1, 14, 3, 1), 83.0),
#    (datetime.datetime(2131, 1, 14, 4, 1), 81.0),
#    (datetime.datetime(2131, 1, 14, 5, 1), 79.0),
#    (datetime.datetime(2131, 1, 14, 6, 1), 85.0),
#    (datetime.datetime(2131, 1, 14, 7, 1), 75.0),
#    (datetime.datetime(2131, 1, 14, 8, 1), 77.0),
#    (datetime.datetime(2131, 1, 14, 9, 1), 77.0),
#    (datetime.datetime(2131, 1, 14, 10, 31), 84.0),
#    (datetime.datetime(2131, 1, 14, 13, 38), 81.0),
#    (datetime.datetime(2131, 1, 14, 14, 0), 85.0),
#    (datetime.datetime(2131, 1, 14, 15, 16), 93.0),
#    (datetime.datetime(2131, 1, 14, 16, 1), 95.0),
#    (datetime.datetime(2131, 1, 14, 17, 31), 93.0),
#    (datetime.datetime(2131, 1, 14, 18, 16), 87.0),
#    (datetime.datetime(2131, 1, 14, 19, 1), 81.0),
#    (datetime.datetime(2131, 1, 14, 20, 1), 87.0),
#    (datetime.datetime(2131, 1, 14, 21, 1), 86.0),
#    (datetime.datetime(2131, 1, 14, 22, 1), 80.0),
#    (datetime.datetime(2131, 1, 14, 23, 1), 82.0),
#    (datetime.datetime(2131, 1, 15, 0, 1), 81.0),
#    (datetime.datetime(2131, 1, 15, 1, 1), 76.0),
#    (datetime.datetime(2131, 1, 15, 2, 1), 80.0),
#    (datetime.datetime(2131, 1, 15, 3, 1), 75.0),
#    (datetime.datetime(2131, 1, 15, 4, 1), 75.0),
#    (datetime.datetime(2131, 1, 15, 5, 1), 74.0),
#    (datetime.datetime(2131, 1, 15, 6, 1), 74.0),
#    (datetime.datetime(2131, 1, 15, 7, 1), 79.0),
#    (datetime.datetime(2131, 1, 15, 8, 1), 74.0),
#    (datetime.datetime(2131, 1, 15, 9, 1), 77.0),
#    (datetime.datetime(2131, 1, 15, 10, 1), 79.0),
#    (datetime.datetime(2131, 1, 15, 11, 1), 81.0),
#    (datetime.datetime(2131, 1, 15, 12, 1), 74.0),
#    (datetime.datetime(2131, 1, 15, 13, 1), 81.0),
#    (datetime.datetime(2131, 1, 15, 14, 1), 84.0),
#    (datetime.datetime(2131, 1, 15, 15, 1), 79.0),
#    (datetime.datetime(2131, 1, 15, 16, 1), 71.0),
#    (datetime.datetime(2131, 1, 15, 17, 1), 70.0),
#    (datetime.datetime(2131, 1, 15, 18, 1), 77.0),
#    (datetime.datetime(2131, 1, 15, 19, 1), 75.0),
#    (datetime.datetime(2131, 1, 15, 20, 1), 82.0),
#    (datetime.datetime(2131, 1, 15, 21, 1), 82.0),
#    (datetime.datetime(2131, 1, 15, 22, 1), 82.0),
#    (datetime.datetime(2131, 1, 15, 23, 1), 79.0),
#    (datetime.datetime(2131, 1, 16, 0, 1), 77.0),
#    (datetime.datetime(2131, 1, 16, 1, 1), 82.0),
#    (datetime.datetime(2131, 1, 16, 2, 1), 78.0),
#    (datetime.datetime(2131, 1, 16, 3, 1), 81.0),
#    (datetime.datetime(2131, 1, 16, 4, 1), 78.0),
#    (datetime.datetime(2131, 1, 16, 5, 1), 70.0),
#    (datetime.datetime(2131, 1, 16, 6, 1), 66.0),
#    (datetime.datetime(2131, 1, 16, 7, 1), 80.0),
#    (datetime.datetime(2131, 1, 16, 8, 1), 75.0),
#    (datetime.datetime(2131, 1, 16, 9, 1), 74.0),
#    (datetime.datetime(2131, 1, 16, 10, 1), 76.0),
#    (datetime.datetime(2131, 1, 16, 11, 1), 77.0),
#    (datetime.datetime(2131, 1, 16, 12, 1), 67.0),
#    (datetime.datetime(2131, 1, 16, 13, 1), 65.0),
#    (datetime.datetime(2131, 1, 16, 14, 1), 72.0),
#    (datetime.datetime(2131, 1, 16, 15, 1), 75.0),
#    (datetime.datetime(2131, 1, 16, 16, 1), 61.0),
#    (datetime.datetime(2131, 1, 16, 17, 1), 69.0),
#    (datetime.datetime(2131, 1, 16, 18, 1), 79.0),
#    (datetime.datetime(2131, 1, 16, 19, 1), 72.0),
#    (datetime.datetime(2131, 1, 16, 20, 1), 76.0),
#    (datetime.datetime(2131, 1, 16, 21, 1), 79.0),
#    (datetime.datetime(2131, 1, 16, 22, 1), 61.0),
#    (datetime.datetime(2131, 1, 16, 23, 1), 72.0),
#    (datetime.datetime(2131, 1, 17, 0, 1), 73.0),
#    (datetime.datetime(2131, 1, 17, 1, 1), 69.0),
#    (datetime.datetime(2131, 1, 17, 2, 1), 66.0),
#    (datetime.datetime(2131, 1, 17, 3, 1), 73.0),
#    (datetime.datetime(2131, 1, 17, 4, 1), 77.0),
#    (datetime.datetime(2131, 1, 17, 5, 1), 72.0),
#    (datetime.datetime(2131, 1, 17, 6, 1), 86.0),
#    (datetime.datetime(2131, 1, 17, 7, 1), 64.0),
#    (datetime.datetime(2131, 1, 17, 8, 1), 67.0),
#    (datetime.datetime(2131, 1, 17, 9, 2), 61.0),
#    (datetime.datetime(2131, 1, 17, 10, 1), 73.0),
#    (datetime.datetime(2131, 1, 17, 11, 1), 69.0),
#    (datetime.datetime(2131, 1, 17, 12, 1), 70.0),
#    (datetime.datetime(2131, 1, 17, 13, 1), 60.0),
#    (datetime.datetime(2131, 1, 17, 14, 1), 64.0),
#    (datetime.datetime(2131, 1, 17, 15, 1), 70.0),
#    (datetime.datetime(2131, 1, 17, 16, 1), 66.0),
#    (datetime.datetime(2131, 1, 17, 17, 1), 59.0),
#    (datetime.datetime(2131, 1, 17, 18, 1), 70.0),
#    (datetime.datetime(2131, 1, 17, 19, 1), 67.0),
#    (datetime.datetime(2131, 1, 17, 20, 1), 69.0),
#    (datetime.datetime(2131, 1, 17, 21, 1), 71.0),
#    (datetime.datetime(2131, 1, 17, 22, 1), 68.0),
#    (datetime.datetime(2131, 1, 17, 23, 1), 66.0),
#    (datetime.datetime(2131, 1, 18, 0, 1), 65.0),
#    (datetime.datetime(2131, 1, 18, 1, 1), 75.0),
#    (datetime.datetime(2131, 1, 18, 2, 1), 80.0),
#    (datetime.datetime(2131, 1, 18, 3, 1), 68.0),
#    (datetime.datetime(2131, 1, 18, 4, 1), 69.0),
#    (datetime.datetime(2131, 1, 18, 5, 1), 62.0),
#    (datetime.datetime(2131, 1, 18, 6, 1), 71.0),
#    (datetime.datetime(2131, 1, 18, 7, 1), 68.0),
#    (datetime.datetime(2131, 1, 18, 8, 1), 69.0),
#    (datetime.datetime(2131, 1, 18, 9, 4), 80.0),
#    (datetime.datetime(2131, 1, 18, 10, 1), 58.0),
#    (datetime.datetime(2131, 1, 18, 11, 1), 66.0),
#    (datetime.datetime(2131, 1, 18, 12, 1), 69.0),
#    (datetime.datetime(2131, 1, 18, 13, 1), 73.0),
#    (datetime.datetime(2131, 1, 18, 14, 1), 60.0),
#    (datetime.datetime(2131, 1, 18, 15, 1), 63.0),
#    (datetime.datetime(2131, 1, 18, 16, 1), 67.0),
#    (datetime.datetime(2131, 1, 18, 17, 1), 87.0),
#    (datetime.datetime(2131, 1, 18, 18, 0), 62.0),
#    (datetime.datetime(2131, 1, 18, 19, 1), 67.0),
#    (datetime.datetime(2131, 1, 18, 20, 1), 57.0),
#    (datetime.datetime(2131, 1, 18, 21, 1), 110.0),
#    (datetime.datetime(2131, 1, 18, 22, 1), 53.0),
#    (datetime.datetime(2131, 1, 18, 23, 1), 64.0),
#    (datetime.datetime(2131, 1, 19, 0, 1), 61.0),
#    (datetime.datetime(2131, 1, 19, 1, 1), 63.0),
#    (datetime.datetime(2131, 1, 19, 2, 1), 71.0),
#    (datetime.datetime(2131, 1, 19, 3, 1), 70.0),
#    (datetime.datetime(2131, 1, 19, 4, 1), 67.0),
#    (datetime.datetime(2131, 1, 19, 5, 1), 77.0),
#    (datetime.datetime(2131, 1, 19, 6, 1), 73.0),
#    (datetime.datetime(2131, 1, 19, 7, 1), 72.0),
#    (datetime.datetime(2131, 1, 19, 8, 1), 74.0),
#    (datetime.datetime(2131, 1, 19, 9, 1), 67.0),
#    (datetime.datetime(2131, 1, 19, 10, 1), 72.0),
#    (datetime.datetime(2131, 1, 19, 11, 1), 67.0),
#    (datetime.datetime(2131, 1, 19, 12, 1), 79.0),
#    (datetime.datetime(2131, 1, 19, 13, 1), 75.0),
#    (datetime.datetime(2131, 1, 19, 14, 1), 78.0),
#    (datetime.datetime(2131, 1, 19, 15, 1), 67.0),
#    (datetime.datetime(2131, 1, 19, 16, 1), 62.0),
#    (datetime.datetime(2131, 1, 19, 17, 1), 74.0),
#    (datetime.datetime(2131, 1, 19, 18, 1), 70.0),
#    (datetime.datetime(2131, 1, 19, 19, 1), 72.0),
#    (datetime.datetime(2131, 1, 19, 20, 1), 67.0),
#    (datetime.datetime(2131, 1, 19, 21, 1), 80.0),
#    (datetime.datetime(2131, 1, 19, 22, 1), 77.0),
#    (datetime.datetime(2131, 1, 19, 23, 1), 75.0),
#    (datetime.datetime(2131, 1, 20, 0, 1), 83.0),
#    (datetime.datetime(2131, 1, 20, 4, 19), 48.0)],
#   'TEMP': [(datetime.datetime(2131, 1, 11, 6, 47), 35.4),
#    (datetime.datetime(2131, 1, 11, 8, 0), 35.8),
#    (datetime.datetime(2131, 1, 11, 9, 0), 36.3),
#    (datetime.datetime(2131, 1, 11, 10, 0), 36.7),
#    (datetime.datetime(2131, 1, 11, 11, 0), 36.8),
#    (datetime.datetime(2131, 1, 11, 12, 0), 37.2),
#    (datetime.datetime(2131, 1, 11, 13, 0), 37.2),
#    (datetime.datetime(2131, 1, 11, 14, 0), 37.2),
#    (datetime.datetime(2131, 1, 11, 16, 0), 35.1),
#    (datetime.datetime(2131, 1, 11, 19, 0), 36.9),
#    (datetime.datetime(2131, 1, 11, 20, 0), 37.1),
#    (datetime.datetime(2131, 1, 11, 21, 0), 36.9),
# ...
#    (datetime.datetime(2131, 1, 14, 3, 8), 0.4),
#    (datetime.datetime(2131, 1, 14, 15, 30), 0.4),
#    (datetime.datetime(2131, 1, 15, 2, 30), 0.5),
#    (datetime.datetime(2131, 1, 15, 15, 0), 0.5),
#    (datetime.datetime(2131, 1, 16, 4, 2), 0.4),
#    (datetime.datetime(2131, 1, 16, 16, 20), 0.4),
#    (datetime.datetime(2131, 1, 17, 4, 3), 0.3),
#    (datetime.datetime(2131, 1, 18, 2, 51), 0.4)],
#   'CREATININE': [(datetime.datetime(2131, 1, 8, 5, 11), 0.9),
#    (datetime.datetime(2131, 1, 9, 4, 45), 1.0),
#    (datetime.datetime(2131, 1, 10, 4, 35), 0.9),
#    (datetime.datetime(2131, 1, 10, 20, 45), 1.1),
#    (datetime.datetime(2131, 1, 11, 6, 31), 1.1),
#    (datetime.datetime(2131, 1, 12, 3, 34), 1.0),
#    (datetime.datetime(2131, 1, 13, 4, 29), 1.2),
#    (datetime.datetime(2131, 1, 13, 8, 23), 1.3),
#    (datetime.datetime(2131, 1, 13, 10, 35), 1.2),
#    (datetime.datetime(2131, 1, 14, 3, 8), 1.1),
#    (datetime.datetime(2131, 1, 14, 15, 30), 0.9),
#    (datetime.datetime(2131, 1, 15, 2, 30), 0.8),
#    (datetime.datetime(2131, 1, 15, 15, 0), 0.8),
#    (datetime.datetime(2131, 1, 16, 4, 2), 0.7),
#    (datetime.datetime(2131, 1, 16, 16, 20), 0.6),
#    (datetime.datetime(2131, 1, 17, 4, 3), 0.6),
#    (datetime.datetime(2131, 1, 18, 2, 51), 0.5),
#    (datetime.datetime(2131, 1, 19, 4, 15), 0.6)],
#   'POTASSIUM': [(datetime.datetime(2131, 1, 8, 5, 11), 3.6),
#    (datetime.datetime(2131, 1, 9, 4, 45), 3.7),
#    (datetime.datetime(2131, 1, 10, 4, 35), 4.4),
#    (datetime.datetime(2131, 1, 10, 20, 45), 4.5),
#    (datetime.datetime(2131, 1, 11, 6, 31), 4.0),
#    (datetime.datetime(2131, 1, 12, 3, 34), 4.2),
#    (datetime.datetime(2131, 1, 13, 4, 29), 5.8),
#    (datetime.datetime(2131, 1, 13, 8, 23), 7.1),
#    (datetime.datetime(2131, 1, 13, 10, 35), 5.0),
#    (datetime.datetime(2131, 1, 14, 3, 8), 4.6),
#    (datetime.datetime(2131, 1, 14, 15, 30), 5.2),
#    (datetime.datetime(2131, 1, 15, 2, 30), 4.8),
#    (datetime.datetime(2131, 1, 15, 15, 0), 5.2),
#    (datetime.datetime(2131, 1, 16, 4, 2), 4.4),
#    (datetime.datetime(2131, 1, 16, 16, 20), 4.6),
#    (datetime.datetime(2131, 1, 17, 4, 3), 4.1),
#    (datetime.datetime(2131, 1, 18, 2, 51), 4.1),
#    (datetime.datetime(2131, 1, 19, 4, 15), 4.2)],
#   'SODIUM': [(datetime.datetime(2131, 1, 8, 5, 11), 135.0),
#    (datetime.datetime(2131, 1, 9, 4, 45), 131.0),
#    (datetime.datetime(2131, 1, 10, 4, 35), 131.0),
#    (datetime.datetime(2131, 1, 10, 20, 45), 130.0),
#    (datetime.datetime(2131, 1, 11, 6, 31), 136.0),
#    (datetime.datetime(2131, 1, 12, 3, 34), 138.0),
#    (datetime.datetime(2131, 1, 13, 4, 29), 135.0),
#    (datetime.datetime(2131, 1, 13, 8, 23), 132.0),
#    (datetime.datetime(2131, 1, 13, 10, 35), 139.0),
#    (datetime.datetime(2131, 1, 14, 3, 8), 140.0),
#    (datetime.datetime(2131, 1, 14, 15, 30), 137.0),
#    (datetime.datetime(2131, 1, 15, 2, 30), 139.0),
#    (datetime.datetime(2131, 1, 15, 15, 0), 136.0),
#    (datetime.datetime(2131, 1, 16, 4, 2), 137.0),
#    (datetime.datetime(2131, 1, 16, 16, 20), 135.0),
#    (datetime.datetime(2131, 1, 17, 4, 3), 135.0),
#    (datetime.datetime(2131, 1, 18, 2, 51), 134.0),
#    (datetime.datetime(2131, 1, 19, 4, 15), 138.0)],
#   'LACTATE': [(datetime.datetime(2131, 1, 8, 10, 40), 4.0),
#    (datetime.datetime(2131, 1, 10, 13, 15), 2.0),
#    (datetime.datetime(2131, 1, 11, 1, 51), 1.7),
#    (datetime.datetime(2131, 1, 11, 6, 37), 1.5),
#    (datetime.datetime(2131, 1, 11, 11, 33), 1.1),
#    (datetime.datetime(2131, 1, 12, 21, 4), 1.1),
#    (datetime.datetime(2131, 1, 13, 2, 28), 1.2)],
#   'PH': [(datetime.datetime(2131, 1, 8, 10, 40), 7.42),
#    (datetime.datetime(2131, 1, 10, 13, 15), 7.42),
#    (datetime.datetime(2131, 1, 11, 1, 51), 7.37),
#    (datetime.datetime(2131, 1, 11, 2, 49), 7.24),
#    (datetime.datetime(2131, 1, 11, 3, 42), 7.22),
#    (datetime.datetime(2131, 1, 11, 6, 37), 7.33),
#    (datetime.datetime(2131, 1, 11, 11, 33), 7.33),
#    (datetime.datetime(2131, 1, 11, 14, 48), 7.36),
#    (datetime.datetime(2131, 1, 11, 22, 21), 7.32),
#    (datetime.datetime(2131, 1, 12, 3, 48), 7.36),
#    (datetime.datetime(2131, 1, 12, 21, 4), 7.38),
#    (datetime.datetime(2131, 1, 13, 2, 28), 7.42),
#    (datetime.datetime(2131, 1, 14, 3, 27), 7.38),
#    (datetime.datetime(2131, 1, 14, 7, 5), 7.46)]},
#  '23581541': {'FiO2': [(datetime.datetime(2160, 5, 18, 14, 0), 100.0),
#    (datetime.datetime(2160, 5, 18, 15, 0), 50.0),
#    (datetime.datetime(2160, 5, 18, 18, 0), 50.0)],
#   'SBP': [(datetime.datetime(2160, 5, 18, 14, 6), 134.0),
#    (datetime.datetime(2160, 5, 18, 15, 0), 90.0),
#    (datetime.datetime(2160, 5, 18, 15, 50), 131.0),
#    (datetime.datetime(2160, 5, 18, 16, 0), 122.0),
#    (datetime.datetime(2160, 5, 18, 16, 0), 125.0),
#    (datetime.datetime(2160, 5, 18, 17, 0), 143.0),
#    (datetime.datetime(2160, 5, 18, 17, 0), 152.0),
#    (datetime.datetime(2160, 5, 18, 18, 0), 104.0),
#    (datetime.datetime(2160, 5, 18, 18, 0), 105.0),
#    (datetime.datetime(2160, 5, 18, 19, 0), 121.0),
#    (datetime.datetime(2160, 5, 18, 19, 0), 120.0),
#    (datetime.datetime(2160, 5, 18, 20, 0), 116.0),
#    (datetime.datetime(2160, 5, 18, 20, 0), 132.0),
#    (datetime.datetime(2160, 5, 18, 21, 0), 97.0),
#    (datetime.datetime(2160, 5, 18, 21, 0), 94.0),
#    (datetime.datetime(2160, 5, 18, 22, 0), 123.0),
#    (datetime.datetime(2160, 5, 18, 22, 0), 133.0),
#    (datetime.datetime(2160, 5, 18, 22, 10), 94.0),
#    (datetime.datetime(2160, 5, 18, 22, 10), 99.0),
#    (datetime.datetime(2160, 5, 18, 23, 0), 116.0),
#    (datetime.datetime(2160, 5, 18, 23, 0), 127.0),
#    (datetime.datetime(2160, 5, 19, 0, 0), 90.0),
#    (datetime.datetime(2160, 5, 19, 0, 0), 88.0),
#    (datetime.datetime(2160, 5, 19, 1, 0), 116.0),
#    (datetime.datetime(2160, 5, 19, 2, 0), 111.0),
#    (datetime.datetime(2160, 5, 19, 3, 0), 100.0),
#    (datetime.datetime(2160, 5, 19, 4, 4), 92.0),
#    (datetime.datetime(2160, 5, 19, 5, 1), 105.0),
#    (datetime.datetime(2160, 5, 19, 6, 0), 136.0),
#    (datetime.datetime(2160, 5, 19, 7, 0), 117.0),
#    (datetime.datetime(2160, 5, 19, 7, 53), 104.0),
#    (datetime.datetime(2160, 5, 19, 8, 2), 80.0),
#    (datetime.datetime(2160, 5, 19, 8, 3), 93.0),
#    (datetime.datetime(2160, 5, 19, 9, 0), 116.0),
#    (datetime.datetime(2160, 5, 19, 9, 2), 106.0),
#    (datetime.datetime(2160, 5, 19, 10, 0), 127.0),
#    (datetime.datetime(2160, 5, 19, 11, 0), 126.0),
#    (datetime.datetime(2160, 5, 19, 12, 0), 109.0),
#    (datetime.datetime(2160, 5, 19, 13, 0), 128.0),
#    (datetime.datetime(2160, 5, 19, 14, 0), 113.0),
#    (datetime.datetime(2160, 5, 19, 15, 0), 93.0),
#    (datetime.datetime(2160, 5, 19, 16, 0), 106.0)],
#   'DBP': [(datetime.datetime(2160, 5, 18, 14, 6), 75.0),
#    (datetime.datetime(2160, 5, 18, 15, 0), 55.0),
#    (datetime.datetime(2160, 5, 18, 15, 50), 64.0),
#    (datetime.datetime(2160, 5, 18, 16, 0), 70.0),
#    (datetime.datetime(2160, 5, 18, 16, 0), 65.0),
#    (datetime.datetime(2160, 5, 18, 17, 0), 81.0),
#    (datetime.datetime(2160, 5, 18, 17, 0), 77.0),
#    (datetime.datetime(2160, 5, 18, 18, 0), 62.0),
#    (datetime.datetime(2160, 5, 18, 18, 0), 56.0),
#    (datetime.datetime(2160, 5, 18, 19, 0), 71.0),
#    (datetime.datetime(2160, 5, 18, 19, 0), 66.0),
#    (datetime.datetime(2160, 5, 18, 20, 0), 75.0),
#    (datetime.datetime(2160, 5, 18, 20, 0), 66.0),
#    (datetime.datetime(2160, 5, 18, 21, 0), 60.0),
#    (datetime.datetime(2160, 5, 18, 21, 0), 56.0),
#    (datetime.datetime(2160, 5, 18, 22, 0), 65.0),
#    (datetime.datetime(2160, 5, 18, 22, 0), 65.0),
#    (datetime.datetime(2160, 5, 18, 22, 10), 53.0),
#    (datetime.datetime(2160, 5, 18, 22, 10), 53.0),
#    (datetime.datetime(2160, 5, 18, 23, 0), 62.0),
#    (datetime.datetime(2160, 5, 18, 23, 0), 61.0),
#    (datetime.datetime(2160, 5, 19, 0, 0), 51.0),
#    (datetime.datetime(2160, 5, 19, 0, 0), 50.0),
#    (datetime.datetime(2160, 5, 19, 1, 0), 59.0),
#    (datetime.datetime(2160, 5, 19, 2, 0), 58.0),
#    (datetime.datetime(2160, 5, 19, 3, 0), 53.0),
#    (datetime.datetime(2160, 5, 19, 4, 4), 55.0),
#    (datetime.datetime(2160, 5, 19, 5, 1), 52.0),
#    (datetime.datetime(2160, 5, 19, 6, 0), 62.0),
#    (datetime.datetime(2160, 5, 19, 7, 0), 54.0),
#    (datetime.datetime(2160, 5, 19, 7, 53), 70.0),
#    (datetime.datetime(2160, 5, 19, 8, 2), 55.0),
#    (datetime.datetime(2160, 5, 19, 8, 3), 54.0),
#    (datetime.datetime(2160, 5, 19, 9, 0), 63.0),
#    (datetime.datetime(2160, 5, 19, 9, 2), 65.0),
#    (datetime.datetime(2160, 5, 19, 10, 0), 75.0),
#    (datetime.datetime(2160, 5, 19, 11, 0), 68.0),
#    (datetime.datetime(2160, 5, 19, 12, 0), 63.0),
#    (datetime.datetime(2160, 5, 19, 13, 0), 78.0),
#    (datetime.datetime(2160, 5, 19, 14, 0), 71.0),
#    (datetime.datetime(2160, 5, 19, 15, 0), 41.0),
#    (datetime.datetime(2160, 5, 19, 16, 0), 60.0)],
#   'MAP': [(datetime.datetime(2160, 5, 18, 14, 6), 94.0),
#    (datetime.datetime(2160, 5, 18, 15, 0), 66.0),
#    (datetime.datetime(2160, 5, 18, 16, 0), 88.0),
#    (datetime.datetime(2160, 5, 18, 17, 0), 102.0),
#    (datetime.datetime(2160, 5, 18, 18, 0), 76.0),
#    (datetime.datetime(2160, 5, 18, 19, 0), 89.0),
#    (datetime.datetime(2160, 5, 18, 20, 0), 89.0),
#    (datetime.datetime(2160, 5, 18, 21, 0), 73.0),
#    (datetime.datetime(2160, 5, 18, 22, 0), 86.0),
#    (datetime.datetime(2160, 5, 18, 22, 10), 66.0),
#    (datetime.datetime(2160, 5, 18, 23, 0), 80.0),
#    (datetime.datetime(2160, 5, 19, 0, 0), 65.0),
#    (datetime.datetime(2160, 5, 19, 1, 0), 75.0),
#    (datetime.datetime(2160, 5, 19, 2, 0), 73.0),
#    (datetime.datetime(2160, 5, 19, 3, 0), 67.0),
#    (datetime.datetime(2160, 5, 19, 4, 1), 41.0),
#    (datetime.datetime(2160, 5, 19, 6, 0), 85.0),
#    (datetime.datetime(2160, 5, 19, 7, 0), 73.0),
#    (datetime.datetime(2160, 5, 19, 8, 2), 65.0),
#    (datetime.datetime(2160, 5, 19, 9, 0), 81.0)],
#   'PULSE': [(datetime.datetime(2160, 5, 18, 14, 7), 80.0),
#    (datetime.datetime(2160, 5, 18, 15, 0), 88.0),
#    (datetime.datetime(2160, 5, 18, 16, 0), 92.0),
#    (datetime.datetime(2160, 5, 18, 17, 0), 91.0),
#    (datetime.datetime(2160, 5, 18, 18, 0), 101.0),
#    (datetime.datetime(2160, 5, 18, 19, 0), 99.0),
#    (datetime.datetime(2160, 5, 18, 20, 0), 103.0),
#    (datetime.datetime(2160, 5, 18, 21, 0), 105.0),
#    (datetime.datetime(2160, 5, 18, 22, 0), 101.0),
#    (datetime.datetime(2160, 5, 18, 22, 10), 96.0),
#    (datetime.datetime(2160, 5, 18, 23, 0), 94.0),
#    (datetime.datetime(2160, 5, 19, 0, 0), 99.0),
#    (datetime.datetime(2160, 5, 19, 1, 0), 95.0),
#    (datetime.datetime(2160, 5, 19, 2, 0), 95.0),
#    (datetime.datetime(2160, 5, 19, 3, 0), 93.0),
#    (datetime.datetime(2160, 5, 19, 4, 0), 94.0),
#    (datetime.datetime(2160, 5, 19, 5, 0), 91.0),
#    (datetime.datetime(2160, 5, 19, 6, 0), 90.0),
#    (datetime.datetime(2160, 5, 19, 7, 0), 94.0),
#    (datetime.datetime(2160, 5, 19, 8, 0), 94.0),
#    (datetime.datetime(2160, 5, 19, 9, 0), 92.0),
#    (datetime.datetime(2160, 5, 19, 10, 0), 95.0),
#    (datetime.datetime(2160, 5, 19, 11, 0), 91.0),
#    (datetime.datetime(2160, 5, 19, 12, 0), 96.0),
#    (datetime.datetime(2160, 5, 19, 13, 0), 95.0),
#    (datetime.datetime(2160, 5, 19, 14, 0), 92.0),
#    (datetime.datetime(2160, 5, 19, 15, 0), 88.0),
#    (datetime.datetime(2160, 5, 19, 16, 0), 94.0)],
#   'RESP': [(datetime.datetime(2160, 5, 18, 14, 7), 14.0),
#    (datetime.datetime(2160, 5, 18, 15, 0), 14.0),
#    (datetime.datetime(2160, 5, 18, 16, 1), 14.0),
#    (datetime.datetime(2160, 5, 18, 17, 0), 15.0),
#    (datetime.datetime(2160, 5, 18, 18, 0), 23.0),
#    (datetime.datetime(2160, 5, 18, 19, 0), 20.0),
#    (datetime.datetime(2160, 5, 18, 20, 0), 18.0),
#    (datetime.datetime(2160, 5, 18, 21, 0), 19.0),
#    (datetime.datetime(2160, 5, 18, 22, 0), 18.0),
#    (datetime.datetime(2160, 5, 18, 23, 0), 20.0),
#    (datetime.datetime(2160, 5, 19, 0, 0), 15.0),
#    (datetime.datetime(2160, 5, 19, 1, 0), 14.0),
#    (datetime.datetime(2160, 5, 19, 2, 0), 15.0),
#    (datetime.datetime(2160, 5, 19, 3, 0), 12.0),
#    (datetime.datetime(2160, 5, 19, 4, 0), 12.0),
#    (datetime.datetime(2160, 5, 19, 5, 0), 11.0),
#    (datetime.datetime(2160, 5, 19, 6, 0), 16.0),
#    (datetime.datetime(2160, 5, 19, 7, 0), 12.0),
#    (datetime.datetime(2160, 5, 19, 8, 0), 13.0),
#    (datetime.datetime(2160, 5, 19, 9, 0), 13.0),
#    (datetime.datetime(2160, 5, 19, 10, 0), 16.0),
#    (datetime.datetime(2160, 5, 19, 11, 0), 10.0),
#    (datetime.datetime(2160, 5, 19, 12, 0), 16.0),
#    (datetime.datetime(2160, 5, 19, 13, 0), 14.0),
#    (datetime.datetime(2160, 5, 19, 14, 0), 13.0),
#    (datetime.datetime(2160, 5, 19, 15, 0), 19.0),
#    (datetime.datetime(2160, 5, 19, 16, 0), 14.0)],
#   'TEMP': [(datetime.datetime(2160, 5, 18, 14, 18), 37.2),
#    (datetime.datetime(2160, 5, 18, 15, 0), 37.0),
#    (datetime.datetime(2160, 5, 18, 16, 0), 36.9),
#    (datetime.datetime(2160, 5, 18, 17, 0), 37.1),
#    (datetime.datetime(2160, 5, 18, 18, 0), 36.7),
#    (datetime.datetime(2160, 5, 18, 19, 0), 36.8),
#    (datetime.datetime(2160, 5, 18, 20, 0), 37.3),
#    (datetime.datetime(2160, 5, 18, 21, 0), 37.4),
#    (datetime.datetime(2160, 5, 18, 22, 0), 37.5),
#    (datetime.datetime(2160, 5, 18, 23, 0), 37.5),
#    (datetime.datetime(2160, 5, 19, 0, 0), 37.5),
#    (datetime.datetime(2160, 5, 19, 1, 0), 37.4),
#    (datetime.datetime(2160, 5, 19, 2, 0), 37.6),
#    (datetime.datetime(2160, 5, 19, 3, 0), 37.6),
#    (datetime.datetime(2160, 5, 19, 4, 0), 37.7),
#    (datetime.datetime(2160, 5, 19, 5, 0), 37.7),
#    (datetime.datetime(2160, 5, 19, 8, 0), 36.22),
#    (datetime.datetime(2160, 5, 19, 14, 0), 36.56)],
#   'LACTATE': [(datetime.datetime(2160, 5, 18, 9, 19), 2.3),
#    (datetime.datetime(2160, 5, 18, 10, 26), 3.3),
#    (datetime.datetime(2160, 5, 18, 11, 23), 2.8),
#    (datetime.datetime(2160, 5, 18, 12, 20), 3.1),
#    (datetime.datetime(2160, 5, 18, 13, 2), 2.6)],
#   'PH': [(datetime.datetime(2160, 5, 18, 9, 19), 7.33),
#    (datetime.datetime(2160, 5, 18, 10, 26), 7.35),
#    (datetime.datetime(2160, 5, 18, 11, 23), 7.4),
#    (datetime.datetime(2160, 5, 18, 12, 20), 7.27),
#    (datetime.datetime(2160, 5, 18, 13, 2), 7.32),
#    (datetime.datetime(2160, 5, 18, 14, 46), 7.34),
#    (datetime.datetime(2160, 5, 18, 16, 3), 7.33),
#    (datetime.datetime(2160, 5, 18, 17, 42), 7.33),
#    (datetime.datetime(2160, 5, 18, 21, 32), 7.35),
#    (datetime.datetime(2160, 5, 19, 4, 10), 7.36)],
#   'HEMATOCRIT': [(datetime.datetime(2160, 5, 18, 13, 1), 28.6),
#    (datetime.datetime(2160, 5, 18, 14, 38), 31.9),
#    (datetime.datetime(2160, 5, 18, 17, 30), 31.0),
#    (datetime.datetime(2160, 5, 19, 4, 0), 31.2),
#    (datetime.datetime(2160, 5, 20, 8, 20), 32.3),
#    (datetime.datetime(2160, 5, 22, 6, 15), 32.1),
#    (datetime.datetime(2160, 5, 23, 6, 5), 30.5)],
#   'PLATELET': [(datetime.datetime(2160, 5, 18, 13, 1), 252.0),
#    (datetime.datetime(2160, 5, 18, 14, 38), 254.0),
#    (datetime.datetime(2160, 5, 19, 4, 0), 248.0),
#    (datetime.datetime(2160, 5, 20, 8, 20), 192.0),
#    (datetime.datetime(2160, 5, 22, 6, 15), 230.0),
#    (datetime.datetime(2160, 5, 23, 6, 5), 253.0)],
#   'WBC': [(datetime.datetime(2160, 5, 18, 13, 1), 18.2),
#    (datetime.datetime(2160, 5, 18, 14, 38), 20.2),
#    (datetime.datetime(2160, 5, 19, 4, 0), 17.9),
#    (datetime.datetime(2160, 5, 20, 8, 20), 14.0),
#    (datetime.datetime(2160, 5, 22, 6, 15), 11.1),
#    (datetime.datetime(2160, 5, 23, 6, 5), 11.7)],
#   'CREATININE': [(datetime.datetime(2160, 5, 18, 14, 38), 1.1),
#    (datetime.datetime(2160, 5, 19, 4, 0), 0.9),
#    (datetime.datetime(2160, 5, 20, 8, 20), 1.0),
#    (datetime.datetime(2160, 5, 21, 8, 0), 0.9),
#    (datetime.datetime(2160, 5, 22, 6, 15), 1.1)],
#   'POTASSIUM': [(datetime.datetime(2160, 5, 18, 14, 38), 4.0),
#    (datetime.datetime(2160, 5, 18, 17, 30), 4.0),
#    (datetime.datetime(2160, 5, 19, 4, 0), 4.7),
#    (datetime.datetime(2160, 5, 20, 8, 20), 4.6),
#    (datetime.datetime(2160, 5, 21, 8, 0), 4.1),
#    (datetime.datetime(2160, 5, 22, 6, 15), 4.0),
#    (datetime.datetime(2160, 5, 23, 6, 5), 4.1)],
#   'SODIUM': [(datetime.datetime(2160, 5, 18, 14, 38), 140.0),
#    (datetime.datetime(2160, 5, 18, 17, 30), 139.0),
#    (datetime.datetime(2160, 5, 19, 4, 0), 136.0),
#    (datetime.datetime(2160, 5, 20, 8, 20), 134.0),
#    (datetime.datetime(2160, 5, 21, 8, 0), 136.0),
#    (datetime.datetime(2160, 5, 22, 6, 15), 136.0),
#    (datetime.datetime(2160, 5, 23, 6, 5), 137.0)]}}

# %%
# 사망 레이블 하기
death_labels = dict()
admissions = csv.DictReader(open('/content/gdrive/MyDrive/mimiciv_der/sepsis3_admissions.csv', 'r', encoding='utf-8'))
for row in tqdm(admissions, desc='Get Death Label'):
  hadm_id = row['hadm_id']
  death_yn = int(row['hospital_expire_flag'])
  if death_yn:
    event_time = str2datetime(row['deathtime'])
  else:
    event_time = str2datetime(row['dischtime'])
  death_labels[hadm_id] = dict({'DEATH': death_yn, 'EVENT_TIME': event_time})
# Out:
# Get Death Label: 0it [00:00, ?it/s]

# %%
# 재실 기간 레이블 하기
los_labels = dict()
admissions = csv.DictReader(open('/content/gdrive/MyDrive/mimiciv_der/sepsis3_admissions.csv', 'r', encoding='utf-8'))
for row in tqdm(admissions, desc='Get loss Label'):
  hadm_id = row['hadm_id']
  admin_time = str2datetime(row['admittime'])
  disc_time = str2datetime(row['dischtime'])
  los = (disc_time - admin_time).total_seconds() / (60*60)
  los_labels[hadm_id] = int(los)
# Out:
# Get loss Label: 0it [00:00, ?it/s]

# %%
## Define some util functions
NOT_CONVERTED = 'NOT_CONVERTED'
## 문자로 기록된 날짜 값들을 파이썬의 datetime 데이터로 바꿔주는 함수 작성
def str2datetime(s):
    def _convert(_s, _dformat):
        try:
            converted_dt = datetime.strptime(_s, _dformat)
        except Exception:
            return NOT_CONVERTED

        return converted_dt

    if isinstance(s, datetime):
        return s

    dformats = [
        '%Y-%m-%d %p %I:%M:%S',
        '%Y-%m-%d %H:%M:%S.%f',
        '%Y-%m-%d %H:%M:%S',
        '%Y-%m-%d %H:%M',
        '%y-%m-%d %H:%M',
        '%Y-%m-%d',
        '%Y%m%d',
        '%Y-%m-%d +%H:%M',
        '%Y%m%d %H%M',
        '%Y%m%d%H%M%S',
        ]

    s = s.split('.')[0]
    s = s.replace('오전', 'am').replace('오후', 'pm')
    for dformat in dformats:
        dt = _convert(s, dformat)
        if dt != NOT_CONVERTED:
            return dt

    return NOT_CONVERTED

# %%
## 환자의 입실 퇴실 시간 정보 가져오기
Extracted_HADMIDS = list(extracted_features.keys())
admin_disc_time = dict()

admissions = csv.DictReader(open('/content/gdrive/MyDrive/mimiciv_der/sepsis3_admissions.csv', 'r', encoding='utf-8'))
for row in admissions:
  hadm_id = row['hadm_id']
  admin_time = str2datetime(row['admittime'])
  disc_time = str2datetime(row['dischtime'])

  if (admin_time != NOT_CONVERTED) and (disc_time != NOT_CONVERTED):
    admin_disc_time[hadm_id] = dict({'ADMIN': admin_time, 'DISC': disc_time})

# %%
## 입실 시점으로부터 1시간 간격으로 데이터를 읽어오는 함수 정의
def quantize_features(feature_list, admin_time, disc_time, missing_feature=False):
  total_hours = int((disc_time - admin_time).total_seconds() / (60*60))
  #입실 이후 최대 24시간 동안의 데이터만 가져오기
  if total_hours > 24:
    total_hours = 24
  
  quantized_features = list()
  if missing_feature:
    for i in range(total_hours):
      quantized_time = admin_time + timedelta(hours=i)
      quantized_value = np.nan #지금은 dic 형태라, pandas 쓰면 NAN이랑 동일, carry forward 도 가능
      quantized_features.append((quantized_time, quantized_value))
  else:
    feature_list = list(sorted(feature_list, key=lambda x: x[0]))
    for i in range(total_hours):
      quantized_time = admin_time + timedelta(hours=i)
      quantized_time_start = quantized_time - timedelta(hours=1)
      quantized_values = list(filter(lambda x: quantized_time_start < x[0] <= quantized_time, feature_list)) #filter함수 True만 필터
      if len(quantized_values) > 0:
        quantized_value = quantized_values[-1][1]
      else:
        quantized_value = np.nan 

      quantized_features.append((quantized_time, quantized_value))
  
  return quantized_features

# %%
## 전체 데이터에 대해서 데이터 변환하기
quantized_features = dict()
for hadm_id in tqdm(Extracted_HADMIDS, desc='Doing Quantization'):
    feature_keys = ['PULSE', 'SBP', 'DBP', 'RESP', 'TEMP','FiO2','MAP', 'BILIRUBIN', 'WBC', 'HEMATOCRIT','PH' ,'LACTATE', 'PLATELET', 'CREATININE', 'SODIUM','POTASSIUM']
    admin_time = admin_disc_time[hadm_id]['ADMIN']
    disc_time = admin_disc_time[hadm_id]['DISC']
    if (disc_time - admin_time).total_seconds() / (60*60) < 1.0:
      continue
    quantized_features[hadm_id] = dict()
    for kk in feature_keys:
      if kk in extracted_features[hadm_id]:
        feature_list = extracted_features[hadm_id][kk]
        quantized_features[hadm_id][kk] = quantize_features(feature_list, admin_time, disc_time)
      else:
        quantized_features[hadm_id][kk] = quantize_features(None, admin_time, disc_time, missing_feature=True)
# Out:
# Doing Quantization:   0%|          | 0/32812 [00:00<?, ?it/s]

# %%
NORMAL_VALUE = dict({
    'PULSE': 80.0,
    'SBP': 120.0,
    'DBP': 80.0,
    'RESP': 14.0,
    'TEMP': 36.5,
    'BILIRUBIN': 0.6,
    'WBC': 7.0,
    'HEMATOCRIT': 45.0,
    'LACTATE': 0.7,
    'PLATELET': 300.,
    'CREATININE': 0.8,
    'SODIUM': 140.,
    'FiO2' : 400,
    'PH' : 7.35,
    'POTASSIUM' : 4.25,
    'MAP' : 85
})

# %%
def carry_forward(feature_name, feature_list):
  imputed_features = list()
  for i, (feature_t, feature_v) in enumerate(feature_list):
    if np.isnan(feature_v):
      last_observations = list(filter(lambda x: (x[0] <= feature_t) and (not np.isnan(x[1])), feature_list))
      if len(last_observations) > 0:
        imputed_features.append((feature_t, last_observations[-1][1]))
      else:
        imputed_features.append((feature_t, NORMAL_VALUE[feature_name]))
    else:
      imputed_features.append((feature_t, feature_v))

  return imputed_features

# %%
Quantized_HADMIDS = list(quantized_features.keys())
carry_forwarded_features = dict()
feature_keys = ['PULSE', 'SBP', 'DBP', 'RESP', 'TEMP','FiO2','MAP', 'BILIRUBIN', 'WBC', 'HEMATOCRIT','PH' ,'LACTATE', 'PLATELET', 'CREATININE', 'SODIUM','POTASSIUM']
for hadm_id in tqdm(Quantized_HADMIDS, desc='Carry-Forward'):
  carry_forwarded_features[hadm_id] = dict()

  for kk in feature_keys:
    feature_list = quantized_features[hadm_id][kk]
    carry_forwarded_features[hadm_id][kk] = carry_forward(kk, feature_list)
# Out:
# Carry-Forward:   0%|          | 0/32785 [00:00<?, ?it/s]

# %%
#항목별 정상값의 범위
#수정 필요
FEATURE_NORMAL_RANGE = dict({
    'PULSE': (0, 300),
    'SBP': (0, 300),
    'DBP': (0, 300),
    'RESP': (0, 120),
    'TEMP': (25, 50),
    'BILIRUBIN': (0, 75),
    'WBC': (0, 100),
    'HEMATOCRIT': (0, 100),
    'LACTATE': (0, 20),
    'PLATELET': (0, 1000),
    'CREATININE': (0, 20),
    'SODIUM': (0, 500),
    'FiO2' : (300, 500),
    'PH' : (7.35, 7.45),
    'POTASSIUM' : (3.7, 5.2),
    'MAP' : (70, 100)
})

# %%
#Min-Max Normalization
min_max_normalized = dict()
for hadm_id in tqdm(Quantized_HADMIDS, desc='Min-Max Normalization', ncols=700):
  min_max_normalized[hadm_id] = dict()
  feature_keys = ['PULSE', 'SBP', 'DBP', 'RESP', 'TEMP','FiO2','MAP', 'BILIRUBIN', 'WBC', 'HEMATOCRIT','PH' ,'LACTATE', 'PLATELET', 'CREATININE', 'SODIUM','POTASSIUM']
  for kk in feature_keys:
    features = np.array(carry_forwarded_features[hadm_id][kk])

    min = FEATURE_NORMAL_RANGE[kk][0]
    max = FEATURE_NORMAL_RANGE[kk][1]

    features[:, 1] = (features[:, 1] - min) / (max - min)
    min_max_normalized[hadm_id][kk] = features
# Out:
# Min-Max Normalization:   0%|                                                                                  …

# %%
total_death_included_hadm_ids = list(death_labels.keys())
total_los_included_hadm_ids = list(los_labels.keys())
feature_keys = ['PULSE', 'SBP', 'DBP', 'RESP', 'TEMP','FiO2','MAP', 'BILIRUBIN', 'WBC', 'HEMATOCRIT','PH' ,'LACTATE', 'PLATELET', 'CREATININE', 'SODIUM','POTASSIUM']

# %%
## 사망 예측용 데이터
death_dataset = dict({
    'HADM_IDS': list(),
    'LABEL': list(),
    'DATA': list()
})

for hadm_id in tqdm(total_death_included_hadm_ids, desc='Make Death Dataset', ncols=700):
  if hadm_id not in min_max_normalized:
    continue
  if len(min_max_normalized[hadm_id][feature_keys[0]]) >= 24:
    time_len = 24
  else:
    time_len = len(min_max_normalized[hadm_id][feature_keys[0]])
  
  try:
    data = np.array(min_max_normalized[hadm_id][feature_keys[0]])[:time_len, 1].reshape(time_len, 1)
  except:
    continue

  for kk in feature_keys[1:]:
    data = np.concatenate((data, np.array(min_max_normalized[hadm_id][kk])[:time_len, 1].reshape(time_len, 1)), axis=1)
  
  death_dataset['HADM_IDS'].append(hadm_id)
  death_dataset['LABEL'].append(death_labels[hadm_id]['DEATH'])
  death_dataset['DATA'].append(data)
# Out:
# Make Death Dataset:   0%|                                                                                     …

# %%
## 재실기간 예측용 데이터
los_dataset = dict({
    'HADM_IDS': list(),
    'LABEL': list(),
    'DATA': list()
})

for hadm_id in tqdm(total_los_included_hadm_ids, desc='Make LOS Dataset', ncols=700):
  time_len = 12
  
  try:
    data = np.array(min_max_normalized[hadm_id][feature_keys[0]])[:time_len, 1].reshape(time_len, 1)
  except:
    continue

  for kk in feature_keys[1:]:
    data = np.concatenate((data, np.array(min_max_normalized[hadm_id][kk])[:time_len, 1].reshape(time_len, 1)), axis=1)
  
  los_dataset['HADM_IDS'].append(hadm_id)
  los_dataset['LABEL'].append(los_labels[hadm_id])
  los_dataset['DATA'].append(data)
# Out:
# Make LOS Dataset:   0%|                                                                                       …

# %%
with open('/content/gdrive/MyDrive/mimiciv_der/sepsis3_dataset_death_HADM_IDS.p', 'wb') as f:
    pickle.dump(death_dataset['HADM_IDS'], f)

# %%
with open('/content/gdrive/MyDrive/mimiciv_der/sepsis3_dataset_death_LABEL.p', 'wb') as f:
    pickle.dump(death_dataset['LABEL'], f)

# %%
with open('/content/gdrive/MyDrive/mimiciv_der/sepsis3_dataset_death_DATA.p', 'wb') as f:
    pickle.dump(death_dataset['DATA'], f)

# %%
death_dataset_read = dict({
    'HADM_IDS': list(),
    'LABEL': list(),
    'DATA': list()
})
with open('/content/gdrive/MyDrive/mimiciv_der/sepsis3_dataset_death_HADM_IDS.p', 'rb') as f:
    death_dataset_read['HADM_IDS'] = pickle.load(f)

# %%
#load
with open('/content/gdrive/MyDrive/mimiciv_der/sepsis3_dataset_death.pickle', 'rb') as f:
    death_dataset_read = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-94-2fc6ec55d04c> in <module>
#       1 #load
#       2 with open('/content/gdrive/MyDrive/mimiciv_der/sepsis3_dataset_death.pickle', 'rb') as f:
# ----> 3     death_dataset_read = pickle.load(f)
#
# UnpicklingError: invalid load key, '\x1f'.

# %%
# gzip 압축 파일을 열기
with gzip.open('/content/gdrive/MyDrive/mimiciv_der/sepsis3_dataset_death.pickle.gz', 'rb') as f:
    death_dataset_read = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# <ipython-input-99-5459890c033b> in <module>
#       1 # gzip 압축 파일을 열기
#       2 with gzip.open('/content/gdrive/MyDrive/mimiciv_der/sepsis3_dataset_death.pickle.gz', 'rb') as f:
# ----> 3     death_dataset_read = pickle.load(f)
#
# UnpicklingError: invalid load key, '\x1f'.

# %%
death_dataset_read

# %%
# load
# with open('data.pickle', 'rb') as f:
#     data = pickle.load(f)

# %%
len(death_dataset['DATA'][0])
# Out:
# 24

# %%
pd.DataFrame(zip(death_dataset['HADM_IDS'],death_dataset['LABEL'] ,death_dataset['DATA'])).
# Out:
#           0  1                                                  2
# 0  26184834  1  [[0.26666666666666666, 0.4, 0.2666666666666666...
# 1  23581541  0  [[0.26666666666666666, 0.4, 0.2666666666666666...
# 2  20345487  1  [[0.26666666666666666, 0.4, 0.2666666666666666...
# 3  23822395  0  [[0.26666666666666666, 0.4, 0.2666666666666666...
# 4  28994087  0  [[0.26666666666666666, 0.4, 0.2666666666666666...
